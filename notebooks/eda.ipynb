# %%
import pandas as pd
import numpy as np
import random
import os
import sys
import requests
import time
import datetime as dt


from dotenv import load_dotenv
from flipside import Flipside
from prophet import Prophet

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# from sql_queries.sql_scripts import eth_price

# %%
Optimistic_Domains_Sales_query = """
  SELECT
      DATE_TRUNC('HOUR', BLOCK_TIMESTAMP) AS day, tokenid, price
    FROM
      optimism.nft.ez_nft_sales
    WHERE
      NFT_ADDRESS = LOWER('0xC16aCAdf99E4540E6f4E6Da816fd6D2A2C6E1d4F')
      AND event_type = 'sale'

"""

eth_price = """

  select
    hour as dt,
    symbol,
    price
  from
    ethereum.price.ez_prices_hourly
  where
    symbol in('WETH', 'MATIC')
    AND date_trunc('day', dt) >= '	2022-06-01'
  order by
    dt DESC

"""

# %%
os.chdir('..')
print(os.getcwd())
# Out:
# e:\Projects\liquid_domains

# %%
from scripts.utils import flipside_api_results, set_random_seed
from scripts.pull_data import pull_data
from scripts.data_processing import process_data

# %%
os.chdir('Notebooks')

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
current_directory = os.getcwd()
current_directory
# Out:
# 'e:\\Projects\\liquid_domains\\Notebooks'

# %%
load_dotenv()
# Out:
# True

# %%
seed = 20
set_random_seed(seed)

# %%
flipside_api_key = os.getenv('FLIPSIDE_API_KEY')
alchemy_api_key = os.getenv('ALCHEMY_API_KEY')
opensea_api_key = os.getenv('OPENSEA_API_KEY')

print(alchemy_api_key)
# Out:
# 6AUlaGmWe505S7gRPZXVh4YEFgJdYHy5

# %%
X, y, prophet_features, gen_features, target, combined_dataset, features, web3_data, X_web3, y_web3 = process_data(api=False,web2_data=True,threshold=None,temporals=False)
# Out:
# 6AUlaGmWe505S7gRPZXVh4YEFgJdYHy5
# Loading Existing Data...
# --- ens ---
# Head:
#   event_type order_hash     chain protocol_address  closing_date  \
# 0       sale             ethereum                     1722697211
# 1       sale             ethereum                     1722693815
# 2       sale             ethereum                     1722691055
# 3       sale             ethereum                     1722678503
# 4       sale             ethereum                     1722674255
#
#                                                  nft  quantity  \
# 0  {'identifier': '863490954761714220907626264732...         1
# 1  {'identifier': '715520077537323923546374738250...         1
# 2  {'identifier': '369104001661904545929843729287...         1
# 3  {'identifier': '806657909463245954014835911972...         1
# 4  {'identifier': '101676255068068540833804650067...         1
#
#                                        seller  \
# 0  0x43fe064944ca1bc444853568131a3501b80a878f
# 1  0xd93725855d7812d950292a0d8f0d358a38a6b3d1
# 2  0x45ad2f39f591622050952dc7ce4659f5bfc7782c
# 3  0x47baba9b83c7cd484297e771d99076e904647511
# 4  0x2e8834f8417a3bf2fe9949eb04ad6a1be19652f2
#
#                                         buyer  \
# 0  0xdf87f06b2eccd221cf09c7022de1555515bff943
# 1  0x282fdeff5d6ccb038b427836881a051371664e45
# 2  0xbf195737afdae2c543fa0afc0161ad9869e0a805
# 3  0xe2cfb86df73c9f9a399a1a5a1aa14f7b1b203233
# 4  0x2080699a61efa9f6947901ed2361d4d0eea0fca4
#
#                                              payment  \
# 0  {'quantity': '2455000000000000', 'token_addres...
# 1  {'quantity': '7000000000000000', 'token_addres...
# 2  {'quantity': '2000000000000000', 'token_addres...
# 3  {'quantity': '550000000000000000', 'token_addr...
# 4  {'quantity': '10000000000000000', 'token_addre...
#
#                                          transaction  event_timestamp  \
# 0  0xd301ce6718e6b9e762c7c461b829c4e5c6f3bccd7199...       1722697211
# 1  0xf4a6e1252e9235b8ff2022ed34e1b762dbe66498f029...       1722693815
# 2  0x4e2d7a310ce5cbde53c06ac8e600e10e1231ba37ee0e...       1722691055
# 3  0x6939e3b81520e08706a028998ea9771f9d90a95f0f4b...       1722678503
# 4  0x74f5a3db5dda9b05905bb760a680ec4c635b92155527...       1722674255
#
#                                       nft_identifier        nft_name  \
# 0 86,349,095,476,171,416,204,496,000,643,597,425,...       ghaut.eth
# 1 71,552,007,753,732,387,614,282,500,469,513,396,...    ltaliano.eth
# 2 36,910,400,166,190,457,351,422,022,548,683,801,...      9797th.eth
# 3 80,665,790,946,324,601,651,199,810,530,833,638,...       joule.eth
# 4 101,676,255,068,068,542,704,731,039,737,725,146...  domainbank.eth
#
#                token_amt_raw token_symbol  token_decimals  \
# 0   2,455,000,000,000,000.00          ETH              18
# 1   7,000,000,000,000,000.00          ETH              18
# 2   2,000,000,000,000,000.00          ETH              18
# 3 550,000,000,000,000,000.00         WETH              18
# 4  10,000,000,000,000,000.00          ETH              18
#
#                         dt  token_amt_clean
# 0  2024-08-03T15:00:11.000             0.00
# 1  2024-08-03T14:03:35.000             0.01
# 2  2024-08-03T13:17:35.000             0.00
# 3  2024-08-03T09:48:23.000             0.55
# 4  2024-08-03T08:37:35.000             0.01
#
# Tail:
#       event_type order_hash     chain protocol_address  closing_date  \
# 41151       sale             ethereum                     1686547067
# 41152       sale             ethereum                     1686547067
# 41153       sale             ethereum                     1686547067
# 41154       sale             ethereum                     1686547067
# 41155       sale             ethereum                     1686547067
#
#                                                      nft  quantity  \
# 41151  {'identifier': '264335206260943651965296857543...         1
# 41152  {'identifier': '692490234501923176990969428043...         1
# 41153  {'identifier': '905908885627078610502014404334...         1
# 41154  {'identifier': '965312973343251955114837218570...         1
# 41155  {'identifier': '528239995736602405326750964692...         1
#
#                                            seller  \
# 41151  0xba724e65e81d66ffa085222332485211e77efa7b
# 41152  0xba724e65e81d66ffa085222332485211e77efa7b
# 41153  0xba724e65e81d66ffa085222332485211e77efa7b
# 41154  0xba724e65e81d66ffa085222332485211e77efa7b
# 41155  0xba724e65e81d66ffa085222332485211e77efa7b
#
#                                             buyer  \
# 41151  0xc444d559305be9788f64a2c2b28430edf3cc17fe
# 41152  0xc444d559305be9788f64a2c2b28430edf3cc17fe
# 41153  0xc444d559305be9788f64a2c2b28430edf3cc17fe
# 41154  0xc444d559305be9788f64a2c2b28430edf3cc17fe
# 41155  0xc444d559305be9788f64a2c2b28430edf3cc17fe
#
#                                                  payment  \
# 41151  {'quantity': '9500000000000001', 'token_addres...
# 41152  {'quantity': '9500000000000001', 'token_addres...
# 41153  {'quantity': '9500000000000001', 'token_addres...
# 41154  {'quantity': '9500000000000001', 'token_addres...
# 41155  {'quantity': '9500000000000001', 'token_addres...
#
#                                              transaction  event_timestamp  \
# 41151  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
# 41152  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
# 41153  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
# 41154  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
# 41155  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
#
#                                           nft_identifier   nft_name  \
# 41151 26,433,520,626,094,364,145,687,966,688,793,167,...  82337.eth
# 41152 69,249,023,450,192,320,286,030,058,028,418,970,...  60983.eth
# 41153 90,590,888,562,707,863,584,023,800,423,822,006,...  22967.eth
# 41154 96,531,297,334,325,189,994,337,204,354,020,381,...  55287.eth
# 41155 52,823,999,573,660,241,687,521,878,105,091,111,...  68773.eth
#
#                  token_amt_raw token_symbol  token_decimals  \
# 41151 9,500,000,000,000,000.00          ETH              18
# 41152 9,500,000,000,000,000.00          ETH              18
# 41153 9,500,000,000,000,000.00          ETH              18
# 41154 9,500,000,000,000,000.00          ETH              18
# 41155 9,500,000,000,000,000.00          ETH              18
#
#                             dt  token_amt_clean
# 41151  2023-06-12T05:17:47.000             0.01
# 41152  2023-06-12T05:17:47.000             0.01
# 41153  2023-06-12T05:17:47.000             0.01
# 41154  2023-06-12T05:17:47.000             0.01
# 41155  2023-06-12T05:17:47.000             0.01
#
# ========================================
#
# --- optimistic_domains ---
# Head:
#    tokenId              name
# 0        0        vitalik.op
# 1        1       cardenas.op
# 2        2  davidcardenas.op
# 3        3        bitcoin.op
# 4        4          daffy.op
#
# Tail:
#       tokenId       name
# 1321     1321  agency.op
# 1322     1322   trump.op
# 1323     1323    send.op
# 1324     1324    mint.op
# 1325     1325    lock.op
#
# ========================================
#
# --- Three_DNS_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0xa9e856a5258931c57071cf787ab88dc425d542eb617c...  optimism
# 1       sale  0x475d0b58dbbc6e861b1e0df67be0e9eae0d623459d1b...  optimism
# 2       sale  0xc292285285639ab3f4dc95d2fd965a62fc1f94388f4a...  optimism
# 3       sale  0x2cc8de6755a7f9ef0b0a2252c7064896dde56b74e150...  optimism
# 4       sale  0xe49e38d70d15a87977a194ced8dfd395d724aff2ee07...  optimism
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1722706445
# 1  0x0000000000000068f116a894984e2db1123eb395    1722705143
# 2  0x0000000000000068f116a894984e2db1123eb395    1722705143
# 3  0x0000000000000068f116a894984e2db1123eb395    1722705143
# 4  0x0000000000000068f116a894984e2db1123eb395    1722705143
#
#                                                  nft  quantity  \
# 0  {'identifier': '103630415007535906696789966598...         1
# 1  {'identifier': '639074560259187791163341248616...         1
# 2  {'identifier': '704945072107423982885731232559...         1
# 3  {'identifier': '102076623466713499022234692002...         1
# 4  {'identifier': '118122428161922898295278368225...         1
#
#                                        seller  \
# 0  0x3f1c0ea76342cc3427962452891f8de8649a301b
# 1  0x72597de06e58ad98c6f66c6cd8fab1dd9f73a2ca
# 2  0x3e0783b65e967c6c702344d21855cb0813c24721
# 3  0x64b561dd2ee540e8f99ee29b614b43235bb868fe
# 4  0x2888eecd915fbb6be65dac1d51cd48a340e3ab1f
#
#                                         buyer  \
# 0  0x0123456789070ce8f0d6bab722103d12674bc257
# 1  0xce462546297fa07a11eca7f1a3a5a36df8925cf7
# 2  0xce462546297fa07a11eca7f1a3a5a36df8925cf7
# 3  0xce462546297fa07a11eca7f1a3a5a36df8925cf7
# 4  0xce462546297fa07a11eca7f1a3a5a36df8925cf7
#
#                                              payment  \
# 0  {'quantity': '120000000000000000', 'token_addr...
# 1  {'quantity': '280000000000000', 'token_address...
# 2  {'quantity': '290000000000000', 'token_address...
# 3  {'quantity': '300000000000000', 'token_address...
# 4  {'quantity': '450000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0x640e67bd79a430a2229b2596ae243693700e81dd20d1...       1722706445
# 1  0x2e14caceffd934cb6d75e255111b4ac207b166357c29...       1722705143
# 2  0x2e14caceffd934cb6d75e255111b4ac207b166357c29...       1722705143
# 3  0x2e14caceffd934cb6d75e255111b4ac207b166357c29...       1722705143
# 4  0x2e14caceffd934cb6d75e255111b4ac207b166357c29...       1722705143
#
#                                       nft_identifier  \
# 0 103,630,415,007,535,905,091,168,346,033,468,857...
# 1 63,907,456,025,918,784,550,431,386,390,280,815,...
# 2 70,494,507,210,742,404,178,780,831,369,986,847,...
# 3 102,076,623,466,713,504,937,515,277,532,453,510...
# 4 11,812,242,816,192,290,227,614,680,555,896,161,...
#
#                    nft_name              token_amt_raw token_symbol  \
# 0                    03.box 120,000,000,000,000,000.00         WETH
# 1            flon.chain.box     280,000,000,000,000.00          ETH
# 2             eua.chain.box     290,000,000,000,000.00          ETH
# 3  investecriptos.chain.box     300,000,000,000,000.00          ETH
# 4    drivenspyder.chain.box     450,000,000,000,000.00          ETH
#
#    token_decimals             dt  token_amt_clean
# 0              18  1722706445000             0.12
# 1              18  1722705143000             0.00
# 2              18  1722705143000             0.00
# 3              18  1722705143000             0.00
# 4              18  1722705143000             0.00
#
# Tail:
#     event_type                                         order_hash     chain  \
# 153       sale  0x8bde44f2d46537cf8d025cc498eaf7bdeadce3631f15...  optimism
# 154       sale  0xc0547b5b8d575e3ba16b529ee2530a35c437bc75fa93...  optimism
# 155       sale  0xff4b9bdd3f140f8211864ef34e0a07ea0a92eaf98f7d...  optimism
# 156       sale  0x03188e15aaf9596307117e30355f6b2ac79665fbd1c2...  optimism
# 157       sale  0x3cd7cfda4dd935529af2c4f882476b40cc37340ae2a6...  optimism
#
#                                protocol_address  closing_date  \
# 153  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706970257
# 154  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706653465
# 155  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706203283
# 156  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1704080589
# 157  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1703624873
#
#                                                    nft  quantity  \
# 153  {'identifier': '260923785748676206958654735781...         1
# 154  {'identifier': '566479911085778512201556021651...         1
# 155  {'identifier': '364706086468987072255605061503...         1
# 156  {'identifier': '992340878683635895851755157396...         1
# 157  {'identifier': '686186082504474765846111255346...         1
#
#                                          seller  \
# 153  0xcc0e0b9ebd4ce352f5a50b3ae77ea01202c284ee
# 154  0x240ad467a71210629d71d4de22ebde27951c83fc
# 155  0x7b363822d744143d51c69b0757165c987a6e4ef4
# 156  0x31b32020fb1bdf0228c58b80590f07b235f2b0ce
# 157  0xff3d39f7766ebb57a4175b6d919937409f6d6fee
#
#                                           buyer  \
# 153  0xc48a8ac51df7b71e500a5580b89e47ab26ca1472
# 154  0x82eb45562f991329ed2867f43fc60f0ba52c3dab
# 155  0xe68e8cc7ff772b026c062b9cc28246676d044947
# 156  0x64233eaa064ef0d54ff1a963933d0d2d46ab5829
# 157  0x46f09888867c8cd9042b943099663e856e43de46
#
#                                                payment  \
# 153  {'quantity': '1000000000000000', 'token_addres...
# 154  {'quantity': '110000000000000000', 'token_addr...
# 155  {'quantity': '10000000000000000', 'token_addre...
# 156  {'quantity': '150000000000000000', 'token_addr...
# 157  {'quantity': '22000000000000000', 'token_addre...
#
#                                            transaction  event_timestamp  \
# 153  0x60e952a8e0fa8d052791b2e4a22fd52eb3c759511e62...       1706970257
# 154  0x6672189deb7829838aabba20ddeb66a3cb5fee5b55a2...       1706653465
# 155  0xd8e71f4d52c43fa770b9aa7ad7d5cfb073f04c7495e0...       1706203283
# 156  0x186d1ceacf620bab710d11cf928b79e5dd46790ff1d5...       1704080589
# 157  0x1c7ed62756b60a73470fa39ea6546510ad426e261d14...       1703624873
#
#                                         nft_identifier            nft_name  \
# 153 26,092,378,574,867,619,527,232,167,678,805,405,...             696.box
# 154 56,647,991,108,577,850,953,984,972,492,538,466,...         opensea.box
# 155 36,470,608,646,898,707,880,068,503,761,534,760,...           08000.xyz
# 156 99,234,087,868,363,590,418,701,991,799,513,400,...        2024.finance
# 157 68,618,608,250,447,471,069,153,845,880,935,638,...  topdomains.finance
#
#                  token_amt_raw token_symbol  token_decimals             dt  \
# 153   1,000,000,000,000,000.00         WETH              18  1706970257000
# 154 110,000,000,000,000,000.00         WETH              18  1706653465000
# 155  10,000,000,000,000,000.00          ETH              18  1706203283000
# 156 150,000,000,000,000,000.00          ETH              18  1704080589000
# 157  22,000,000,000,000,000.00          ETH              18  1703624873000
#
#      token_amt_clean
# 153             0.00
# 154             0.11
# 155             0.01
# 156             0.15
# 157             0.02
#
# ========================================
#
# --- base_domains_metadata_pd ---
# Head:
#   event_type                                         order_hash chain  \
# 0       sale                                                     base
# 1       sale                                                     base
# 2       sale  0x945d37a0e222fc4b276bdb2128f8a9bbfbebd10efbbb...  base
# 3       sale  0xf252233595c8e5ed9537fda860278acefa19a8db542d...  base
# 4       sale  0xb2abcf6e7e0c0118c8999cfbfe93b226b8e068d81fe3...  base
#
#                              protocol_address  closing_date  \
# 0                                                1719530881
# 1                                                1719530857
# 2  0x0000000000000068f116a894984e2db1123eb395    1719112413
# 3  0x0000000000000068f116a894984e2db1123eb395    1719110431
# 4  0x0000000000000068f116a894984e2db1123eb395    1719108841
#
#                                                  nft  quantity  \
# 0  {'identifier': '6625', 'collection': 'basedoma...         1
# 1  {'identifier': '6707', 'collection': 'basedoma...         1
# 2  {'identifier': '4863', 'collection': 'basedoma...         1
# 3  {'identifier': '19245', 'collection': 'basedom...         1
# 4  {'identifier': '9711', 'collection': 'basedoma...         1
#
#                                        seller  \
# 0  0x8afefd4a26c46b48dbaed293f78a6cf5e72093be
# 1  0x8afefd4a26c46b48dbaed293f78a6cf5e72093be
# 2  0x0d24ddea6ceefaa45e4d577ce07b840320097586
# 3  0xc2e3d9f054a494b228d44b78781eb03ca6e05c35
# 4  0x1458cb4003eb115bf3e19497016009a69db35982
#
#                                         buyer  \
# 0  0xc2e3d9f054a494b228d44b78781eb03ca6e05c35
# 1  0xc2e3d9f054a494b228d44b78781eb03ca6e05c35
# 2  0x20a27618cdb1ae314b5852249c4fa09447c90bdb
# 3  0xb509c39166a690f73d152051ec8076b7ee4de900
# 4  0x147b72fd2e1fb3b7e478b4ad6e3ecc11236a8973
#
#                                              payment  \
# 0  {'quantity': '10000000000000', 'token_address'...
# 1  {'quantity': '10000000000000', 'token_address'...
# 2  {'quantity': '544900000000000', 'token_address...
# 3  {'quantity': '544900000000000', 'token_address...
# 4  {'quantity': '488000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0x361fefcb858f70d5718985628159bdd6a41aa7beb1b7...       1719530881
# 1  0x4d76726610008f8d5f98ba5ec8c7430dc9ae6f97b7d3...       1719530857
# 2  0x5c5ae2b392f25822bcce3c166334ab978d2f066eb002...       1719112413
# 3  0x1009bae51041cc0f0f88b0e5b613359801287fa6e67c...       1719110431
# 4  0x365f6f2308037def5f7fa98410409a8d94aed08a07c8...       1719108841
#
#    nft_identifier          nft_name    token_amt_raw token_symbol  \
# 0            6625  Vizzycrypto.base   10000000000000          ETH
# 1            6707      Cryptox.base   10000000000000          ETH
# 2            4863        38888.base  544900000000000          ETH
# 3           19245       venice.base  544900000000000          ETH
# 4            9711        13333.base  488000000000000          ETH
#
#    token_decimals             dt  token_amt_clean
# 0              18  1719530881000             0.00
# 1              18  1719530857000             0.00
# 2              18  1719112413000             0.00
# 3              18  1719110431000             0.00
# 4              18  1719108841000             0.00
#
# Tail:
#    event_type                                         order_hash chain  \
# 91       sale  0x179558a1e2b1588b041e77960b7c415339db8d055f29...  base
# 92       sale  0x3b6a002b6daf8e3218cf5d8d858d482c4076d88d3fcc...  base
# 93       sale  0x6a9be1bc39c943a96d0f7c7afce10082d4f295f0adfa...  base
# 94       sale  0xb4693b06b1c088276aaff2c83e8b736272fad0e1bd19...  base
# 95       sale  0xb7b5e18955103fa4ca87d37d44c18362867a6b3fbca4...  base
#
#                               protocol_address  closing_date  \
# 91  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691618587
# 92  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691616539
# 93  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691613043
# 94  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691607621
# 95  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691598979
#
#                                                   nft  quantity  \
# 91  {'identifier': '3505', 'collection': 'basedoma...         1
# 92  {'identifier': '2704', 'collection': 'basedoma...         1
# 93  {'identifier': '4695', 'collection': 'basedoma...         1
# 94  {'identifier': '3204', 'collection': 'basedoma...         1
# 95  {'identifier': '6435', 'collection': 'basedoma...         1
#
#                                         seller  \
# 91  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 92  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 93  0x269f77497956ef4aa79962b54bc715ee62b4c684
# 94  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 95  0x280ad8a544ca166f4ec2ddc4458aeb194d53e3fb
#
#                                          buyer  \
# 91  0xa2bae9e9fc3af9dc136db6d06be07c7f2e71b5bc
# 92  0x1deacf16b32bd686bea74cff7c382f675c3aa7c1
# 93  0x208e184f3186bc19b1c49a3cae8cbff3142d6e91
# 94  0x570866568da48898755268239c27e34afa575226
# 95  0x96fd61202a698ee3eac21e247a6b209ea5ffeb91
#
#                                               payment  \
# 91  {'quantity': '11000000000000000', 'token_addre...
# 92  {'quantity': '11000000000000000', 'token_addre...
# 93  {'quantity': '2500000000000000', 'token_addres...
# 94  {'quantity': '3500000000000000', 'token_addres...
# 95  {'quantity': '7300000000000000', 'token_addres...
#
#                                           transaction  event_timestamp  \
# 91  0x3064100ce1ab4419c19324f7d83e5b42ab6603e96b15...       1691618587
# 92  0x18e2ed5f6ee64211f19e887197fe104c78becff9dbb6...       1691616539
# 93  0x45819e6cea811e2b858b8dc938cf234e69d24f7b84e6...       1691613043
# 94  0xb5cd43a2d7fb7b4e9acebdc727190c079204c1d23529...       1691607621
# 95  0x2a2ce146c08f0424b8a82448abe1308ff3a9c8ceb9e6...       1691598979
#
#     nft_identifier      nft_name      token_amt_raw token_symbol  \
# 91            3505      rug.base  11000000000000000          ETH
# 92            2704      200.base  11000000000000000          ETH
# 93            4695    manga.base   2500000000000000          ETH
# 94            3204  bullish.base   3500000000000000          ETH
# 95            6435    Clock.base   7300000000000000          ETH
#
#     token_decimals             dt  token_amt_clean
# 91              18  1691618587000             0.01
# 92              18  1691616539000             0.01
# 93              18  1691613043000             0.00
# 94              18  1691607621000             0.00
# 95              18  1691598979000             0.01
#
# ========================================
#
# --- unstoppable_sales_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0xb03f2e78925cde538c10e5fad3bcc6b4e655ae51e003...  ethereum
# 1       sale  0x088e924cb0ef441b0d68821764db063467c572e8f9a1...  ethereum
# 2       sale  0xceb738fa285cf4de22c16c5c676ba026e5ffe84c73b7...  ethereum
# 3       sale  0x1064f829ae8be80b5ad31a1271cdeae52d7e3a44f474...  ethereum
# 4       sale  0xa30969fb217ac7c58101213ac2104bd6598db75d7c5d...  ethereum
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1720198883
# 1  0x0000000000000068f116a894984e2db1123eb395    1718617967
# 2  0x0000000000000068f116a894984e2db1123eb395    1718614055
# 3  0x0000000000000068f116a894984e2db1123eb395    1718613323
# 4  0x0000000000000068f116a894984e2db1123eb395    1718550443
#
#                                                  nft  quantity  \
# 0  {'identifier': '732609744346663118421256248151...         1
# 1  {'identifier': '799288950834081445126736498481...         1
# 2  {'identifier': '720141416088167626284738564926...         1
# 3  {'identifier': '559353050680242471594511596608...         1
# 4  {'identifier': '911899529139068149563600522019...         1
#
#                                        seller  \
# 0  0xd5b43c1d9c145bdf25c163ecf8fa1fe040202adc
# 1  0xcbb58904774cf1bee98741c466aace0206fb090b
# 2  0xcbb58904774cf1bee98741c466aace0206fb090b
# 3  0xcbb58904774cf1bee98741c466aace0206fb090b
# 4  0xcbb58904774cf1bee98741c466aace0206fb090b
#
#                                         buyer  \
# 0  0x84eb2355fc7556e07bbc410be55063bc3b61a006
# 1  0xb54e5bd4a9d9f2a7721136041ba41db77cd90e9a
# 2  0x0a3b0a790ca4f9fbaa2618c548cde45be0249c2f
# 3  0x8be28746913422eef1e255df992b32c702576bdc
# 4  0xeb11c3f006b1fe207f8ec1a153e480db86c3ce4f
#
#                                              payment  \
# 0  {'quantity': '50000000000000', 'token_address'...
# 1  {'quantity': '990000000000000', 'token_address...
# 2  {'quantity': '990000000000000', 'token_address...
# 3  {'quantity': '990000000000000', 'token_address...
# 4  {'quantity': '890000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0xdb0a0ef3662b0975e886b41bf984f03f387ab6edcfa2...       1720198883
# 1  0x6d26ae182bb40d6dd4a7378609061cb046103bd30853...       1718617967
# 2  0x447d7ccb8ccb6eeb7d4dfbb6e838e918639172ac66a9...       1718614055
# 3  0x22369eee55b5313147708ada54f6276be250850f8f7a...       1718613323
# 4  0x25db8dd631e2901f0020dee0f8d826dd1b7f2c22f8b5...       1718550443
#
#                                       nft_identifier  \
# 0 73,260,974,434,666,309,016,726,815,552,216,794,...
# 1 79,928,895,083,408,148,097,614,756,880,763,030,...
# 2 72,014,141,608,816,767,035,628,981,280,910,821,...
# 3 55,935,305,068,024,247,420,483,647,586,810,650,...
# 4 91,189,952,913,906,813,838,813,506,742,274,520,...
#
#                    nft_name          token_amt_raw token_symbol  \
# 0           gaydream.crypto  50,000,000,000,000.00          ETH
# 1    officialdaimler.crypto 990,000,000,000,000.00          ETH
# 2       officialaudi.crypto 990,000,000,000,000.00          ETH
# 3  officialbillgates.crypto 990,000,000,000,000.00          ETH
# 4         scaryterry.crypto 890,000,000,000,000.00          ETH
#
#    token_decimals                       dt  token_amt_clean
# 0              18  2024-07-05T17:01:23.000             0.00
# 1              18  2024-06-17T09:52:47.000             0.00
# 2              18  2024-06-17T08:47:35.000             0.00
# 3              18  2024-06-17T08:35:23.000             0.00
# 4              18  2024-06-16T15:07:23.000             0.00
#
# Tail:
#      event_type order_hash     chain  \
# 3896       sale             ethereum
# 3897       sale             ethereum
# 3898       sale             ethereum
# 3899       sale             ethereum
# 3900       sale             ethereum
#
#                                 protocol_address  closing_date  \
# 3896  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1577178632
# 3897  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1577178582
# 3898  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576900527
# 3899  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576768395
# 3900  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576313422
#
#                                                     nft  quantity  \
# 3896  {'identifier': '860899055054694856908010487707...         1
# 3897  {'identifier': '940569713444058262943635252235...         1
# 3898  {'identifier': '446163175071435156510839745607...         1
# 3899  {'identifier': '176192171829730767798338643850...         1
# 3900  {'identifier': '164502264543840507301076043053...         1
#
#                                           seller  \
# 3896  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3897  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3898  0x8124b02b4967bd7338a450420a572d574915ff9c
# 3899  0xfa4ab967d3ac0b94955b8df63ede213695f38d6f
# 3900  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
#
#                                            buyer  \
# 3896  0x525e89c4d5052d5afb5a7f0884b296b0138adfd4
# 3897  0x525e89c4d5052d5afb5a7f0884b296b0138adfd4
# 3898  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3899  0x8124b02b4967bd7338a450420a572d574915ff9c
# 3900  0x519e570344747173c5febde6c2df0c3252175bb3
#
#                                                 payment  \
# 3896  {'quantity': '100000000000000000', 'token_addr...
# 3897  {'quantity': '100000000000000000', 'token_addr...
# 3898  {'quantity': '45000000000000000', 'token_addre...
# 3899  {'quantity': '70000000000000000', 'token_addre...
# 3900  {'quantity': '69900000000000000', 'token_addre...
#
#                                             transaction  event_timestamp  \
# 3896  0xa0349c718c1f794d51d1ba664ee238f2d61dac847e5c...       1577178632
# 3897  0x6f83aa5c2d5377fa88d770d6b6709922fe79d16eb2c5...       1577178582
# 3898  0x068264028eac1e60c0bfc6dac93d65165edaaad19ea6...       1576900527
# 3899  0x0994ef978059265afb7b8c6deb0ac6afe4d6f31b25ba...       1576768395
# 3900  0x60b8773e82dd9f9612f687c925062aa2bc4e2cf8c86f...       1576313422
#
#                                          nft_identifier          nft_name  \
# 3896 86,089,905,505,469,488,148,445,830,396,242,062,...    bittiez.crypto
# 3897 94,056,971,344,405,822,053,661,343,907,032,761,...    bitties.crypto
# 3898 44,616,317,507,143,517,844,109,711,444,778,473,...  impeached.crypto
# 3899 17,619,217,182,973,076,162,112,808,839,711,553,...  ethstaker.crypto
# 3900 16,450,226,454,384,049,539,296,233,940,056,623,...    cryptoq.crypto
#
#                   token_amt_raw token_symbol  token_decimals  \
# 3896 100,000,000,000,000,000.00         WETH              18
# 3897 100,000,000,000,000,000.00         WETH              18
# 3898  45,000,000,000,000,000.00         WETH              18
# 3899  70,000,000,000,000,000.00          ETH              18
# 3900  69,900,000,000,000,000.00          ETH              18
#
#                            dt  token_amt_clean
# 3896  2019-12-24T09:10:32.000             0.10
# 3897  2019-12-24T09:09:42.000             0.10
# 3898  2019-12-21T03:55:27.000             0.04
# 3899  2019-12-19T15:13:15.000             0.07
# 3900  2019-12-14T08:50:22.000             0.07
#
# ========================================
#
# --- optimistic_domains_sales ---
# Head:
#                        DAY  TOKENID  PRICE  PRICE_USD
# 0  2022-07-28 16:00:00.000   850.00   0.01       8.27
# 1  2022-07-13 06:00:00.000   902.00   0.02      21.05
# 2  2022-07-13 06:00:00.000   915.00   0.03      26.31
# 3  2022-08-04 20:00:00.000   933.00   0.01      22.76
# 4  2022-08-04 20:00:00.000   932.00   0.01      21.43
#
# Tail:
#                         DAY  TOKENID  PRICE  PRICE_USD
# 13  2023-02-20 21:00:00.000   413.00   0.03      46.02
# 14  2023-02-20 21:00:00.000 1,076.00   0.05      85.22
# 15  2022-06-06 14:00:00.000   576.00   0.05      95.46
# 16  2022-10-13 10:00:00.000   413.00  11.00       7.53
# 17                        ﻿      NaN    NaN        NaN
#
# ========================================
#
# --- optimism_name_service_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0x9370590b86b641bc94a2be25aca2b15531a19325191f...  optimism
# 1       sale  0x18ea42e4de0d824598c95f5612ba0bca41bc73d8d4a2...  optimism
# 2       sale  0xa90655cad3a8fcb26609bafe5cc3d83d709c2fb48ccb...  optimism
# 3       sale  0x23170df056ba214c65aec2b300595a3c8cbae7c864dc...  optimism
# 4       sale  0x78be0458f50d3d89ad3206cb82ce38119c8df530c08b...  optimism
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1717118919
# 1  0x0000000000000068f116a894984e2db1123eb395    1715204651
# 2  0x0000000000000068f116a894984e2db1123eb395    1711976895
# 3  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1710975355
# 4  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1710017397
#
#                                                  nft  quantity  \
# 0  {'identifier': '986055613691005048366660295505...         1
# 1  {'identifier': '549978610354346671082331131741...         1
# 2  {'identifier': '397548654027272243885589702261...         1
# 3  {'identifier': '548782968751199257669238317507...         1
# 4  {'identifier': '525166297008421355185137086623...         1
#
#                                        seller  \
# 0  0x670b244e4bc0667224c603cf2ab1dace411fdbb5
# 1  0x9bac53cbfbb8c52f22e7e278c63ec7c4abf0593e
# 2  0x670b244e4bc0667224c603cf2ab1dace411fdbb5
# 3  0x1960a7b4993a3e85cad2f3e765111065ca3b3743
# 4  0x3352640be5c1c26d0e0f36e1cc3847ade4d79806
#
#                                         buyer  \
# 0  0xc7c72e53c78447041c4728aac33f286fa532ca4c
# 1  0x450aeab30443a3ad15750ddb3c8636717e9c048a
# 2  0x4b9cf9153935e17000d896e78f4230ecd3d9d997
# 3  0xd06d855652a73e61bfe26a3427dfe51f3b827fe3
# 4  0xf408bee3443d0397e2c1cde588fb060ac657006f
#
#                                              payment  \
# 0  {'quantity': '700000000000000', 'token_address...
# 1  {'quantity': '600000000000000', 'token_address...
# 2  {'quantity': '700000000000000', 'token_address...
# 3  {'quantity': '700000000000000', 'token_address...
# 4  {'quantity': '700000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0x57ce323344bedf790dd7bd93ae7c351e8f1989be316c...       1717118919
# 1  0xee6fd38e4e341eefc2382161bbd9b44d27dee994060d...       1715204651
# 2  0xc78f61b77433609c82e04aa4a5ced1247081505ddb5d...       1711976895
# 3  0x27a00b506cf28bb145830b479ddbcef675848da4b00e...       1710975355
# 4  0xe08912c1109dd694128de39871a113217c8c2cc99735...       1710017397
#
#                                       nft_identifier     nft_name  \
# 0 98,605,561,369,100,498,602,024,245,469,838,703,...    zainal.op
# 1 5,499,786,103,543,466,330,119,275,902,716,700,8...     oksie.op
# 2 39,754,865,402,727,223,184,320,167,547,016,687,...    ahamad.op
# 3 5,487,829,687,511,992,584,552,359,460,892,473,9...  squanchy.op
# 4 52,516,629,700,842,134,031,927,131,776,612,298,...    azukii.op
#
#      token_amt_raw token_symbol  token_decimals             dt  \
# 0  700000000000000          ETH              18  1717118919000
# 1  600000000000000          ETH              18  1715204651000
# 2  700000000000000          ETH              18  1711976895000
# 3  700000000000000          ETH              18  1710975355000
# 4  700000000000000          ETH              18  1710017397000
#
#    token_amt_clean
# 0             0.00
# 1             0.00
# 2             0.00
# 3             0.00
# 4             0.00
#
# Tail:
#     event_type                                         order_hash     chain  \
# 728       sale  0x0da4f090909f31862f79a4e76a396766a7fe3e3d8637...  optimism
# 729       sale  0x07f366c8693d6492b394ce78aa1e580a230b6e282d36...  optimism
# 730       sale  0x029b6a83792ed956bff1318490196524c8de7b5d5d74...  optimism
# 731       sale  0x621db398cdef6e0b0737ba21715d07b42927ad838ea4...  optimism
# 732       sale  0xbb5d4c44682316fee95d1dd37d302982ec32f626b5c7...  optimism
#
#                                protocol_address  closing_date  \
# 728  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932343
# 729  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 730  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 731  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 732  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677921991
#
#                                                    nft  quantity  \
# 728  {'identifier': '120219272988803680872974995977...         1
# 729  {'identifier': '212128970836456136940270979598...         1
# 730  {'identifier': '248444384559923954980940474589...         1
# 731  {'identifier': '549015022443570801134689433390...         1
# 732  {'identifier': '488099369330375128690249371270...         1
#
#                                          seller  \
# 728  0xaf6d4f2f0f4d08b34182234d6c39865b56ab5b4c
# 729  0x50921467fd9defc962af2636b36867d423244ff8
# 730  0x50921467fd9defc962af2636b36867d423244ff8
# 731  0x50921467fd9defc962af2636b36867d423244ff8
# 732  0xa2bc5e3be3d883879caf9a9f2a610584506fc6dd
#
#                                           buyer  \
# 728  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 729  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 730  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 731  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 732  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
#
#                                                payment  \
# 728  {'quantity': '2500000000000000', 'token_addres...
# 729  {'quantity': '50000000000000000', 'token_addre...
# 730  {'quantity': '50000000000000000', 'token_addre...
# 731  {'quantity': '50000000000000000', 'token_addre...
# 732  {'quantity': '100000000000000000', 'token_addr...
#
#                                            transaction  event_timestamp  \
# 728  0xdaff73e094af54678a23e9a419d4d7fb53ce76d443e3...       1677932343
# 729  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 730  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 731  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 732  0xf1c8349d99024e6792525239b4cd655d219957433ec9...       1677921991
#
#                                         nft_identifier       nft_name  \
# 728 12,021,927,298,880,368,312,276,012,569,694,239,...      888666.op
# 729 21,212,897,083,645,615,095,268,562,890,835,548,...  highstreet.op
# 730 24,844,438,455,992,396,859,894,623,792,547,027,...      bitget.op
# 731 54,901,502,244,357,081,727,363,511,107,096,227,...       bybit.op
# 732 48,809,936,933,037,512,706,059,515,308,167,888,...       abcde.op
#
#           token_amt_raw token_symbol  token_decimals             dt  \
# 728    2500000000000000          ETH              18  1677932343000
# 729   50000000000000000          ETH              18  1677932205000
# 730   50000000000000000          ETH              18  1677932205000
# 731   50000000000000000          ETH              18  1677932205000
# 732  100000000000000000          ETH              18  1677921991000
#
#      token_amt_clean
# 728             0.00
# 729             0.05
# 730             0.05
# 731             0.05
# 732             0.10
#
# ========================================
#
# --- prices_data ---
# Head:
#                         DT SYMBOL    PRICE
# 0  2024-08-03 18:00:00.000   WETH 2,933.84
# 1  2024-08-03 18:00:00.000  MATIC     0.46
# 2  2024-08-03 17:00:00.000   WETH 2,952.17
# 3  2024-08-03 17:00:00.000  MATIC     0.46
# 4  2024-08-03 16:00:00.000  MATIC     0.47
#
# Tail:
#                              DT SYMBOL  PRICE
# 99996   2018-06-16 08:00:00.000   WETH 494.07
# 99997   2018-06-16 07:00:00.000   WETH 492.07
# 99998   2018-06-16 06:00:00.000   WETH 490.08
# 99999   2018-06-16 05:00:00.000   WETH 489.49
# 100000                        ﻿    NaN    NaN
#
# ========================================
# e:\Projects\liquid_domains\scripts\data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_data['SYMBOL'] = prices_data['SYMBOL'].replace('WETH', 'ETH')
# e:\Projects\liquid_domains\scripts\data_processing.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optimistic_domains_sales['TOKENID'] = optimistic_domains_sales['TOKENID'].astype(int)
# e:\Projects\liquid_domains\scripts\data_processing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optimistic_domains_sales.rename(columns={"TOKENID":"tokenId"}, inplace=True)
# e:\Projects\liquid_domains\scripts\data_processing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optimism_name_service_data['dt'] = pd.to_datetime(optimism_name_service_data['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Three_DNS_data['dt'] = pd.to_datetime(Three_DNS_data['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ens_data['dt'] = pd.to_datetime(ens_data['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unstoppable_sales_data['dt'] = pd.to_datetime(unstoppable_sales_data['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_domains_metadata_pd['dt'] = pd.to_datetime(base_domains_metadata_pd['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:253: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_dataset['tld_weight'] = combined_dataset['tld'].map(tld_weights).fillna(default_tld_weight)  # Default weight is 1 if tld is not in tld_weights
# target:price_usd,
#  features:Index(['dt', 'domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld',
#        'tld_weight'],
#       dtype='object')
# num_vowels       -0.00
# domain_length    -0.00
# num_consonants   -0.00
# price_usd         1.00
# tld_weight         NaN
# Name: price_usd, dtype: float64
# cols to drop: []
# prophet to drop: ['dt']
# features: Index(['dt', 'domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld',
#        'tld_weight'],
#       dtype='object')
# gen features
# prophet features

# %%
combined_dataset.columns
# Out:
# Index(['dt', 'domain', 'price_usd', 'domain_length', 'num_vowels',
#        'num_consonants', 'tld', 'tld_weight'],
#       dtype='object')

# %% [markdown]
# # Sales

# %%
from models.model import train_model

# %%
train_model()
# Out:
# 6AUlaGmWe505S7gRPZXVh4YEFgJdYHy5
# Loading Existing Data...
# --- ens ---
# Head:
#   event_type order_hash     chain protocol_address  closing_date  \
# 0       sale             ethereum                     1722697211
# 1       sale             ethereum                     1722693815
# 2       sale             ethereum                     1722691055
# 3       sale             ethereum                     1722678503
# 4       sale             ethereum                     1722674255
#
#                                                  nft  quantity  \
# 0  {'identifier': '863490954761714220907626264732...         1
# 1  {'identifier': '715520077537323923546374738250...         1
# 2  {'identifier': '369104001661904545929843729287...         1
# 3  {'identifier': '806657909463245954014835911972...         1
# 4  {'identifier': '101676255068068540833804650067...         1
#
#                                        seller  \
# 0  0x43fe064944ca1bc444853568131a3501b80a878f
# 1  0xd93725855d7812d950292a0d8f0d358a38a6b3d1
# 2  0x45ad2f39f591622050952dc7ce4659f5bfc7782c
# 3  0x47baba9b83c7cd484297e771d99076e904647511
# 4  0x2e8834f8417a3bf2fe9949eb04ad6a1be19652f2
#
#                                         buyer  \
# 0  0xdf87f06b2eccd221cf09c7022de1555515bff943
# 1  0x282fdeff5d6ccb038b427836881a051371664e45
# 2  0xbf195737afdae2c543fa0afc0161ad9869e0a805
# 3  0xe2cfb86df73c9f9a399a1a5a1aa14f7b1b203233
# 4  0x2080699a61efa9f6947901ed2361d4d0eea0fca4
#
#                                              payment  \
# 0  {'quantity': '2455000000000000', 'token_addres...
# 1  {'quantity': '7000000000000000', 'token_addres...
# 2  {'quantity': '2000000000000000', 'token_addres...
# 3  {'quantity': '550000000000000000', 'token_addr...
# 4  {'quantity': '10000000000000000', 'token_addre...
#
#                                          transaction  event_timestamp  \
# 0  0xd301ce6718e6b9e762c7c461b829c4e5c6f3bccd7199...       1722697211
# 1  0xf4a6e1252e9235b8ff2022ed34e1b762dbe66498f029...       1722693815
# 2  0x4e2d7a310ce5cbde53c06ac8e600e10e1231ba37ee0e...       1722691055
# 3  0x6939e3b81520e08706a028998ea9771f9d90a95f0f4b...       1722678503
# 4  0x74f5a3db5dda9b05905bb760a680ec4c635b92155527...       1722674255
#
#                                       nft_identifier        nft_name  \
# 0 86,349,095,476,171,416,204,496,000,643,597,425,...       ghaut.eth
# 1 71,552,007,753,732,387,614,282,500,469,513,396,...    ltaliano.eth
# 2 36,910,400,166,190,457,351,422,022,548,683,801,...      9797th.eth
# 3 80,665,790,946,324,601,651,199,810,530,833,638,...       joule.eth
# 4 101,676,255,068,068,542,704,731,039,737,725,146...  domainbank.eth
#
#                token_amt_raw token_symbol  token_decimals  \
# 0   2,455,000,000,000,000.00          ETH              18
# 1   7,000,000,000,000,000.00          ETH              18
# 2   2,000,000,000,000,000.00          ETH              18
# 3 550,000,000,000,000,000.00         WETH              18
# 4  10,000,000,000,000,000.00          ETH              18
#
#                         dt  token_amt_clean
# 0  2024-08-03T15:00:11.000             0.00
# 1  2024-08-03T14:03:35.000             0.01
# 2  2024-08-03T13:17:35.000             0.00
# 3  2024-08-03T09:48:23.000             0.55
# 4  2024-08-03T08:37:35.000             0.01
#
# Tail:
#       event_type order_hash     chain protocol_address  closing_date  \
# 41151       sale             ethereum                     1686547067
# 41152       sale             ethereum                     1686547067
# 41153       sale             ethereum                     1686547067
# 41154       sale             ethereum                     1686547067
# 41155       sale             ethereum                     1686547067
#
#                                                      nft  quantity  \
# 41151  {'identifier': '264335206260943651965296857543...         1
# 41152  {'identifier': '692490234501923176990969428043...         1
# 41153  {'identifier': '905908885627078610502014404334...         1
# 41154  {'identifier': '965312973343251955114837218570...         1
# 41155  {'identifier': '528239995736602405326750964692...         1
#
#                                            seller  \
# 41151  0xba724e65e81d66ffa085222332485211e77efa7b
# 41152  0xba724e65e81d66ffa085222332485211e77efa7b
# 41153  0xba724e65e81d66ffa085222332485211e77efa7b
# 41154  0xba724e65e81d66ffa085222332485211e77efa7b
# 41155  0xba724e65e81d66ffa085222332485211e77efa7b
#
#                                             buyer  \
# 41151  0xc444d559305be9788f64a2c2b28430edf3cc17fe
# 41152  0xc444d559305be9788f64a2c2b28430edf3cc17fe
# 41153  0xc444d559305be9788f64a2c2b28430edf3cc17fe
# 41154  0xc444d559305be9788f64a2c2b28430edf3cc17fe
# 41155  0xc444d559305be9788f64a2c2b28430edf3cc17fe
#
#                                                  payment  \
# 41151  {'quantity': '9500000000000001', 'token_addres...
# 41152  {'quantity': '9500000000000001', 'token_addres...
# 41153  {'quantity': '9500000000000001', 'token_addres...
# 41154  {'quantity': '9500000000000001', 'token_addres...
# 41155  {'quantity': '9500000000000001', 'token_addres...
#
#                                              transaction  event_timestamp  \
# 41151  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
# 41152  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
# 41153  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
# 41154  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
# 41155  0xf796a351d86564271846de82f29257c6142de5483e1d...       1686547067
#
#                                           nft_identifier   nft_name  \
# 41151 26,433,520,626,094,364,145,687,966,688,793,167,...  82337.eth
# 41152 69,249,023,450,192,320,286,030,058,028,418,970,...  60983.eth
# 41153 90,590,888,562,707,863,584,023,800,423,822,006,...  22967.eth
# 41154 96,531,297,334,325,189,994,337,204,354,020,381,...  55287.eth
# 41155 52,823,999,573,660,241,687,521,878,105,091,111,...  68773.eth
#
#                  token_amt_raw token_symbol  token_decimals  \
# 41151 9,500,000,000,000,000.00          ETH              18
# 41152 9,500,000,000,000,000.00          ETH              18
# 41153 9,500,000,000,000,000.00          ETH              18
# 41154 9,500,000,000,000,000.00          ETH              18
# 41155 9,500,000,000,000,000.00          ETH              18
#
#                             dt  token_amt_clean
# 41151  2023-06-12T05:17:47.000             0.01
# 41152  2023-06-12T05:17:47.000             0.01
# 41153  2023-06-12T05:17:47.000             0.01
# 41154  2023-06-12T05:17:47.000             0.01
# 41155  2023-06-12T05:17:47.000             0.01
#
# ========================================
#
# --- optimistic_domains ---
# Head:
#    tokenId              name
# 0        0        vitalik.op
# 1        1       cardenas.op
# 2        2  davidcardenas.op
# 3        3        bitcoin.op
# 4        4          daffy.op
#
# Tail:
#       tokenId       name
# 1321     1321  agency.op
# 1322     1322   trump.op
# 1323     1323    send.op
# 1324     1324    mint.op
# 1325     1325    lock.op
#
# ========================================
#
# --- Three_DNS_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0xa9e856a5258931c57071cf787ab88dc425d542eb617c...  optimism
# 1       sale  0x475d0b58dbbc6e861b1e0df67be0e9eae0d623459d1b...  optimism
# 2       sale  0xc292285285639ab3f4dc95d2fd965a62fc1f94388f4a...  optimism
# 3       sale  0x2cc8de6755a7f9ef0b0a2252c7064896dde56b74e150...  optimism
# 4       sale  0xe49e38d70d15a87977a194ced8dfd395d724aff2ee07...  optimism
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1722706445
# 1  0x0000000000000068f116a894984e2db1123eb395    1722705143
# 2  0x0000000000000068f116a894984e2db1123eb395    1722705143
# 3  0x0000000000000068f116a894984e2db1123eb395    1722705143
# 4  0x0000000000000068f116a894984e2db1123eb395    1722705143
#
#                                                  nft  quantity  \
# 0  {'identifier': '103630415007535906696789966598...         1
# 1  {'identifier': '639074560259187791163341248616...         1
# 2  {'identifier': '704945072107423982885731232559...         1
# 3  {'identifier': '102076623466713499022234692002...         1
# 4  {'identifier': '118122428161922898295278368225...         1
#
#                                        seller  \
# 0  0x3f1c0ea76342cc3427962452891f8de8649a301b
# 1  0x72597de06e58ad98c6f66c6cd8fab1dd9f73a2ca
# 2  0x3e0783b65e967c6c702344d21855cb0813c24721
# 3  0x64b561dd2ee540e8f99ee29b614b43235bb868fe
# 4  0x2888eecd915fbb6be65dac1d51cd48a340e3ab1f
#
#                                         buyer  \
# 0  0x0123456789070ce8f0d6bab722103d12674bc257
# 1  0xce462546297fa07a11eca7f1a3a5a36df8925cf7
# 2  0xce462546297fa07a11eca7f1a3a5a36df8925cf7
# 3  0xce462546297fa07a11eca7f1a3a5a36df8925cf7
# 4  0xce462546297fa07a11eca7f1a3a5a36df8925cf7
#
#                                              payment  \
# 0  {'quantity': '120000000000000000', 'token_addr...
# 1  {'quantity': '280000000000000', 'token_address...
# 2  {'quantity': '290000000000000', 'token_address...
# 3  {'quantity': '300000000000000', 'token_address...
# 4  {'quantity': '450000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0x640e67bd79a430a2229b2596ae243693700e81dd20d1...       1722706445
# 1  0x2e14caceffd934cb6d75e255111b4ac207b166357c29...       1722705143
# 2  0x2e14caceffd934cb6d75e255111b4ac207b166357c29...       1722705143
# 3  0x2e14caceffd934cb6d75e255111b4ac207b166357c29...       1722705143
# 4  0x2e14caceffd934cb6d75e255111b4ac207b166357c29...       1722705143
#
#                                       nft_identifier  \
# 0 103,630,415,007,535,905,091,168,346,033,468,857...
# 1 63,907,456,025,918,784,550,431,386,390,280,815,...
# 2 70,494,507,210,742,404,178,780,831,369,986,847,...
# 3 102,076,623,466,713,504,937,515,277,532,453,510...
# 4 11,812,242,816,192,290,227,614,680,555,896,161,...
#
#                    nft_name              token_amt_raw token_symbol  \
# 0                    03.box 120,000,000,000,000,000.00         WETH
# 1            flon.chain.box     280,000,000,000,000.00          ETH
# 2             eua.chain.box     290,000,000,000,000.00          ETH
# 3  investecriptos.chain.box     300,000,000,000,000.00          ETH
# 4    drivenspyder.chain.box     450,000,000,000,000.00          ETH
#
#    token_decimals             dt  token_amt_clean
# 0              18  1722706445000             0.12
# 1              18  1722705143000             0.00
# 2              18  1722705143000             0.00
# 3              18  1722705143000             0.00
# 4              18  1722705143000             0.00
#
# Tail:
#     event_type                                         order_hash     chain  \
# 153       sale  0x8bde44f2d46537cf8d025cc498eaf7bdeadce3631f15...  optimism
# 154       sale  0xc0547b5b8d575e3ba16b529ee2530a35c437bc75fa93...  optimism
# 155       sale  0xff4b9bdd3f140f8211864ef34e0a07ea0a92eaf98f7d...  optimism
# 156       sale  0x03188e15aaf9596307117e30355f6b2ac79665fbd1c2...  optimism
# 157       sale  0x3cd7cfda4dd935529af2c4f882476b40cc37340ae2a6...  optimism
#
#                                protocol_address  closing_date  \
# 153  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706970257
# 154  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706653465
# 155  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706203283
# 156  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1704080589
# 157  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1703624873
#
#                                                    nft  quantity  \
# 153  {'identifier': '260923785748676206958654735781...         1
# 154  {'identifier': '566479911085778512201556021651...         1
# 155  {'identifier': '364706086468987072255605061503...         1
# 156  {'identifier': '992340878683635895851755157396...         1
# 157  {'identifier': '686186082504474765846111255346...         1
#
#                                          seller  \
# 153  0xcc0e0b9ebd4ce352f5a50b3ae77ea01202c284ee
# 154  0x240ad467a71210629d71d4de22ebde27951c83fc
# 155  0x7b363822d744143d51c69b0757165c987a6e4ef4
# 156  0x31b32020fb1bdf0228c58b80590f07b235f2b0ce
# 157  0xff3d39f7766ebb57a4175b6d919937409f6d6fee
#
#                                           buyer  \
# 153  0xc48a8ac51df7b71e500a5580b89e47ab26ca1472
# 154  0x82eb45562f991329ed2867f43fc60f0ba52c3dab
# 155  0xe68e8cc7ff772b026c062b9cc28246676d044947
# 156  0x64233eaa064ef0d54ff1a963933d0d2d46ab5829
# 157  0x46f09888867c8cd9042b943099663e856e43de46
#
#                                                payment  \
# 153  {'quantity': '1000000000000000', 'token_addres...
# 154  {'quantity': '110000000000000000', 'token_addr...
# 155  {'quantity': '10000000000000000', 'token_addre...
# 156  {'quantity': '150000000000000000', 'token_addr...
# 157  {'quantity': '22000000000000000', 'token_addre...
#
#                                            transaction  event_timestamp  \
# 153  0x60e952a8e0fa8d052791b2e4a22fd52eb3c759511e62...       1706970257
# 154  0x6672189deb7829838aabba20ddeb66a3cb5fee5b55a2...       1706653465
# 155  0xd8e71f4d52c43fa770b9aa7ad7d5cfb073f04c7495e0...       1706203283
# 156  0x186d1ceacf620bab710d11cf928b79e5dd46790ff1d5...       1704080589
# 157  0x1c7ed62756b60a73470fa39ea6546510ad426e261d14...       1703624873
#
#                                         nft_identifier            nft_name  \
# 153 26,092,378,574,867,619,527,232,167,678,805,405,...             696.box
# 154 56,647,991,108,577,850,953,984,972,492,538,466,...         opensea.box
# 155 36,470,608,646,898,707,880,068,503,761,534,760,...           08000.xyz
# 156 99,234,087,868,363,590,418,701,991,799,513,400,...        2024.finance
# 157 68,618,608,250,447,471,069,153,845,880,935,638,...  topdomains.finance
#
#                  token_amt_raw token_symbol  token_decimals             dt  \
# 153   1,000,000,000,000,000.00         WETH              18  1706970257000
# 154 110,000,000,000,000,000.00         WETH              18  1706653465000
# 155  10,000,000,000,000,000.00          ETH              18  1706203283000
# 156 150,000,000,000,000,000.00          ETH              18  1704080589000
# 157  22,000,000,000,000,000.00          ETH              18  1703624873000
#
#      token_amt_clean
# 153             0.00
# 154             0.11
# 155             0.01
# 156             0.15
# 157             0.02
#
# ========================================
#
# --- base_domains_metadata_pd ---
# Head:
#   event_type                                         order_hash chain  \
# 0       sale                                                     base
# 1       sale                                                     base
# 2       sale  0x945d37a0e222fc4b276bdb2128f8a9bbfbebd10efbbb...  base
# 3       sale  0xf252233595c8e5ed9537fda860278acefa19a8db542d...  base
# 4       sale  0xb2abcf6e7e0c0118c8999cfbfe93b226b8e068d81fe3...  base
#
#                              protocol_address  closing_date  \
# 0                                                1719530881
# 1                                                1719530857
# 2  0x0000000000000068f116a894984e2db1123eb395    1719112413
# 3  0x0000000000000068f116a894984e2db1123eb395    1719110431
# 4  0x0000000000000068f116a894984e2db1123eb395    1719108841
#
#                                                  nft  quantity  \
# 0  {'identifier': '6625', 'collection': 'basedoma...         1
# 1  {'identifier': '6707', 'collection': 'basedoma...         1
# 2  {'identifier': '4863', 'collection': 'basedoma...         1
# 3  {'identifier': '19245', 'collection': 'basedom...         1
# 4  {'identifier': '9711', 'collection': 'basedoma...         1
#
#                                        seller  \
# 0  0x8afefd4a26c46b48dbaed293f78a6cf5e72093be
# 1  0x8afefd4a26c46b48dbaed293f78a6cf5e72093be
# 2  0x0d24ddea6ceefaa45e4d577ce07b840320097586
# 3  0xc2e3d9f054a494b228d44b78781eb03ca6e05c35
# 4  0x1458cb4003eb115bf3e19497016009a69db35982
#
#                                         buyer  \
# 0  0xc2e3d9f054a494b228d44b78781eb03ca6e05c35
# 1  0xc2e3d9f054a494b228d44b78781eb03ca6e05c35
# 2  0x20a27618cdb1ae314b5852249c4fa09447c90bdb
# 3  0xb509c39166a690f73d152051ec8076b7ee4de900
# 4  0x147b72fd2e1fb3b7e478b4ad6e3ecc11236a8973
#
#                                              payment  \
# 0  {'quantity': '10000000000000', 'token_address'...
# 1  {'quantity': '10000000000000', 'token_address'...
# 2  {'quantity': '544900000000000', 'token_address...
# 3  {'quantity': '544900000000000', 'token_address...
# 4  {'quantity': '488000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0x361fefcb858f70d5718985628159bdd6a41aa7beb1b7...       1719530881
# 1  0x4d76726610008f8d5f98ba5ec8c7430dc9ae6f97b7d3...       1719530857
# 2  0x5c5ae2b392f25822bcce3c166334ab978d2f066eb002...       1719112413
# 3  0x1009bae51041cc0f0f88b0e5b613359801287fa6e67c...       1719110431
# 4  0x365f6f2308037def5f7fa98410409a8d94aed08a07c8...       1719108841
#
#    nft_identifier          nft_name    token_amt_raw token_symbol  \
# 0            6625  Vizzycrypto.base   10000000000000          ETH
# 1            6707      Cryptox.base   10000000000000          ETH
# 2            4863        38888.base  544900000000000          ETH
# 3           19245       venice.base  544900000000000          ETH
# 4            9711        13333.base  488000000000000          ETH
#
#    token_decimals             dt  token_amt_clean
# 0              18  1719530881000             0.00
# 1              18  1719530857000             0.00
# 2              18  1719112413000             0.00
# 3              18  1719110431000             0.00
# 4              18  1719108841000             0.00
#
# Tail:
#    event_type                                         order_hash chain  \
# 91       sale  0x179558a1e2b1588b041e77960b7c415339db8d055f29...  base
# 92       sale  0x3b6a002b6daf8e3218cf5d8d858d482c4076d88d3fcc...  base
# 93       sale  0x6a9be1bc39c943a96d0f7c7afce10082d4f295f0adfa...  base
# 94       sale  0xb4693b06b1c088276aaff2c83e8b736272fad0e1bd19...  base
# 95       sale  0xb7b5e18955103fa4ca87d37d44c18362867a6b3fbca4...  base
#
#                               protocol_address  closing_date  \
# 91  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691618587
# 92  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691616539
# 93  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691613043
# 94  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691607621
# 95  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691598979
#
#                                                   nft  quantity  \
# 91  {'identifier': '3505', 'collection': 'basedoma...         1
# 92  {'identifier': '2704', 'collection': 'basedoma...         1
# 93  {'identifier': '4695', 'collection': 'basedoma...         1
# 94  {'identifier': '3204', 'collection': 'basedoma...         1
# 95  {'identifier': '6435', 'collection': 'basedoma...         1
#
#                                         seller  \
# 91  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 92  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 93  0x269f77497956ef4aa79962b54bc715ee62b4c684
# 94  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 95  0x280ad8a544ca166f4ec2ddc4458aeb194d53e3fb
#
#                                          buyer  \
# 91  0xa2bae9e9fc3af9dc136db6d06be07c7f2e71b5bc
# 92  0x1deacf16b32bd686bea74cff7c382f675c3aa7c1
# 93  0x208e184f3186bc19b1c49a3cae8cbff3142d6e91
# 94  0x570866568da48898755268239c27e34afa575226
# 95  0x96fd61202a698ee3eac21e247a6b209ea5ffeb91
#
#                                               payment  \
# 91  {'quantity': '11000000000000000', 'token_addre...
# 92  {'quantity': '11000000000000000', 'token_addre...
# 93  {'quantity': '2500000000000000', 'token_addres...
# 94  {'quantity': '3500000000000000', 'token_addres...
# 95  {'quantity': '7300000000000000', 'token_addres...
#
#                                           transaction  event_timestamp  \
# 91  0x3064100ce1ab4419c19324f7d83e5b42ab6603e96b15...       1691618587
# 92  0x18e2ed5f6ee64211f19e887197fe104c78becff9dbb6...       1691616539
# 93  0x45819e6cea811e2b858b8dc938cf234e69d24f7b84e6...       1691613043
# 94  0xb5cd43a2d7fb7b4e9acebdc727190c079204c1d23529...       1691607621
# 95  0x2a2ce146c08f0424b8a82448abe1308ff3a9c8ceb9e6...       1691598979
#
#     nft_identifier      nft_name      token_amt_raw token_symbol  \
# 91            3505      rug.base  11000000000000000          ETH
# 92            2704      200.base  11000000000000000          ETH
# 93            4695    manga.base   2500000000000000          ETH
# 94            3204  bullish.base   3500000000000000          ETH
# 95            6435    Clock.base   7300000000000000          ETH
#
#     token_decimals             dt  token_amt_clean
# 91              18  1691618587000             0.01
# 92              18  1691616539000             0.01
# 93              18  1691613043000             0.00
# 94              18  1691607621000             0.00
# 95              18  1691598979000             0.01
#
# ========================================
#
# --- unstoppable_sales_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0xb03f2e78925cde538c10e5fad3bcc6b4e655ae51e003...  ethereum
# 1       sale  0x088e924cb0ef441b0d68821764db063467c572e8f9a1...  ethereum
# 2       sale  0xceb738fa285cf4de22c16c5c676ba026e5ffe84c73b7...  ethereum
# 3       sale  0x1064f829ae8be80b5ad31a1271cdeae52d7e3a44f474...  ethereum
# 4       sale  0xa30969fb217ac7c58101213ac2104bd6598db75d7c5d...  ethereum
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1720198883
# 1  0x0000000000000068f116a894984e2db1123eb395    1718617967
# 2  0x0000000000000068f116a894984e2db1123eb395    1718614055
# 3  0x0000000000000068f116a894984e2db1123eb395    1718613323
# 4  0x0000000000000068f116a894984e2db1123eb395    1718550443
#
#                                                  nft  quantity  \
# 0  {'identifier': '732609744346663118421256248151...         1
# 1  {'identifier': '799288950834081445126736498481...         1
# 2  {'identifier': '720141416088167626284738564926...         1
# 3  {'identifier': '559353050680242471594511596608...         1
# 4  {'identifier': '911899529139068149563600522019...         1
#
#                                        seller  \
# 0  0xd5b43c1d9c145bdf25c163ecf8fa1fe040202adc
# 1  0xcbb58904774cf1bee98741c466aace0206fb090b
# 2  0xcbb58904774cf1bee98741c466aace0206fb090b
# 3  0xcbb58904774cf1bee98741c466aace0206fb090b
# 4  0xcbb58904774cf1bee98741c466aace0206fb090b
#
#                                         buyer  \
# 0  0x84eb2355fc7556e07bbc410be55063bc3b61a006
# 1  0xb54e5bd4a9d9f2a7721136041ba41db77cd90e9a
# 2  0x0a3b0a790ca4f9fbaa2618c548cde45be0249c2f
# 3  0x8be28746913422eef1e255df992b32c702576bdc
# 4  0xeb11c3f006b1fe207f8ec1a153e480db86c3ce4f
#
#                                              payment  \
# 0  {'quantity': '50000000000000', 'token_address'...
# 1  {'quantity': '990000000000000', 'token_address...
# 2  {'quantity': '990000000000000', 'token_address...
# 3  {'quantity': '990000000000000', 'token_address...
# 4  {'quantity': '890000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0xdb0a0ef3662b0975e886b41bf984f03f387ab6edcfa2...       1720198883
# 1  0x6d26ae182bb40d6dd4a7378609061cb046103bd30853...       1718617967
# 2  0x447d7ccb8ccb6eeb7d4dfbb6e838e918639172ac66a9...       1718614055
# 3  0x22369eee55b5313147708ada54f6276be250850f8f7a...       1718613323
# 4  0x25db8dd631e2901f0020dee0f8d826dd1b7f2c22f8b5...       1718550443
#
#                                       nft_identifier  \
# 0 73,260,974,434,666,309,016,726,815,552,216,794,...
# 1 79,928,895,083,408,148,097,614,756,880,763,030,...
# 2 72,014,141,608,816,767,035,628,981,280,910,821,...
# 3 55,935,305,068,024,247,420,483,647,586,810,650,...
# 4 91,189,952,913,906,813,838,813,506,742,274,520,...
#
#                    nft_name          token_amt_raw token_symbol  \
# 0           gaydream.crypto  50,000,000,000,000.00          ETH
# 1    officialdaimler.crypto 990,000,000,000,000.00          ETH
# 2       officialaudi.crypto 990,000,000,000,000.00          ETH
# 3  officialbillgates.crypto 990,000,000,000,000.00          ETH
# 4         scaryterry.crypto 890,000,000,000,000.00          ETH
#
#    token_decimals                       dt  token_amt_clean
# 0              18  2024-07-05T17:01:23.000             0.00
# 1              18  2024-06-17T09:52:47.000             0.00
# 2              18  2024-06-17T08:47:35.000             0.00
# 3              18  2024-06-17T08:35:23.000             0.00
# 4              18  2024-06-16T15:07:23.000             0.00
#
# Tail:
#      event_type order_hash     chain  \
# 3896       sale             ethereum
# 3897       sale             ethereum
# 3898       sale             ethereum
# 3899       sale             ethereum
# 3900       sale             ethereum
#
#                                 protocol_address  closing_date  \
# 3896  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1577178632
# 3897  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1577178582
# 3898  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576900527
# 3899  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576768395
# 3900  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576313422
#
#                                                     nft  quantity  \
# 3896  {'identifier': '860899055054694856908010487707...         1
# 3897  {'identifier': '940569713444058262943635252235...         1
# 3898  {'identifier': '446163175071435156510839745607...         1
# 3899  {'identifier': '176192171829730767798338643850...         1
# 3900  {'identifier': '164502264543840507301076043053...         1
#
#                                           seller  \
# 3896  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3897  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3898  0x8124b02b4967bd7338a450420a572d574915ff9c
# 3899  0xfa4ab967d3ac0b94955b8df63ede213695f38d6f
# 3900  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
#
#                                            buyer  \
# 3896  0x525e89c4d5052d5afb5a7f0884b296b0138adfd4
# 3897  0x525e89c4d5052d5afb5a7f0884b296b0138adfd4
# 3898  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3899  0x8124b02b4967bd7338a450420a572d574915ff9c
# 3900  0x519e570344747173c5febde6c2df0c3252175bb3
#
#                                                 payment  \
# 3896  {'quantity': '100000000000000000', 'token_addr...
# 3897  {'quantity': '100000000000000000', 'token_addr...
# 3898  {'quantity': '45000000000000000', 'token_addre...
# 3899  {'quantity': '70000000000000000', 'token_addre...
# 3900  {'quantity': '69900000000000000', 'token_addre...
#
#                                             transaction  event_timestamp  \
# 3896  0xa0349c718c1f794d51d1ba664ee238f2d61dac847e5c...       1577178632
# 3897  0x6f83aa5c2d5377fa88d770d6b6709922fe79d16eb2c5...       1577178582
# 3898  0x068264028eac1e60c0bfc6dac93d65165edaaad19ea6...       1576900527
# 3899  0x0994ef978059265afb7b8c6deb0ac6afe4d6f31b25ba...       1576768395
# 3900  0x60b8773e82dd9f9612f687c925062aa2bc4e2cf8c86f...       1576313422
#
#                                          nft_identifier          nft_name  \
# 3896 86,089,905,505,469,488,148,445,830,396,242,062,...    bittiez.crypto
# 3897 94,056,971,344,405,822,053,661,343,907,032,761,...    bitties.crypto
# 3898 44,616,317,507,143,517,844,109,711,444,778,473,...  impeached.crypto
# 3899 17,619,217,182,973,076,162,112,808,839,711,553,...  ethstaker.crypto
# 3900 16,450,226,454,384,049,539,296,233,940,056,623,...    cryptoq.crypto
#
#                   token_amt_raw token_symbol  token_decimals  \
# 3896 100,000,000,000,000,000.00         WETH              18
# 3897 100,000,000,000,000,000.00         WETH              18
# 3898  45,000,000,000,000,000.00         WETH              18
# 3899  70,000,000,000,000,000.00          ETH              18
# 3900  69,900,000,000,000,000.00          ETH              18
#
#                            dt  token_amt_clean
# 3896  2019-12-24T09:10:32.000             0.10
# 3897  2019-12-24T09:09:42.000             0.10
# 3898  2019-12-21T03:55:27.000             0.04
# 3899  2019-12-19T15:13:15.000             0.07
# 3900  2019-12-14T08:50:22.000             0.07
#
# ========================================
#
# --- optimistic_domains_sales ---
# Head:
#                        DAY  TOKENID  PRICE  PRICE_USD
# 0  2022-07-28 16:00:00.000   850.00   0.01       8.27
# 1  2022-07-13 06:00:00.000   902.00   0.02      21.05
# 2  2022-07-13 06:00:00.000   915.00   0.03      26.31
# 3  2022-08-04 20:00:00.000   933.00   0.01      22.76
# 4  2022-08-04 20:00:00.000   932.00   0.01      21.43
#
# Tail:
#                         DAY  TOKENID  PRICE  PRICE_USD
# 13  2023-02-20 21:00:00.000   413.00   0.03      46.02
# 14  2023-02-20 21:00:00.000 1,076.00   0.05      85.22
# 15  2022-06-06 14:00:00.000   576.00   0.05      95.46
# 16  2022-10-13 10:00:00.000   413.00  11.00       7.53
# 17                        ﻿      NaN    NaN        NaN
#
# ========================================
#
# --- optimism_name_service_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0x9370590b86b641bc94a2be25aca2b15531a19325191f...  optimism
# 1       sale  0x18ea42e4de0d824598c95f5612ba0bca41bc73d8d4a2...  optimism
# 2       sale  0xa90655cad3a8fcb26609bafe5cc3d83d709c2fb48ccb...  optimism
# 3       sale  0x23170df056ba214c65aec2b300595a3c8cbae7c864dc...  optimism
# 4       sale  0x78be0458f50d3d89ad3206cb82ce38119c8df530c08b...  optimism
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1717118919
# 1  0x0000000000000068f116a894984e2db1123eb395    1715204651
# 2  0x0000000000000068f116a894984e2db1123eb395    1711976895
# 3  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1710975355
# 4  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1710017397
#
#                                                  nft  quantity  \
# 0  {'identifier': '986055613691005048366660295505...         1
# 1  {'identifier': '549978610354346671082331131741...         1
# 2  {'identifier': '397548654027272243885589702261...         1
# 3  {'identifier': '548782968751199257669238317507...         1
# 4  {'identifier': '525166297008421355185137086623...         1
#
#                                        seller  \
# 0  0x670b244e4bc0667224c603cf2ab1dace411fdbb5
# 1  0x9bac53cbfbb8c52f22e7e278c63ec7c4abf0593e
# 2  0x670b244e4bc0667224c603cf2ab1dace411fdbb5
# 3  0x1960a7b4993a3e85cad2f3e765111065ca3b3743
# 4  0x3352640be5c1c26d0e0f36e1cc3847ade4d79806
#
#                                         buyer  \
# 0  0xc7c72e53c78447041c4728aac33f286fa532ca4c
# 1  0x450aeab30443a3ad15750ddb3c8636717e9c048a
# 2  0x4b9cf9153935e17000d896e78f4230ecd3d9d997
# 3  0xd06d855652a73e61bfe26a3427dfe51f3b827fe3
# 4  0xf408bee3443d0397e2c1cde588fb060ac657006f
#
#                                              payment  \
# 0  {'quantity': '700000000000000', 'token_address...
# 1  {'quantity': '600000000000000', 'token_address...
# 2  {'quantity': '700000000000000', 'token_address...
# 3  {'quantity': '700000000000000', 'token_address...
# 4  {'quantity': '700000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0x57ce323344bedf790dd7bd93ae7c351e8f1989be316c...       1717118919
# 1  0xee6fd38e4e341eefc2382161bbd9b44d27dee994060d...       1715204651
# 2  0xc78f61b77433609c82e04aa4a5ced1247081505ddb5d...       1711976895
# 3  0x27a00b506cf28bb145830b479ddbcef675848da4b00e...       1710975355
# 4  0xe08912c1109dd694128de39871a113217c8c2cc99735...       1710017397
#
#                                       nft_identifier     nft_name  \
# 0 98,605,561,369,100,498,602,024,245,469,838,703,...    zainal.op
# 1 5,499,786,103,543,466,330,119,275,902,716,700,8...     oksie.op
# 2 39,754,865,402,727,223,184,320,167,547,016,687,...    ahamad.op
# 3 5,487,829,687,511,992,584,552,359,460,892,473,9...  squanchy.op
# 4 52,516,629,700,842,134,031,927,131,776,612,298,...    azukii.op
#
#      token_amt_raw token_symbol  token_decimals             dt  \
# 0  700000000000000          ETH              18  1717118919000
# 1  600000000000000          ETH              18  1715204651000
# 2  700000000000000          ETH              18  1711976895000
# 3  700000000000000          ETH              18  1710975355000
# 4  700000000000000          ETH              18  1710017397000
#
#    token_amt_clean
# 0             0.00
# 1             0.00
# 2             0.00
# 3             0.00
# 4             0.00
#
# Tail:
#     event_type                                         order_hash     chain  \
# 728       sale  0x0da4f090909f31862f79a4e76a396766a7fe3e3d8637...  optimism
# 729       sale  0x07f366c8693d6492b394ce78aa1e580a230b6e282d36...  optimism
# 730       sale  0x029b6a83792ed956bff1318490196524c8de7b5d5d74...  optimism
# 731       sale  0x621db398cdef6e0b0737ba21715d07b42927ad838ea4...  optimism
# 732       sale  0xbb5d4c44682316fee95d1dd37d302982ec32f626b5c7...  optimism
#
#                                protocol_address  closing_date  \
# 728  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932343
# 729  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 730  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 731  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 732  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677921991
#
#                                                    nft  quantity  \
# 728  {'identifier': '120219272988803680872974995977...         1
# 729  {'identifier': '212128970836456136940270979598...         1
# 730  {'identifier': '248444384559923954980940474589...         1
# 731  {'identifier': '549015022443570801134689433390...         1
# 732  {'identifier': '488099369330375128690249371270...         1
#
#                                          seller  \
# 728  0xaf6d4f2f0f4d08b34182234d6c39865b56ab5b4c
# 729  0x50921467fd9defc962af2636b36867d423244ff8
# 730  0x50921467fd9defc962af2636b36867d423244ff8
# 731  0x50921467fd9defc962af2636b36867d423244ff8
# 732  0xa2bc5e3be3d883879caf9a9f2a610584506fc6dd
#
#                                           buyer  \
# 728  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 729  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 730  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 731  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 732  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
#
#                                                payment  \
# 728  {'quantity': '2500000000000000', 'token_addres...
# 729  {'quantity': '50000000000000000', 'token_addre...
# 730  {'quantity': '50000000000000000', 'token_addre...
# 731  {'quantity': '50000000000000000', 'token_addre...
# 732  {'quantity': '100000000000000000', 'token_addr...
#
#                                            transaction  event_timestamp  \
# 728  0xdaff73e094af54678a23e9a419d4d7fb53ce76d443e3...       1677932343
# 729  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 730  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 731  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 732  0xf1c8349d99024e6792525239b4cd655d219957433ec9...       1677921991
#
#                                         nft_identifier       nft_name  \
# 728 12,021,927,298,880,368,312,276,012,569,694,239,...      888666.op
# 729 21,212,897,083,645,615,095,268,562,890,835,548,...  highstreet.op
# 730 24,844,438,455,992,396,859,894,623,792,547,027,...      bitget.op
# 731 54,901,502,244,357,081,727,363,511,107,096,227,...       bybit.op
# 732 48,809,936,933,037,512,706,059,515,308,167,888,...       abcde.op
#
#           token_amt_raw token_symbol  token_decimals             dt  \
# 728    2500000000000000          ETH              18  1677932343000
# 729   50000000000000000          ETH              18  1677932205000
# 730   50000000000000000          ETH              18  1677932205000
# 731   50000000000000000          ETH              18  1677932205000
# 732  100000000000000000          ETH              18  1677921991000
#
#      token_amt_clean
# 728             0.00
# 729             0.05
# 730             0.05
# 731             0.05
# 732             0.10
#
# ========================================
#
# --- prices_data ---
# Head:
#                         DT SYMBOL    PRICE
# 0  2024-08-03 18:00:00.000   WETH 2,933.84
# 1  2024-08-03 18:00:00.000  MATIC     0.46
# 2  2024-08-03 17:00:00.000   WETH 2,952.17
# 3  2024-08-03 17:00:00.000  MATIC     0.46
# 4  2024-08-03 16:00:00.000  MATIC     0.47
#
# Tail:
#                              DT SYMBOL  PRICE
# 99996   2018-06-16 08:00:00.000   WETH 494.07
# 99997   2018-06-16 07:00:00.000   WETH 492.07
# 99998   2018-06-16 06:00:00.000   WETH 490.08
# 99999   2018-06-16 05:00:00.000   WETH 489.49
# 100000                        ﻿    NaN    NaN
#
# ========================================
# e:\Projects\liquid_domains\scripts\data_processing.py:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices_data['SYMBOL'] = prices_data['SYMBOL'].replace('WETH', 'ETH')
# e:\Projects\liquid_domains\scripts\data_processing.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optimistic_domains_sales['TOKENID'] = optimistic_domains_sales['TOKENID'].astype(int)
# e:\Projects\liquid_domains\scripts\data_processing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optimistic_domains_sales.rename(columns={"TOKENID":"tokenId"}, inplace=True)
# e:\Projects\liquid_domains\scripts\data_processing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optimism_name_service_data['dt'] = pd.to_datetime(optimism_name_service_data['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Three_DNS_data['dt'] = pd.to_datetime(Three_DNS_data['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ens_data['dt'] = pd.to_datetime(ens_data['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unstoppable_sales_data['dt'] = pd.to_datetime(unstoppable_sales_data['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_domains_metadata_pd['dt'] = pd.to_datetime(base_domains_metadata_pd['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:144: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:253: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_dataset['tld_weight'] = combined_dataset['tld'].map(tld_weights).fillna(default_tld_weight)  # Default weight is 1 if tld is not in tld_weights
# threshold: None
# target corr: price_usd                      1.00
# domain_length                  0.00
# num_vowels                     0.00
# num_consonants                 0.01
# tld_weight                      NaN
# 7d_rolling_avg_price           0.38
# 30d_rolling_avg_price          0.18
# 7d_sales_volume                0.38
# 30d_sales_volume               0.18
# cumulative_rolling_avg_price   0.02
# 7d_domains_sold                0.00
# 30d_domains_sold               0.00
# 60d_domains_sold               0.00
# 90d_domains_sold               0.00
# 7d_rolling_std_dev             0.38
# 30d_rolling_std_dev            0.18
# 7d_rolling_median_price        0.00
# 30d_rolling_median_price       0.00
# cumulative_sum_sales_volume    0.01
# Name: price_usd, dtype: float64
# target corr under: Series([], Name: price_usd, dtype: float64)
# target:price_usd,
#  features:Index(['dt', 'domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld',
#        'tld_weight', '7d_rolling_avg_price', '30d_rolling_avg_price',
#        '7d_sales_volume', '30d_sales_volume', 'cumulative_rolling_avg_price',
#        '7d_domains_sold', '30d_domains_sold', '60d_domains_sold',
#        '90d_domains_sold', '7d_rolling_std_dev', '30d_rolling_std_dev',
#        '7d_rolling_median_price', '30d_rolling_median_price',
#        'cumulative_sum_sales_volume'],
#       dtype='object')
# threshold: None
# target corr: price_usd                      1.00
# domain_length                  0.00
# num_vowels                     0.00
# num_consonants                 0.01
# tld_weight                      NaN
# 7d_rolling_avg_price           0.38
# 30d_rolling_avg_price          0.18
# 7d_sales_volume                0.38
# 30d_sales_volume               0.18
# cumulative_rolling_avg_price   0.02
# 7d_domains_sold                0.00
# 30d_domains_sold               0.00
# 60d_domains_sold               0.00
# 90d_domains_sold               0.00
# 7d_rolling_std_dev             0.38
# 30d_rolling_std_dev            0.18
# 7d_rolling_median_price        0.00
# 30d_rolling_median_price       0.00
# cumulative_sum_sales_volume    0.01
# Name: price_usd, dtype: float64
# target corr under: Series([], Name: price_usd, dtype: float64)
# cols to drop: ['90d_domains_sold', '60d_domains_sold', '30d_domains_sold', '7d_domains_sold', 'cumulative_sum_sales_volume', 'cumulative_rolling_avg_price', '30d_rolling_median_price', '7d_rolling_median_price', '30d_rolling_std_dev']
# prophet to drop: ['dt', '90d_domains_sold', '60d_domains_sold', '30d_domains_sold', '7d_domains_sold', 'cumulative_sum_sales_volume', 'cumulative_rolling_avg_price', '30d_rolling_median_price', '7d_rolling_median_price', '30d_rolling_std_dev']
# features: Index(['dt', 'domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld',
#        'tld_weight', '7d_rolling_avg_price', '30d_rolling_avg_price',
#        '7d_sales_volume', '30d_sales_volume', 'cumulative_rolling_avg_price',
#        '7d_domains_sold', '30d_domains_sold', '60d_domains_sold',
#        '90d_domains_sold', '7d_rolling_std_dev', '30d_rolling_std_dev',
#        '7d_rolling_median_price', '30d_rolling_median_price',
#        'cumulative_sum_sales_volume'],
#       dtype='object')
# gen features
# prophet features
# Training on Combined Data...
# Index(['dt', 'domain', 'price_usd', 'domain_length', 'num_vowels',
#        'num_consonants', 'tld', 'tld_weight', '7d_rolling_avg_price',
#        '30d_rolling_avg_price', '7d_sales_volume', '30d_sales_volume',
#        'cumulative_rolling_avg_price', '7d_domains_sold', '30d_domains_sold',
#        '60d_domains_sold', '90d_domains_sold', '7d_rolling_std_dev',
#        '30d_rolling_std_dev', '7d_rolling_median_price',
#        '30d_rolling_median_price', 'cumulative_sum_sales_volume'],
#       dtype='object')
# 08:05:00 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:04 - cmdstanpy - INFO - Chain [1] done processing
# R²: 0.06830149091672977
# MAE: 39447.49243476476
# RMSE: 154137.75144026938
# MAE: 43620.75806523563
# MSE: 6712088393071.915
# R²: -2.3304543476543316e-05
# MAE: 43838.15502736041
# MSE: 6675760564676.68
# R²: 0.005389120453218821
# Prophet scores: {'r2': 0.06830149091672977, 'mae': np.float64(39447.49243476476), 'rmse': np.float64(154137.75144026938)}
# Ridge scores: {'r2': -2.3304543476543316e-05, 'mae': np.float64(43620.75806523563), 'mse': np.float64(6712088393071.915)}
# Random Forest scores: {'r2': 0.005389120453218821, 'mae': np.float64(43838.15502736041), 'mse': np.float64(6675760564676.68)}
# Training on web3 Data...
# Index(['dt', 'domain', 'price_usd', 'domain_length', 'num_vowels',
#        'num_consonants', 'tld', 'tld_weight', '7d_rolling_avg_price',
#        '30d_rolling_avg_price', '7d_sales_volume', '30d_sales_volume',
#        'cumulative_rolling_avg_price', '7d_domains_sold', '30d_domains_sold',
#        '60d_domains_sold', '90d_domains_sold', '7d_rolling_std_dev',
#        '30d_rolling_std_dev', '7d_rolling_median_price',
#        '30d_rolling_median_price', 'cumulative_sum_sales_volume'],
#       dtype='object')
# 08:05:40 - cmdstanpy - INFO - Chain [1] start processing
# 08:05:44 - cmdstanpy - INFO - Chain [1] done processing
# R²: 0.0713589300637496
# MAE: 38241.358271226454
# RMSE: 153884.63690527482
# MAE: 44007.81542729409
# MSE: 6713797032151.384
# R²: -3.693293826723121e-05
# MAE: 44723.06781096776
# MSE: 6670319206506.095
# R²: 0.006439198407515612
# web3 Prophet scores: {'r2': 0.0713589300637496, 'mae': np.float64(38241.358271226454), 'rmse': np.float64(153884.63690527482)}
# web3 Ridge scores: {'r2': -3.693293826723121e-05, 'mae': np.float64(44007.81542729409), 'mse': np.float64(6713797032151.384)}
# web3 Random Forest scores: {'r2': 0.006439198407515612, 'mae': np.float64(44723.06781096776), 'mse': np.float64(6670319206506.095)}
# Saving Models...

# %%
def train_ridge_model(X, y):

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='median')),
                ('scaler', StandardScaler())
            ]), ['domain_length', 'num_vowels', 'num_consonants']),
            ('cat', Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='most_frequent')),
                ('onehot', OneHotEncoder(handle_unknown='ignore'))
            ]), ['tld'])
        ]
    )

    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', Ridge(alpha=1000.0))  # Set the best alpha value from grid search
    ])

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f'MAE: {mae}')
    print(f'MSE: {mse}')
    print(f'R²: {r2}')

    return pipeline, features

# %%
def train_randomforest_model(X, y):

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='median')),
                ('scaler', StandardScaler())
            ]), ['domain_length', 'num_vowels', 'num_consonants']),
            ('cat', Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='most_frequent')),
                ('onehot', OneHotEncoder(handle_unknown='ignore'))
            ]), ['tld'])
        ]
    )

    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', RandomForestRegressor(n_estimators=200, max_depth=20, min_samples_split=5, random_state=seed))  # Set the best alpha value from grid search
    ])

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)
    pipeline.fit(X_train, y_train)
    y_pred = pipeline.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f'MAE: {mae}')
    print(f'MSE: {mse}')
    print(f'R²: {r2}')

    return pipeline, features

# %%
def train_randomforest_model_with_gridsearch(X, y, seed=seed):

    # Define preprocessor
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='median')),
                ('scaler', StandardScaler())
            ]), ['domain_length', 'num_vowels', 'num_consonants']),
            ('cat', Pipeline(steps=[
                ('imputer', SimpleImputer(strategy='most_frequent')),
                ('onehot', OneHotEncoder(handle_unknown='ignore'))
            ]), ['tld'])
        ]
    )

    # Define the full pipeline
    pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('regressor', RandomForestRegressor(random_state=seed))  # RF with default params for now
    ])

    # Define parameter grid for the RandomForestRegressor
    param_grid = {
        'regressor__n_estimators': [100, 200, 300],
        'regressor__max_depth': [10, 20, 30],
        'regressor__min_samples_split': [2, 5, 10],
        'regressor__min_samples_leaf': [1, 2, 4],
    }

    # Set up the GridSearchCV
    grid_search = GridSearchCV(
        pipeline,
        param_grid,
        cv=5,  # 5-fold cross-validation
        scoring='neg_mean_absolute_error',  # Use MAE as the scoring metric
        n_jobs=-1,  # Use all processors
        verbose=2  # Show detailed log
    )

    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

    # Fit the model using GridSearchCV
    grid_search.fit(X_train, y_train)

    # Get the best parameters
    print(f"Best Parameters: {grid_search.best_params_}")

    # Evaluate the best model on the test data
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f'MAE: {mae}')
    print(f'MSE: {mse}')
    print(f'R²: {r2}')

    return best_model, grid_search.best_params_

# %%
def train_prophet_model(features):
    df_prophet = combined_dataset.copy()
    print(df_prophet.columns)
    df_prophet.rename(columns={"dt": "ds", "price_usd": "y"}, inplace=True)    
    df_prophet['ds'] = df_prophet['ds'].dt.tz_localize(None)

    target = 'y'
    features = df_prophet[features].select_dtypes(include=[np.number]).columns

    train_df, test_df = train_test_split(df_prophet, test_size=0.2, shuffle=False, random_state=seed)

    model = Prophet()

    for feature in features:
        model.add_regressor(feature)

    model.fit(train_df)

    future = test_df[['ds']].copy()
    for feature in features:
        future[feature] = test_df[feature].values

    forecast = model.predict(future)

    y_true = test_df['y'].values
    y_pred = forecast['yhat'].values

    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    print(f"R²: {r2}")
    print(f"MAE: {mae}")
    print(f"RMSE: {rmse}")

    return model, features

# %% [markdown]
# # Valuation Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
class Domain_Valuator():
    def __init__(self, domain, X, y, features, features_data, seed):
        self.domain = domain
        self.features = features
        self.features_data = features_data
        self.model = None
        self.data = None
        self.X = X
        self.y = y 
        self.seed = seed

    def model_prep(self):
        # Prepare the domain DataFrame
        domain_df = pd.DataFrame({'domain': [self.domain]})
        domain_df['domain_length'] = domain_df['domain'].apply(len)
        domain_df['num_vowels'] = domain_df['domain'].apply(lambda x: sum([1 for char in x if char in 'aeiou']))
        domain_df['num_consonants'] = domain_df['domain'].apply(lambda x: sum([1 for char in x if char.isalpha() and char not in 'aeiou']))
        domain_df['tld'] = domain_df['domain'].apply(lambda x: x.split('.')[-1])
        # domain_df['tld_weight'] = domain_df['tld'].map(self.tld_weights).fillna(self.default_tld_weight)

        # Include today’s date
        today = pd.Timestamp.now().normalize()
        print(f'Domain DataFrame Columns: {domain_df.columns}')
        print(f'Feature Data (latest entry): {self.features_data.iloc[-1]}')

        # Prepare features with missing ones from features_data
        missing_features = [feature for feature in self.features if feature not in domain_df.columns]
        print(f'domain df before adding features {domain_df}')
        print(f'domain df cols {domain_df.columns}')
        print(f'missing features {missing_features}')
        if missing_features:
            for feature in missing_features:
                if feature in self.features_data.columns:
                    domain_df[feature] = self.features_data[feature].iloc[-1]
                else:
                    raise ValueError(f"Feature {feature} is missing from features_data")
        
        # Ensure all features are present
        all_features = [feature for feature in self.features if feature != 'ds']
        domain_features = domain_df[all_features].iloc[0]
        print(f'domain features {domain_features}')
        
        self.data = pd.DataFrame({
            'ds': [today],
            **domain_features.to_dict()
        })

        print(f"Prepared data for prediction: {self.data}")
        print(f"Prepared col for prediction: {self.data.columns}")

    def value_domain(self, model):
        self.model = model
        print(f'data: {self.data}')
        domain_x = self.data[self.features]
        value = self.model.predict(domain_x)
        print(f'domain: {self.domain} \npredicted value: {value[0]}')
        return value[0]

# %%
class Prophet_Domain_Valuator():
    def __init__(self, domain, features, features_data):
        self.domain = domain
        self.features_data = features_data
        self.data = None
    
    def model_prep(self):
        # Prepare the domain DataFrame
        domain_df = pd.DataFrame({'domain': [self.domain]})
        domain_df['domain_length'] = domain_df['domain'].apply(len)
        domain_df['num_vowels'] = domain_df['domain'].apply(lambda x: sum([1 for char in x if char in 'aeiou']))
        domain_df['num_consonants'] = domain_df['domain'].apply(lambda x: sum([1 for char in x if char.isalpha() and char not in 'aeiou']))
        domain_df['tld'] = domain_df['domain'].apply(lambda x: x.split('.')[-1])

        # Include today’s date
        today = pd.Timestamp.now().normalize()
        print(f'Domain DataFrame Columns: {domain_df.columns}')
        print(f'Feature Data (latest entry): {self.features_data.iloc[-1]}')

        # Prepare features with missing ones from features_data
        missing_features = [feature for feature in self.features if feature not in domain_df.columns]
        if missing_features:
            for feature in missing_features:
                if feature in self.features_data.columns:
                    domain_df[feature] = self.features_data[feature].iloc[-1]
                else:
                    raise ValueError(f"Feature {feature} is missing from features_data")
        
        # Ensure all features are present
        all_features = [feature for feature in self.features if feature != 'ds']
        domain_features = domain_df[all_features].iloc[0]
        
        self.data = pd.DataFrame({
            'ds': [today],
            **domain_features.to_dict()
        })

        print(f"Prepared data for prediction: {self.data}")

    def value_domain(self, model):
        self.model = model
        # Ensure the feature data includes the latest information
        future = self.data.copy()
        for feature in self.features:
            if feature not in future.columns:
                if feature in self.features_data.columns:
                    future[feature] = self.features_data[feature].iloc[-1]
                else:
                    raise ValueError(f"Feature {feature} is missing from features_data")

        # Predict using the fitted model
        forecast = self.model.predict(future)
        value = forecast['yhat'].values[0]
        print(f'Domain: {self.domain} \nPredicted value: {value}')
        return value

# %%
combined_dataset
# Out:
#                               dt                    domain    price_usd  \
# 0      1999-04-01 00:00:00+00:00                 bingo.com 1,100,000.00
# 1      1999-04-01 00:00:00+00:00             altavista.com 3,250,000.00
# 2      1999-11-01 00:00:00+00:00                   fly.com 1,500,000.00
# 3      1999-12-01 00:00:00+00:00                   tom.com 2,500,000.00
# 4      1999-12-01 00:00:00+00:00               england.com 2,000,000.00
# ...                          ...                       ...          ...
# 394147 2024-08-03 17:00:00+00:00                    03.box       354.26
# 394148 2024-08-03 17:00:00+00:00            flon.chain.box         0.83
# 394149 2024-08-03 17:00:00+00:00             eua.chain.box         0.86
# 394150 2024-08-03 17:00:00+00:00  investecriptos.chain.box         0.89
# 394151 2024-08-03 17:00:00+00:00    drivenspyder.chain.box         1.33
#
#         domain_length  num_vowels  num_consonants  tld  tld_weight
# 0                 NaN         NaN             NaN  NaN         NaN
# 1                 NaN         NaN             NaN  NaN         NaN
# 2                 NaN         NaN             NaN  NaN         NaN
# 3                 NaN         NaN             NaN  NaN         NaN
# 4                 NaN         NaN             NaN  NaN         NaN
# ...               ...         ...             ...  ...         ...
# 394147           6.00        1.00            2.00  box        1.00
# 394148          14.00        4.00            8.00  box        1.00
# 394149          13.00        6.00            5.00  box        1.00
# 394150          24.00        8.00           14.00  box        1.00
# 394151          22.00        6.00           14.00  box        1.00
#
# [394152 rows x 8 columns]

# %%
prophet_model, prophet_features = train_prophet_model(prophet_features)
# Out:
# Index(['dt', 'domain', 'price_usd', 'domain_length', 'num_vowels',
#        'num_consonants', 'tld', 'tld_weight'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 prophet_model, prophet_features = train_prophet_model(prophet_features)
#
# Cell In[31], line 17, in train_prophet_model(features)
#      14 for feature in features:
#      15     model.add_regressor(feature)
# ---> 17 model.fit(train_df)
#      19 future = test_df[['ds']].copy()
#      20 for feature in features:
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1217, in Prophet.fit(self, df, **kwargs)
#    1213 if self.history is not None:
#    1214     raise Exception('Prophet object can only be fit once. '
#    1215                     'Instantiate a new object.')
# -> 1217 model_inputs = self.preprocess(df, **kwargs)
#    1218 initial_params = self.calculate_initial_params(model_inputs.K)
#    1220 dat = dataclasses.asdict(model_inputs)
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1135, in Prophet.preprocess(self, df, **kwargs)
#    1132     raise ValueError('Dataframe has less than 2 non-NaN rows.')
#    1133 self.history_dates = pd.to_datetime(pd.Series(history['ds'].unique(), name='ds')).sort_values()
# -> 1135 self.history = self.setup_dataframe(history, initialize_scales=True)
#    1136 self.set_auto_seasonalities()
#    1137 seasonal_features, prior_scales, component_cols, modes = (
#    1138     self.make_all_seasonality_features(self.history))
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:303, in Prophet.setup_dataframe(self, df, initialize_scales)
#     301     df[name] = pd.to_numeric(df[name])
#     302     if df[name].isnull().any():
# --> 303         raise ValueError(
#     304             'Found NaN in column {name!r}'.format(name=name)
#     305         )
#     306 for props in self.seasonalities.values():
#     307     condition_name = props['condition_name']
#
# ValueError: Found NaN in column 'domain_length'

# %% [markdown]
# best_model, best_params = train_randomforest_model_with_gridsearch(X, y)

# %% [markdown]
# best_params

# %%
ridge_model, ridge_features = train_ridge_model(X, y)
# Out:
# MAE: 4906.891449472705
# MSE: 13452744050.011114
# R²: -0.0008306473758308286

# %%
randomforest_model, random_forest_features = train_randomforest_model(X, y)
# Out:
# MAE: 5822.157495115425
# MSE: 136586595190.82391
# R²: -9.16149939220615

# %%
from sklearn.ensemble import VotingRegressor

class EnsemblePredictor:
    def __init__(self, prophet_model, rf_model, ridge_model, features):
        self.prophet_model = prophet_model
        self.rf_model = rf_model
        self.ridge_model = ridge_model
        self.features = features

    def predict(self, X, df_prophet):
        # Prepare the input for Prophet
        future = X[['ds']].copy()
        for feature in self.features:
            future[feature] = X[feature].values
        
        forecast = self.prophet_model.predict(future)
        prophet_preds = forecast['yhat'].values
        
        # Prepare the input for RandomForest and Ridge
        X_rf = X.drop(columns=['ds'])  # Drop 'ds' for RF and Ridge
        rf_preds = self.rf_model.predict(X_rf)
        ridge_preds = self.ridge_model.predict(X_rf)

        # Create a DataFrame to store predictions
        predictions = pd.DataFrame({
            'prophet': prophet_preds,
            'rf': rf_preds,
            'ridge': ridge_preds
        })

        # Aggregate predictions (you can use mean, median, or other methods)
        predictions['mean_ensemble'] = predictions.mean(axis=1)
        predictions['median_ensemble'] = predictions.median(axis=1)
        
        return predictions[['mean_ensemble','median_ensemble']]

# %%
ensemble_predictor = EnsemblePredictor(prophet_model, randomforest_model, ridge_model, prophet_features)

# Prepare data for prediction (X should be in the correct format for Prophet)
X = combined_dataset.copy()  # Ensure this DataFrame is correctly formatted
X['dt'] = X['dt'].dt.tz_localize(None)
X.rename(columns={'dt':'ds'}, inplace=True)

# Predict using the ensemble
ensemble_predictions = ensemble_predictor.predict(X, combined_dataset)

# %%
y_true = combined_dataset['price_usd'].values
r2 = r2_score(y_true, ensemble_predictions['mean_ensemble'])
mae = mean_absolute_error(y_true, ensemble_predictions['mean_ensemble'])
rmse = np.sqrt(mean_squared_error(y_true, ensemble_predictions['mean_ensemble']))

print(f"Mean Ensemble R²: {r2}")
print(f"Ensemble MAE: {mae}")
print(f"Ensemble RMSE: {rmse}")
# Out:
# Ensemble R²: 0.21678586428996505
# Ensemble MAE: 5101.129566955156
# Ensemble RMSE: 365309.38410804205

# %%
y_true = combined_dataset['price_usd'].values
r2 = r2_score(y_true, ensemble_predictions['median_ensemble'])
mae = mean_absolute_error(y_true, ensemble_predictions['median_ensemble'])
rmse = np.sqrt(mean_squared_error(y_true, ensemble_predictions['median_ensemble']))

print(f"Median Ensemble R²: {r2}")
print(f"Ensemble MAE: {mae}")
print(f"Ensemble RMSE: {rmse}")
# Out:
# Ensemble R²: 0.2302208913448326
# Ensemble MAE: 4533.721506617051
# Ensemble RMSE: 362162.62572964455

# %%
domain = 'env.eth'

# %%
# Ensure features_data is up to date and correctly formatted
prophet_features_data = combined_dataset.copy()
prophet_features_data.rename(columns={"dt": "ds", "price_usd": "y"}, inplace=True)
# prophet_features_data['ds'] = pd.to_datetime(features_data['ds']).dt.tz_localize(None)  # Remove timezone if present

# Initialize the Domain_Valuator
prophet_valuator = Prophet_Domain_Valuator(domain, prophet_features, prophet_features_data)

# Prepare the model and get the domain value
prophet_valuator.model_prep()
prophet_domain_value = prophet_valuator.value_domain(prophet_model)
# Out:
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): ds                              2024-08-03 17:00:00+00:00
# domain                             drivenspyder.chain.box
# y                                                    1.33
# 7d_rolling_avg_price                                55.22
# 30d_rolling_avg_price                              202.53
# 7d_sales_volume                                    386.56
# 30d_sales_volume                                 6,075.89
# cumulative_rolling_avg_price                     2,995.92
# 7d_domains_sold                                      7.00
# 30d_domains_sold                                    30.00
# 60d_domains_sold                                    60.00
# 90d_domains_sold                                    90.00
# 7d_rolling_std_dev                                 132.07
# 30d_rolling_std_dev                                616.25
# 7d_rolling_median_price                              1.33
# 30d_rolling_median_price                             5.98
# cumulative_sum_sales_volume              1,180,848,466.49
# domain_length                                          22
# num_vowels                                              6
# num_consonants                                         14
# tld                                                   box
# Name: 394151, dtype: object
# Prepared data for prediction:           ds  30d_rolling_avg_price  30d_sales_volume  7d_rolling_avg_price  \
# 0 2024-08-03                 202.53          6,075.89                 55.22
#
#    7d_rolling_std_dev  7d_sales_volume  domain_length  num_consonants  \
# 0              132.07           386.56           7.00            4.00
#
#    num_vowels
# 0        2.00
# Domain: env.eth
# Predicted value: 13309.71620767998

# %%
# Right now doesnt work w/ .com
features_data = combined_dataset.copy()
features_data['dt'] = features_data['dt'].dt.tz_localize(None)
features_data = features_data[features] 
ridge_valuator = Domain_Valuator(domain, X, y, gen_features, features_data, seed)

# Prepare the model and get the domain value
ridge_valuator.model_prep()
ridge_domain_value = ridge_valuator.value_domain(ridge_model)
# Out:
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): dt                                 2024-08-03 17:00:00
# domain                          drivenspyder.chain.box
# 7d_rolling_avg_price                             55.22
# 30d_rolling_avg_price                           202.53
# 7d_sales_volume                                 386.56
# 30d_sales_volume                              6,075.89
# cumulative_rolling_avg_price                  2,995.92
# 7d_domains_sold                                   7.00
# 30d_domains_sold                                 30.00
# 60d_domains_sold                                 60.00
# 90d_domains_sold                                 90.00
# 7d_rolling_std_dev                              132.07
# 30d_rolling_std_dev                             616.25
# 7d_rolling_median_price                           1.33
# 30d_rolling_median_price                          5.98
# cumulative_sum_sales_volume           1,180,848,466.49
# domain_length                                       22
# num_vowels                                           6
# num_consonants                                      14
# tld                                                box
# Name: 394151, dtype: object
# domain df before adding features     domain  domain_length  num_vowels  num_consonants  tld
# 0  env.eth              7           2               4  eth
# domain df cols Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# missing features ['30d_rolling_avg_price', '30d_sales_volume', '7d_rolling_avg_price', '7d_rolling_std_dev', '7d_sales_volume', 'dt']
# domain features 30d_rolling_avg_price                 202.53
# 30d_sales_volume                    6,075.89
# 7d_rolling_avg_price                   55.22
# 7d_rolling_std_dev                    132.07
# 7d_sales_volume                       386.56
# domain                               env.eth
# domain_length                              7
# dt                       2024-08-03 17:00:00
# num_consonants                             4
# num_vowels                                 2
# tld                                      eth
# Name: 0, dtype: object
# Prepared data for prediction:           ds  30d_rolling_avg_price  30d_sales_volume  7d_rolling_avg_price  \
# 0 2024-08-03                 202.53          6,075.89                 55.22
#
#    7d_rolling_std_dev  7d_sales_volume   domain  domain_length  \
# 0              132.07           386.56  env.eth              7
#
#                    dt  num_consonants  num_vowels  tld
# 0 2024-08-03 17:00:00               4           2  eth
# Prepared col for prediction: Index(['ds', '30d_rolling_avg_price', '30d_sales_volume',
#        '7d_rolling_avg_price', '7d_rolling_std_dev', '7d_sales_volume',
#        'domain', 'domain_length', 'dt', 'num_consonants', 'num_vowels', 'tld'],
#       dtype='object')
# data:           ds  30d_rolling_avg_price  30d_sales_volume  7d_rolling_avg_price  \
# 0 2024-08-03                 202.53          6,075.89                 55.22
#
#    7d_rolling_std_dev  7d_sales_volume   domain  domain_length  \
# 0              132.07           386.56  env.eth              7
#
#                    dt  num_consonants  num_vowels  tld
# 0 2024-08-03 17:00:00               4           2  eth
# domain: env.eth
# predicted value: 7706.23524447116

# %%
# Right now doesnt work w/ .com
features_data = combined_dataset.copy()
features_data['dt'] = features_data['dt'].dt.tz_localize(None)
features_data = features_data[features] 
randomforest_valuator = Domain_Valuator(domain, X, y, gen_features, features_data, seed)

# Prepare the model and get the domain value
randomforest_valuator.model_prep()
randomforest_domain_value = randomforest_valuator.value_domain(randomforest_model)
# Out:
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): dt                                 2024-08-03 17:00:00
# domain                          drivenspyder.chain.box
# 7d_rolling_avg_price                             55.22
# 30d_rolling_avg_price                           202.53
# 7d_sales_volume                                 386.56
# 30d_sales_volume                              6,075.89
# cumulative_rolling_avg_price                  2,995.92
# 7d_domains_sold                                   7.00
# 30d_domains_sold                                 30.00
# 60d_domains_sold                                 60.00
# 90d_domains_sold                                 90.00
# 7d_rolling_std_dev                              132.07
# 30d_rolling_std_dev                             616.25
# 7d_rolling_median_price                           1.33
# 30d_rolling_median_price                          5.98
# cumulative_sum_sales_volume           1,180,848,466.49
# domain_length                                       22
# num_vowels                                           6
# num_consonants                                      14
# tld                                                box
# Name: 394151, dtype: object
# domain df before adding features     domain  domain_length  num_vowels  num_consonants  tld
# 0  env.eth              7           2               4  eth
# domain df cols Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# missing features ['30d_rolling_avg_price', '30d_sales_volume', '7d_rolling_avg_price', '7d_rolling_std_dev', '7d_sales_volume', 'dt']
# domain features 30d_rolling_avg_price                 202.53
# 30d_sales_volume                    6,075.89
# 7d_rolling_avg_price                   55.22
# 7d_rolling_std_dev                    132.07
# 7d_sales_volume                       386.56
# domain                               env.eth
# domain_length                              7
# dt                       2024-08-03 17:00:00
# num_consonants                             4
# num_vowels                                 2
# tld                                      eth
# Name: 0, dtype: object
# Prepared data for prediction:           ds  30d_rolling_avg_price  30d_sales_volume  7d_rolling_avg_price  \
# 0 2024-08-03                 202.53          6,075.89                 55.22
#
#    7d_rolling_std_dev  7d_sales_volume   domain  domain_length  \
# 0              132.07           386.56  env.eth              7
#
#                    dt  num_consonants  num_vowels  tld
# 0 2024-08-03 17:00:00               4           2  eth
# Prepared col for prediction: Index(['ds', '30d_rolling_avg_price', '30d_sales_volume',
#        '7d_rolling_avg_price', '7d_rolling_std_dev', '7d_sales_volume',
#        'domain', 'domain_length', 'dt', 'num_consonants', 'num_vowels', 'tld'],
#       dtype='object')
# data:           ds  30d_rolling_avg_price  30d_sales_volume  7d_rolling_avg_price  \
# 0 2024-08-03                 202.53          6,075.89                 55.22
#
#    7d_rolling_std_dev  7d_sales_volume   domain  domain_length  \
# 0              132.07           386.56  env.eth              7
#
#                    dt  num_consonants  num_vowels  tld
# 0 2024-08-03 17:00:00               4           2  eth
# domain: env.eth
# predicted value: 2036.7978335506675

# %%
total = randomforest_domain_value+ridge_domain_value+prophet_domain_value

ensemble_value = total.median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ensemble_predictions = ensemble_predictor.predict(X, combined_dataset)
#
# NameError: name 'ensemble_predictor' is not defined
