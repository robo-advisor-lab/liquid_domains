# %%
import pandas as pd
import numpy as np
import random
import os
import sys
import requests
import time
import datetime as dt


from dotenv import load_dotenv
from flipside import Flipside
from prophet import Prophet

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# from sql_queries.sql_scripts import eth_price

# %%
Optimistic_Domains_Sales_query = """
  SELECT
      DATE_TRUNC('HOUR', BLOCK_TIMESTAMP) AS day, tokenid, price
    FROM
      optimism.nft.ez_nft_sales
    WHERE
      NFT_ADDRESS = LOWER('0xC16aCAdf99E4540E6f4E6Da816fd6D2A2C6E1d4F')
      AND event_type = 'sale'

"""

eth_price = """

  select
    hour as dt,
    symbol,
    price
  from
    ethereum.price.ez_prices_hourly
  where
    symbol in('WETH')
    AND date_trunc('day', dt) >= '	2022-06-01'
  order by
    dt DESC

"""

# %%
os.chdir('..')
print(os.getcwd())
# Out:
# e:\Projects\liquid_domains

# %%
from scripts.utils import flipside_api_results, set_random_seed
from scripts.pull_data import pull_data
from scripts.data_processing import process_data

# %%
os.chdir('Notebooks')

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
current_directory = os.getcwd()
current_directory
# Out:
# 'e:\\Projects\\liquid_domains\\Notebooks'

# %%
load_dotenv()
# Out:
# True

# %%
seed = 20
set_random_seed(seed)

# %%
flipside_api_key = os.getenv('FLIPSIDE_API_KEY')
alchemy_api_key = os.getenv('ALCHEMY_API_KEY')
opensea_api_key = os.getenv('OPENSEA_API_KEY')

# %%
api = True #Pulls the most recent data from all web3 sources, web2 sources are still via csv (This function takes 2+ hours, use it periodically)
web2_data = True #Includes web2 data in training
threshold = None #Correlation value for correlation analysis
temporals = True #Tends to inflate estimation
fine_tuning_web3 = True #Train again on web3 data only
correlation_analysis = False #Performs Correlation Analysis to 'price' col and drops cols under the threshold parameter 
last_dataset = False #Saves time of feature engineering, saves the latest copy of the dataset generated by the function

# %% [markdown]
# # To preview web2 domain data; Kaggle dataset and namebio dataset
#
# domain_path = '../data/domain-name-sales.tsv'
# domain_data = pd.read_csv(domain_path, delimiter='\t')
#
# domain_data.set_index('date', inplace=True)
# domain_data = domain_data.drop(columns=['venue'])
# domain_data.sort_index(inplace=True)
# domain_data
#
# domain_data = domain_data.reset_index()
# domain_data = domain_data.rename(columns={"date":"dt","price":"price_usd"})
# domain_data['dt'] = pd.to_datetime(domain_data['dt'])
# domain_data['dt'] = domain_data['dt'].dt.tz_localize('UTC')
# domain_data['dt'] = pd.to_datetime(domain_data['dt'])
#
# domain_data['web3'] = False
#
# namebio_path = '../data/namebio_sales.csv'
# namebio_data = pd.read_csv(namebio_path)
# namebio_data.set_index('Date', inplace=True)
# namebio_data = namebio_data.drop(columns=['Venue'])
# namebio_data.sort_index(inplace=True)
#
# namebio_data = namebio_data.reset_index()
# namebio_data = namebio_data.rename(columns={"Date":"dt","Price":"price_usd","Domain":"domain"})
# namebio_data['dt'] = pd.to_datetime(namebio_data['dt'])
# namebio_data['dt'] = namebio_data['dt'].dt.tz_localize('UTC')
# namebio_data['dt'] = pd.to_datetime(namebio_data['dt'])
#
# namebio_data['web3'] = False
#
# domain_data = pd.concat([domain_data,namebio_data],ignore_index=True)

# %%
X, y, prophet_features, gen_features, target, combined_dataset, features, web3_data, X_web3, y_web3 = process_data(api=api,web2_data=web2_data,threshold=threshold,temporals=temporals,correlation_analysis=correlation_analysis,last_dataset=last_dataset)
# Out:
# starting process_data
# 6AUlaGmWe505S7gRPZXVh4YEFgJdYHy5
# Pulling Fresh Data...
# Fetching sale: Page 1, Events Fetched: 50, Total Events: 50, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTMwKzA3JTNBMjAlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDQ3MjYzMjU1OQ==
# Fetching sale: Page 2, Events Fetched: 50, Total Events: 100, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTI5KzE5JTNBMjglM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDQ1NDc1MDU5Nw==
# Fetching sale: Page 3, Events Fetched: 50, Total Events: 150, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTI3KzE5JTNBNDUlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDM4NTQ5MDAzOQ==
# Fetching sale: Page 4, Events Fetched: 50, Total Events: 200, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTI2KzEyJTNBMDglM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDMzODYyNzk0MA==
# Fetching sale: Page 5, Events Fetched: 50, Total Events: 250, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTI1KzA4JTNBNDAlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDI4NTcwMTU1NA==
# Fetching sale: Page 6, Events Fetched: 50, Total Events: 300, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTI0KzAzJTNBMTElM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDIzMzgzMDgzMA==
# Fetching sale: Page 7, Events Fetched: 50, Total Events: 350, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTIyKzE1JTNBMDMlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDE4MzQ5NDM5MA==
# Fetching sale: Page 8, Events Fetched: 50, Total Events: 400, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTIxKzE1JTNBMDQlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDE0NTI1MTYwMw==
# Fetching sale: Page 9, Events Fetched: 50, Total Events: 450, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTIwKzIzJTNBMDglM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDEyMDMzNjc0OA==
# Fetching sale: Page 10, Events Fetched: 50, Total Events: 500, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE5KzEyJTNBNDAlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDA2NDIxOTQzNg==
# Fetching sale: Page 11, Events Fetched: 50, Total Events: 550, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE4KzA2JTNBMjclM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zMDAxNTQ1Njc2Mg==
# Fetching sale: Page 12, Events Fetched: 50, Total Events: 600, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE2KzE5JTNBNTclM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTk2MzQ0Njg5OQ==
# Fetching sale: Page 13, Events Fetched: 50, Total Events: 650, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE2KzA2JTNBNDQlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTk0MjQ4MTIxNw==
# Fetching sale: Page 14, Events Fetched: 50, Total Events: 700, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE1KzIxJTNBNTMlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTkyODI4ODI1OQ==
# Fetching sale: Page 15, Events Fetched: 50, Total Events: 750, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE1KzA5JTNBNTclM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTkwNzI1OTkyMQ==
# Fetching sale: Page 16, Events Fetched: 50, Total Events: 800, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE1KzA3JTNBMzYlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTkwMzczOTM2NA==
# Fetching sale: Page 17, Events Fetched: 50, Total Events: 850, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE0KzIwJTNBMzYlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTg4NjExNTc1NA==
# Fetching sale: Page 18, Events Fetched: 50, Total Events: 900, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTE0KzE2JTNBMDElM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTg3ODU4NDI1Nw==
# Fetching sale: Page 19, Events Fetched: 50, Total Events: 950, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTEzKzE5JTNBMDglM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTg0NDQ4ODQ3NA==
# Fetching sale: Page 20, Events Fetched: 50, Total Events: 1000, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTExKzA2JTNBNTIlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yOTczNTk2NDkwMw==
# Fetching sale: Page 21, Events Fetched: 50, Total Events: 1050, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEyLTA4KzIwJTNBNDElM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yO
0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODQ4MjUyNDQ5MQ==
# Fetching sale: Page 46, Events Fetched: 50, Total Events: 2300, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTExLTA3KzAzJTNBNTQlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODQxOTkzNDQxMw==
# Fetching sale: Page 47, Events Fetched: 50, Total Events: 2350, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTExLTA0KzA0JTNBNTQlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODMzNDIyNjIyOQ==
# Fetching sale: Page 48, Events Fetched: 50, Total Events: 2400, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTExLTAyKzExJTNBNDUlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODI4ODk2Mzc3MA==
# Fetching sale: Page 49, Events Fetched: 50, Total Events: 2450, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTMwKzE4JTNBNDglM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODIwNzE5Njg4MQ==
# Fetching sale: Page 50, Events Fetched: 50, Total Events: 2500, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTI4KzE4JTNBMjAlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODE1MDA4MDc5NA==
# Fetching sale: Page 51, Events Fetched: 50, Total Events: 2550, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTI2KzIyJTNBNDElM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODA5NTMyODA0MA==
# Fetching sale: Page 52, Events Fetched: 50, Total Events: 2600, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTI2KzA3JTNBMTElM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODA3NzM2OTk5MA==
# Fetching sale: Page 53, Events Fetched: 50, Total Events: 2650, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTI1KzE0JTNBNTIlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODA1Nzg3NTY2NA==
# Fetching sale: Page 54, Events Fetched: 50, Total Events: 2700, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTI1KzA4JTNBMDIlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODA0OTc3NDIzMA==
# Fetching sale: Page 55, Events Fetched: 50, Total Events: 2750, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTI0KzIwJTNBMjglM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yODAzNDYwMDUyMw==
# Fetching sale: Page 56, Events Fetched: 50, Total Events: 2800, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTIyKzIyJTNBMzklM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzk3Mjg3Nzc2OA==
# Fetching sale: Page 57, Events Fetched: 50, Total Events: 2850, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTIxKzA3JTNBNTMlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzkyMjU2NzQxNw==
# Fetching sale: Page 58, Events Fetched: 50, Total Events: 2900, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTE5KzE5JTNBNTElM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzg2OTMyNjQyMA==
# Fetching sale: Page 59, Events Fetched: 50, Total Events: 2950, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTE3KzEzJTNBNDElM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzc3NzMzMTUwNQ==
# Fetching sale: Page 60, Events Fetched: 50, Total Events: 3000, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTE1KzEwJTNBMzMlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzY4OTQwNzg4Mw==
# Fetching sale: Page 61, Events Fetched: 50, Total Events: 3050, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTE0KzAyJTNBMTklM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzYzODY5ODI3MA==
# Fetching sale: Page 62, Events Fetched: 50, Total Events: 3100, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTEyKzE3JTNBMDElM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzU4NTgyNzU1Nw==
# Fetching sale: Page 63, Events Fetched: 50, Total Events: 3150, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTEwKzIxJTNBMjQlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzUxNDY0NDEwMg==
# Fetching sale: Page 64, Events Fetched: 50, Total Events: 3200, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTA5KzA5JTNBMzQlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzQ2MjU5MTY3OA==
# Fetching sale: Page 65, Events Fetched: 50, Total Events: 3250, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTA4KzE4JTNBMTMlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzQzNzUzMjc1MA==
# Fetching sale: Page 66, Events Fetched: 50, Total Events: 3300, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTA3KzIwJTNBNDUlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzQwMTE3MDgzMw==
# Fetching sale: Page 67, Events Fetched: 50, Total Events: 3350, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTA3KzA0JTNBMzQlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzM3NTE0MjAyNQ==
# Fetching sale: Page 68, Events Fetched: 50, Total Events: 3400, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTA2KzEzJTNBMTElM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzM1MTY5MDM4NQ==
# Fetching sale: Page 69, Events Fetched: 50, Total Events: 3450, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwL
M0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTMwMDYxOTY0Mw==
# Fetching sale: Page 141, Events Fetched: 50, Total Events: 7050, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTE0KzA0JTNBNTIlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTI4NzI4MzMwOA==
# Fetching sale: Page 142, Events Fetched: 50, Total Events: 7100, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTE0KzAzJTNBNDMlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTI4NTY4MjkyOA==
# Fetching sale: Page 143, Events Fetched: 50, Total Events: 7150, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTEzKzIxJTNBMzUlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTI3NzkyMTg2OQ==
# Fetching sale: Page 144, Events Fetched: 50, Total Events: 7200, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTEzKzEzJTNBMjMlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTI2Nzg5MTg4MQ==
# Fetching sale: Page 145, Events Fetched: 50, Total Events: 7250, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTEzKzA0JTNBNTAlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTI1NTgyMzA1Ng==
# Fetching sale: Page 146, Events Fetched: 50, Total Events: 7300, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTEzKzAyJTNBMTAlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTI1MjIyMjk0OQ==
# Fetching sale: Page 147, Events Fetched: 50, Total Events: 7350, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTEyKzIyJTNBMjAlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTI0NzA1NjE2MA==
# Fetching sale: Page 148, Events Fetched: 50, Total Events: 7400, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTEyKzExJTNBMjElM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTIzMjIwMTk5NA==
# Fetching sale: Page 149, Events Fetched: 50, Total Events: 7450, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTExKzE5JTNBMzglM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTIxMTAwNzk4Nw==
# Fetching sale: Page 150, Events Fetched: 50, Total Events: 7500, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTEwKzExJTNBMjglM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTE2NzgzMjMzNw==
# Fetching sale: Page 151, Events Fetched: 50, Total Events: 7550, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTA5KzA3JTNBMzklM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTEyOTM5MTEyNw==
# Fetching sale: Page 152, Events Fetched: 50, Total Events: 7600, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTA4KzA1JTNBMTIlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTA5MzgwOTgxNQ==
# Fetching sale: Page 153, Events Fetched: 50, Total Events: 7650, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTA2KzEzJTNBMTUlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTA0MTUyNTMxNQ==
# Fetching sale: Page 154, Events Fetched: 50, Total Events: 7700, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTA0KzE2JTNBMzYlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDk4OTE4OTgxOQ==
# Fetching sale: Page 155, Events Fetched: 50, Total Events: 7750, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTAzKzA4JTNBMzclM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDk0OTc3Nzc1NQ==
# Fetching sale: Page 156, Events Fetched: 50, Total Events: 7800, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTAxKzIzJTNBMTElM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDkwNjg5MzkwOQ==
# Fetching sale: Page 157, Events Fetched: 50, Total Events: 7850, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTAxKzAxJTNBNTYlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDg4MDI0ODU2Mw==
# Fetching sale: Page 158, Events Fetched: 50, Total Events: 7900, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTAxKzAwJTNBMjglM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDg3ODUyMDM1Mw==
# Fetching sale: Page 159, Events Fetched: 50, Total Events: 7950, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTMwKzExJTNBMDMlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDgyOTY5ODM2MA==
# Fetching sale: Page 160, Events Fetched: 50, Total Events: 8000, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTI5KzEzJTNBNTQlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDgwMTAxOTQ0NQ==
# Fetching sale: Page 161, Events Fetched: 50, Total Events: 8050, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTI5KzA1JTNBMzMlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDc5MDU5ODIyMg==
# Fetching sale: Page 162, Events Fetched: 50, Total Events: 8100, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTI4KzE4JTNBMTklM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDc3NjUxMTk0Nw==
# Fetching sale: Page 163, Events Fetched: 50, Total Events: 8150, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTI3KzA5JTNBMzUlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDczMzQ5MTA4Mg==
# Fetching sale: Page 164, Events Fetched: 50, Total Events: 8200, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTI2KzAyJTNBNTUlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDY5NDgyMzk3Mw==
# Fetching sale: Page 165, Events Fetched: 50, Total Events: 8250, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTI0KzEzJTNBNDIlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDY0NDY5MzEzNw==
# Fetching sale: Page 166, Events Fetched: 50, Total Events: 8300, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTIzKzEwJTNBMTElM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDYwNjY5MDE5Mw==
# Fetching sale: Page 167, Events Fetched: 50, Total Events: 8350, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTIxKzE3JTNBMjYlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDU0OTUyMjk2Mw==
# Fetching sale: Page 168, Events Fetched: 50, Total Events: 8400, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTIxKzAxJTNBNTElM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDUyODgyNjMxOA==
# Fetching sale: Page 169, Events Fetched: 50, Total Events: 8450, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTIwKzAzJTNBMTUlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDQ5OTg1MTc5MA==
# Fetching sale: Page 170, Events Fetched: 50, Total Events: 8500, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTE4KzIyJTNBMjQlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDQ2MjkzNDk4NQ==
# Fetching sale: Page 171, Events Fetched: 50, Total Events: 8550, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTE4KzAxJTNBMjIlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDQzODEyNDkzOA==
# Fetching sale: Page 172, Events Fetched: 50, Total Events: 8600, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTE3KzIxJTNBMTQlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDQzMzM0ODkxOA==
# Fetching sale: Page 173, Events Fetched: 50, Total Events: 8650, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTE2KzIxJTNBMjklM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDQwMzc3Njc2OQ==
# Fetching sale: Page 174, Events Fetched: 50, Total Events: 8700, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTE1KzAyJTNBMTElM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDM0OTA5NTk2Mw==
# Fetching sale: Page 175, Events Fetched: 50, Total Events: 8750, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTE0KzEzJTNBMzQlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDMzMzAxMzI0OQ==
# Fetching sale: Page 176, Events Fetched: 50, Total Events: 8800, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTEzKzA2JTNBNDQlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDI5Mzc0MDI5Mw==
# Fetching sale: Page 177, Events Fetched: 50, Total Events: 8850, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTEyKzAzJTNBMDQlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDI2MDA1MDE5Mg==
# Fetching sale: Page 178, Events Fetched: 50, Total Events: 8900, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTExKzAxJTNBMDclM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDIzMTM5MjcyNQ==
# Fetching sale: Page 179, Events Fetched: 50, Total Events: 8950, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTA5KzA4JTNBMTglM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDE4MTkyNTY4OQ==
# Fetching sale: Page 180, Events Fetched: 50, Total Events: 9000, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTA3KzIxJTNBNTklM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDEzNzgxMzkzNQ==
# Fetching sale: Page 181, Events Fetched: 50, Total Events: 9050, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTA2KzIyJTNBMzMlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDEwNjkyOTc5OA==
# Fetching sale: Page 182, Events Fetched: 50, Total Events: 9100, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTA0KzExJTNBNDUlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDAzMDU4ODUzMw==
# Fetching sale: Page 183, Events Fetched: 50, Total Events: 9150, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTAzKzAyJTNBNDclM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMzk5MDE4MDM5OQ==
# Fetching sale: Page 184, Events Fetched: 50, Total Events: 9200, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTAyKzA3JTNBMTElM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMzk2NTg5MzU1MA==
# Fetching sale: Page 185, Events Fetched: 50, Total Events: 9250, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTAxKzA4JTNBMTIlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMzkzNjMzMTE2NA==
# Fetching sale: Page 186, Events Fetched: 50, Total Events: 9300, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA2LTMwKzExJTNBMTIlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMzkwOTg3NTg2NQ==
# Fetching sale: Page 187, Events Fetched: 50, Total Events: 9350, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA2LTI5KzE1JTNBNTAlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMzg4NTk0NjI1MQ==
# Fetching sale: Page 188, Events Fetched: 50, Total Events: 9400, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA2L
M0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjY0MTI5NjE1OQ==
# Fetching sale: Page 236, Events Fetched: 50, Total Events: 11800, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTE1KzE3JTNBMDclM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjYyMDE1NTQzMw==
# Fetching sale: Page 237, Events Fetched: 50, Total Events: 11850, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTE1KzAzJTNBMjUlM0ExMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjYwNTgwNjM5Mg==
# Fetching sale: Page 238, Events Fetched: 50, Total Events: 11900, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTEzKzE2JTNBMjMlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjU2NTM1MTU1Nw==
# Fetching sale: Page 239, Events Fetched: 50, Total Events: 11950, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTEzKzAwJTNBNDclM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjU0Nzk3ODQ1Mw==
# Fetching sale: Page 240, Events Fetched: 50, Total Events: 12000, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTEyKzA5JTNBMzElM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjUyOTU4MzIyNg==
# Fetching sale: Page 241, Events Fetched: 50, Total Events: 12050, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTExKzA5JTNBNDElM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjQ5OTIwMzM0Mg==
# Fetching sale: Page 242, Events Fetched: 50, Total Events: 12100, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTEwKzEyJTNBMDUlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjQ3MDEyMDY2Mg==
# Fetching sale: Page 243, Events Fetched: 50, Total Events: 12150, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTEwKzAxJTNBNTQlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjQ1NzY5NzAxOA==
# Fetching sale: Page 244, Events Fetched: 50, Total Events: 12200, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA5KzE4JTNBNDIlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjQ0ODgzODAyNg==
# Fetching sale: Page 245, Events Fetched: 50, Total Events: 12250, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA5KzA4JTNBNDAlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjQzNTYxNTg1Mw==
# Fetching sale: Page 246, Events Fetched: 50, Total Events: 12300, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA4KzIwJTNBMTIlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjQyMDMyNTE3Ng==
# Fetching sale: Page 247, Events Fetched: 50, Total Events: 12350, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA4KzEyJTNBMDIlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjQwOTQ4NTQyMw==
# Fetching sale: Page 248, Events Fetched: 50, Total Events: 12400, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA4KzA0JTNBMDglM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjM5OTEzMTkzMg==
# Fetching sale: Page 249, Events Fetched: 50, Total Events: 12450, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA3KzA0JTNBMDMlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjM2ODgyNzUxNg==
# Fetching sale: Page 250, Events Fetched: 50, Total Events: 12500, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA2KzE5JTNBMTglM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjM1NzkyODI5Mg==
# Fetching sale: Page 251, Events Fetched: 50, Total Events: 12550, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA2KzA2JTNBNDAlM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjM0MTk4MDY2Nw==
# Fetching sale: Page 252, Events Fetched: 50, Total Events: 12600, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA1KzE4JTNBNDQlM0EyMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjMyNjY5Nzk5MA==
# Fetching sale: Page 253, Events Fetched: 50, Total Events: 12650, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA1KzA2JTNBMDIlM0E0NyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjMwOTUxMTE2NQ==
# Fetching sale: Page 254, Events Fetched: 50, Total Events: 12700, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA0KzIwJTNBMTclM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjI5NjAxNzA0Mg==
# Fetching sale: Page 255, Events Fetched: 50, Total Events: 12750, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTA0KzAyJTNBMTAlM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjI3MjAwNDY1NA==
# Fetching sale: Page 256, Events Fetched: 50, Total Events: 12800, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA1LTAzKzE4JTNBMDklM0EzNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMjI2MTgxNjIwNg==
# ...
# Fetching sale: Page 11, Events Fetched: 50, Total Events: 550, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDIyLTA4LTE0KzA2JTNBMzclM0ExOCYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz03MzU3MDQ2NDEw
# Fetching sale: Page 12, Events Fetched: 50, Total Events: 600, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDIyLTA4LTAyKzA5JTNBMzElM0ExMCYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz03MjY0NTUwNjM3
# Fetching sale: Page 13, Events Fetched: 50, Total Events: 650, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDIyL
SYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zNjQ2NzExMA==
# Fetching sale: Page 77, Events Fetched: 50, Total Events: 3850, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDIwLTAzLTEyKzAyJTNBNTklM0E0NiYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zNjA0MTQzOQ==
# Fetching sale: Page 78, Events Fetched: 50, Total Events: 3900, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDIwLTAzLTAxKzAyJTNBNTMlM0E0OCYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0zNTA2ODUzMw==
# Fetching sale: Page 79, Events Fetched: 49, Total Events: 3949, next cursor:
# Total events fetched: 3949
# Fetching sale: Page 1, Events Fetched: 50, Total Events: 50, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDIzLTEyLTMwKzE2JTNBNDglM0E1OSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0xODYwNDg0OTc5Mg==
# Fetching sale: Page 2, Events Fetched: 50, Total Events: 100, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDIzLTA4LTIxKzEwJTNBMzclM0EyNSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0xNDU5MzQyMDU2MQ==
# Fetching sale: Page 3, Events Fetched: 25, Total Events: 125, next cursor:
# Total events fetched: 125
# Fetching sale: Page 1, Events Fetched: 50, Total Events: 50, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTEwLTA2KzAyJTNBNTclM0EzOSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNzMzNjMwMDM0Nw==
# Fetching sale: Page 2, Events Fetched: 50, Total Events: 100, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTI5KzIwJTNBMzElM0EwOSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTg3MTE0MTAxOA==
# Fetching sale: Page 3, Events Fetched: 50, Total Events: 150, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA4LTE0KzA4JTNBMTYlM0EzMSYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNTI5MjIzMTE5Mg==
# Fetching sale: Page 4, Events Fetched: 50, Total Events: 200, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTI2KzAzJTNBMjIlM0EzNyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDY5NTQyMDg3NA==
# Fetching sale: Page 5, Events Fetched: 50, Total Events: 250, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTA3LTA2KzA1JTNBMTUlM0EwMyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yNDA4Mzg2OTg2Nw==
# Fetching sale: Page 6, Events Fetched: 50, Total Events: 300, next cursor: LWV2ZW50X3RpbWVzdGFtcD0yMDI0LTAzLTE4KzA4JTNBMzQlM0EwNyYtZXZlbnRfdHlwZT1zdWNjZXNzZnVsJi1waz0yMDk5NjUyNzU1OQ==
# Fetching sale: Page 7, Events Fetched: 38, Total Events: 338, next cursor:
# Total events fetched: 338
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X, y, prophet_features, gen_features, target, combined_dataset, features, web3_data, X_web3, y_web3 = process_data(api=api,web2_data=web2_data,threshold=threshold,temporals=temporals,correlation_analysis=correlation_analysis,last_dataset=last_dataset)
#
# File e:\Projects\liquid_domains\scripts\data_processing.py:94, in process_data(seed, api, web2_data, tld_weight, temporals, corr_type, threshold, correlation_analysis, last_dataset)
#      90 opensea_api_key = os.getenv('OPENSEA_API_KEY')
#      92 print(alchemy_api_key)
# ---> 94 data_dict = pull_data(api=api)
#      96 print(f'pulled data')
#      99 domain_rankings = pd.read_csv('../data/tranco_5863N.csv')
#
# File e:\Projects\liquid_domains\scripts\pull_data.py:68, in pull_data(api)
#      65 Three_DNS_data = fetch_all_events(api_key=opensea_api_key,collection='3dns-powered-domains')
#      66 Three_DNS_data.to_json(three_dns_path, orient='records')
# ---> 68 optimistic_domains_sales = flipside_api_results(flipside_api_key, Optimistic_Domains_Sales_query)
#      69 optimistic_domains_sales.to_csv(optimistic_domains_sales_path, index=False)
#      71 prices = flipside_api_results(flipside_api_key, eth_price)
#
# File e:\Projects\liquid_domains\scripts\apis.py:160, in flipside_api_results(key, query)
#     158 def flipside_api_results(key, query):
#     159   flipside = key
# --> 160   query_result_set = flipside.query(query)
#     161   # what page are we starting on?
#     162   current_page_number = 1
#
# AttributeError: 'NoneType' object has no attribute 'query'

# %%
combined_dataset['price_usd'].max()
# Out:
# np.float64(30000000.0)

# %%
combined_dataset[combined_dataset['word_count']>1]
# Out:
#         Unnamed: 0                        dt                      domain  \
# 228            228 2015-07-08 00:00:00+00:00       interfaith-center.org
# 407            407 2015-07-14 00:00:00+00:00             face-europe.org
# 463            463 2015-07-18 00:00:00+00:00           velo-city2014.com
# 554            554 2015-07-26 00:00:00+00:00               outer-rim.net
# 669            669 2015-07-26 00:00:00+00:00        festival-kinetik.net
# ...            ...                       ...                         ...
# 565698      565698 2024-10-11 00:00:00+00:00        perdre-la-raison.com
# 565703      565703 2024-10-11 05:00:00+00:00            step-brother.eth
# 565715      565715 2024-10-11 17:00:00+00:00                 v-bucks.eth
# 565721      565721 2024-10-12 00:00:00+00:00  re-captha-version-3-31.top
# 565730      565730 2024-10-12 00:00:00+00:00               alt-minds.com
#
#         price_usd  web3  domain_length  num_vowels  num_consonants  tld  \
# 228        110.00     0             21           7              12  org
# 407        490.00     0             15           7               6  org
# 463        185.00     0             17           4               7  com
# 554        120.00     0             13           5               6  net
# 669        206.00     0             20           7              11  net
# ...           ...   ...            ...         ...             ...  ...
# 565698     305.00     0             20           7              10  com
# 565703       1.69     1             16           4              10  eth
# 565715   3,665.09     1             11           2               7  eth
# 565721     146.00     0             26           7              11  top
# 565730     105.00     0             13           3               8  com
#
#         word_count  ...  tld_length  is_brandable  levenshtein_distance  \
# 228              2  ...           3             1                     8
# 407              2  ...           3             0                     5
# 463              2  ...           3             0                     8
# 554              2  ...           3             0                     4
# 669              2  ...           3             0                     9
# ...            ...  ...         ...           ...                   ...
# 565698           3  ...           3             1                     9
# 565703           2  ...           3             0                     5
# 565715           2  ...           3             0                     4
# 565721           5  ...           3             0                    14
# 565730           2  ...           3             0                     4
#
#         is_subdomain  domain_entropy      rank tld_weight  \
# 228                0            3.52  unranked          1
# 407                0            3.32  unranked          1
# 463                0            3.85  unranked          1
# 554                0            3.24  unranked          1
# 669                0            3.41  unranked          1
# ...              ...             ...       ...        ...
# 565698             0            3.68  unranked          1
# 565703             0            3.16  unranked          1
# 565715             0            3.46  unranked          1
# 565721             0            3.85  unranked          1
# 565730             0            3.55  unranked          1
#
#         7d_rolling_avg_price  7d_sales_volume  7d_rolling_std_dev
# 228                 1,451.29        10,159.00            3,272.02
# 407                   332.71         2,329.00              151.97
# 463                   612.00         4,284.00              550.70
# 554                   204.29         1,430.00              141.84
# 669                   222.00         1,554.00              192.54
# ...                      ...              ...                 ...
# 565698              2,003.43        14,024.00              917.53
# 565703                121.97           853.81              121.56
# 565715                880.93         6,166.48            1,348.77
# 565721                119.43           836.00               23.00
# 565730                227.71         1,594.00              188.30
#
# [13912 rows x 21 columns]

# %%
combined_dataset[combined_dataset['rank']!='unranked']
# Out:
#         Unnamed: 0                        dt                      domain  \
# 0                0 1999-04-01 00:00:00+00:00                   bingo.com
# 1                1 1999-04-01 00:00:00+00:00               altavista.com
# 2                2 1999-11-01 00:00:00+00:00                     fly.com
# 3                3 1999-12-01 00:00:00+00:00                     tom.com
# 5                5 1999-12-01 00:00:00+00:00                   autos.com
# ...            ...                       ...                         ...
# 565120      565120 2024-10-10 00:00:00+00:00                 clomida.com
# 565245      565245 2024-10-10 00:00:00+00:00                 realtime.co
# 565260      565260 2024-10-10 00:00:00+00:00            circleof6app.com
# 565439      565439 2024-10-11 00:00:00+00:00  shoeswholesalesuppliers.us
# 565683      565683 2024-10-11 00:00:00+00:00               itwissen.info
#
#           price_usd  web3  domain_length  num_vowels  num_consonants   tld  \
# 0      1,100,000.00     0              9           3               5   com
# 1      3,250,000.00     0             13           5               7   com
# 2      1,500,000.00     0              7           1               5   com
# 3      2,500,000.00     0              7           2               4   com
# 5      2,200,000.00     0              9           4               4   com
# ...             ...   ...            ...         ...             ...   ...
# 565120       460.00     0             11           4               6   com
# 565245     3,383.00     0             11           5               5    co
# 565260     2,309.00     0             16           5               9   com
# 565439       205.00     0             26          10              15    us
# 565683     6,938.00     0             13           5               7  info
#
#         word_count  ...  tld_length  is_brandable  levenshtein_distance  \
# 0                1  ...           3             0                     1
# 1                1  ...           3             0                     0
# 2                1  ...           3             0                     2
# 3                1  ...           3             0                     1
# 5                1  ...           3             0                     2
# ...            ...  ...         ...           ...                   ...
# 565120           1  ...           3             0                     3
# 565245           1  ...           2             0                     2
# 565260           1  ...           3             0                     6
# 565439           1  ...           2             0                    14
# 565683           1  ...           4             0                     4
#
#         is_subdomain  domain_entropy    rank tld_weight  7d_rolling_avg_price  \
# 0                  0            2.95   75007          1            622,779.22
# 1                  0            3.18    6188          1            465,643.35
# 2                  0            2.81  903841          1            836,411.67
# 3                  0            2.24   15127          1          1,793,551.35
# 5                  0            2.95  852369          1          1,150,697.37
# ...              ...             ...     ...        ...                   ...
# 565120             0            2.91  664783          1                480.57
# 565245             0            3.28  479337          1              2,581.57
# 565260             0            3.45  684382          1              2,507.00
# 565439             0            3.31  663874          1                185.14
# 565683             0            3.03  386036          1              5,620.71
#
#         7d_sales_volume  7d_rolling_std_dev
# 0          4,359,454.53        1,228,655.56
# 1          3,259,503.47        1,227,787.88
# 2          5,854,881.72        1,233,249.92
# 3         12,554,859.42        1,048,390.72
# 5          8,054,881.62        1,264,502.04
# ...                 ...                 ...
# 565120         3,364.00               21.05
# 565245        18,071.00              623.57
# 565260        17,549.00              289.28
# 565439         1,296.00               17.05
# 565683        39,345.00            3,634.99
#
# [2366 rows x 21 columns]

# %% [markdown]
# domain_rankings = pd.read_csv('../data/tranco_5863N.csv')
# google_rank = pd.DataFrame({'rank': [1], 'domain': ['google.com']})
# domain_rankings.columns = ['rank','domain']
#
# # Concatenate the new row with the original domain rankings
# domain_rankings = pd.concat([google_rank, domain_rankings], ignore_index=True)
#
# # Reset the index and display the updated rankings
# domain_rankings.reset_index(drop=True, inplace=True)
#
# domain_rankings['domain'].head(500).values

# %% [markdown]
# # Sales

# %%
from models.model import train_model

# %%
combined_dataset
# Out:
#         Unnamed: 0                        dt                       domain  \
# 0                0 1999-04-01 00:00:00+00:00                    bingo.com
# 1                1 1999-04-01 00:00:00+00:00                altavista.com
# 2                2 1999-11-01 00:00:00+00:00                      fly.com
# 3                3 1999-12-01 00:00:00+00:00                      tom.com
# 4                4 1999-12-01 00:00:00+00:00                  england.com
# ...            ...                       ...                          ...
# 565729      565729 2024-10-12 00:00:00+00:00            revenueserver.com
# 565730      565730 2024-10-12 00:00:00+00:00                alt-minds.com
# 565731      565731 2024-10-12 00:00:00+00:00  amazingusambaratrekking.com
# 565732      565732 2024-10-12 00:00:00+00:00                  👨‍⚕️.eth ⚠️
# 565733      565733 2024-10-12 00:00:00+00:00                       117.tv
#
#           price_usd  web3  domain_length  num_vowels  num_consonants     tld  \
# 0      1,100,000.00     0              9           3               5     com
# 1      3,250,000.00     0             13           5               7     com
# 2      1,500,000.00     0              7           1               5     com
# 3      2,500,000.00     0              7           2               4     com
# 4      2,000,000.00     0             11           3               7     com
# ...             ...   ...            ...         ...             ...     ...
# 565729       105.00     0             17           7               9     com
# 565730       105.00     0             13           3               8     com
# 565731       100.00     0             27          10              16     com
# 565732     4,859.42     1             11           1               2  eth ⚠️
# 565733     2,025.00     0              6           0               2      tv
#
#         word_count  ...  tld_length  is_brandable  levenshtein_distance  \
# 0                1  ...           3             0                     1
# 1                1  ...           3             0                     0
# 2                1  ...           3             0                     2
# 3                1  ...           3             0                     1
# 4                1  ...           3             0                     2
# ...            ...  ...         ...           ...                   ...
# 565729           1  ...           3             0                     5
# 565730           2  ...           3             0                     4
# 565731           1  ...           3             0                    14
# 565732           1  ...           6             0                     4
# 565733           1  ...           2             0                     2
#
#         is_subdomain  domain_entropy      rank tld_weight  \
# 0                  0            2.95     75007          1
# 1                  0            3.18      6188          1
# 2                  0            2.81    903841          1
# 3                  0            2.24     15127          1
# 4                  0            3.28  unranked          1
# ...              ...             ...       ...        ...
# 565729             0            3.01  unranked          1
# 565730             0            3.55  unranked          1
# 565731             0            3.78  unranked          1
# 565732             0            3.28  unranked          1
# 565733             0            2.25  unranked          1
#
#         7d_rolling_avg_price  7d_sales_volume  7d_rolling_std_dev
# 0                 622,779.22     4,359,454.53        1,228,655.56
# 1                 465,643.35     3,259,503.47        1,227,787.88
# 2                 836,411.67     5,854,881.72        1,233,249.92
# 3               1,793,551.35    12,554,859.42        1,048,390.72
# 4               1,436,408.50    10,054,859.52        1,184,598.24
# ...                      ...              ...                 ...
# 565729                288.14         2,017.00              209.08
# 565730                227.71         1,594.00              188.30
# 565731                170.00         1,190.00              146.86
# 565732              1,881.22        13,168.55            2,351.85
# 565733                386.57         2,706.00              722.67
#
# [565734 rows x 21 columns]

# %%
results = train_model(X, y, prophet_features, gen_features, target, combined_dataset, features, web3_data, X_web3, y_web3, seed=seed, web3=fine_tuning_web3)
# Out:
# prophet features: Index(['7d_rolling_avg_price', '7d_rolling_std_dev', '7d_sales_volume',
#        'Unnamed: 0', 'domain', 'domain_entropy', 'domain_length',
#        'has_numbers', 'is_brandable', 'is_subdomain', 'levenshtein_distance',
#        'num_consonants', 'num_vowels', 'rank', 'tld', 'tld_length',
#        'tld_weight', 'web3', 'word_count'],
#       dtype='object')
# Training on Combined Data...
# Index(['Unnamed: 0', 'dt', 'domain', 'price_usd', 'web3', 'domain_length',
#        'num_vowels', 'num_consonants', 'tld', 'word_count', 'has_numbers',
#        'tld_length', 'is_brandable', 'levenshtein_distance', 'is_subdomain',
#        'domain_entropy', 'rank', 'tld_weight', '7d_rolling_avg_price',
#        '7d_sales_volume', '7d_rolling_std_dev'],
#       dtype='object')
# 16:01:28 - cmdstanpy - INFO - Chain [1] start processing
# 16:06:04 - cmdstanpy - INFO - Chain [1] done processing
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 results = train_model(X, y, prophet_features, gen_features, target, combined_dataset, features, web3_data, X_web3, y_web3, seed=seed, web3=fine_tuning_web3)
#
# File e:\Projects\liquid_domains\models\model.py:50, in train_model(X, y, prophet_features, gen_features, target, combined_dataset, features, web3_data, X_web3, y_web3, seed, web3)
#      47 # Train models on entire dataset and save them
#      49 print(f'Training on Combined Data...')
# ---> 50 prophet_model, prophet_features, prophet_metrics = train_prophet_model(prophet_features, combined_dataset, seed)
#      51 ridge_model, ridge_features, ridge_metrics = train_ridge_model(X, y, features, seed)
#      52 randomforest_model, random_forest_features, randomforest_metrics = train_randomforest_model(X, y, features, seed)
#
# File e:\Projects\liquid_domains\models\forecasters.py:320, in train_prophet_model(features, combined_dataset, seed)
#     317 for feature in features:
#     318     future[feature] = test_df[feature].values
# --> 320 forecast = model.predict(future)
#     322 y_true = test_df['y'].values
#     323 y_pred = forecast['yhat'].values
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1275, in Prophet.predict(self, df, vectorized)
#    1273 seasonal_components = self.predict_seasonal_components(df)
#    1274 if self.uncertainty_samples:
# -> 1275     intervals = self.predict_uncertainty(df, vectorized)
#    1276 else:
#    1277     intervals = None
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1440, in Prophet.predict_uncertainty(self, df, vectorized)
#    1428 def predict_uncertainty(self, df: pd.DataFrame, vectorized: bool) -> pd.DataFrame:
#    1429     """Prediction intervals for yhat and trend.
#    1430
#    1431     Parameters
#    (...)
#    1438     Dataframe with uncertainty intervals.
#    1439     """
# -> 1440     sim_values = self.sample_posterior_predictive(df, vectorized)
#    1442     lower_p = 100 * (1.0 - self.interval_width) / 2
#    1443     upper_p = 100 * (1.0 + self.interval_width) / 2
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1478, in Prophet.sample_posterior_predictive(self, df, vectorized)
#    1476 for i in range(n_iterations):
#    1477     if vectorized:
# -> 1478         sims = self.sample_model_vectorized(
#    1479             df=df,
#    1480             seasonal_features=seasonal_features,
#    1481             iteration=i,
#    1482             s_a=component_cols['additive_terms'],
#    1483             s_m=component_cols['multiplicative_terms'],
#    1484             n_samples=samp_per_iter
#    1485         )
#    1486     else:
#    1487         sims = [
#    1488             self.sample_model(
#    1489                 df=df,
#    (...)
#    1494             ) for _ in range(samp_per_iter)
#    1495         ]
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1554, in Prophet.sample_model_vectorized(self, df, seasonal_features, iteration, s_a, s_m, n_samples)
#    1552 Xb_m = np.matmul(seasonal_features.values, beta * s_m.values)
#    1553 # Get the future trend, which is stochastic per iteration
# -> 1554 trends = self.sample_predictive_trend_vectorized(df, n_samples, iteration)  # already on the same scale as the actual data
#    1555 sigma = self.params['sigma_obs'][iteration]
#    1556 noise_terms = np.random.normal(0, sigma, trends.shape) * self.y_scale
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1639, in Prophet.sample_predictive_trend_vectorized(self, df, n_samples, iteration)
#    1637 else:
#    1638     raise NotImplementedError
# -> 1639 uncertainty = self._sample_uncertainty(df, n_samples, iteration)
#    1640 return (
#    1641     (np.tile(expected, (n_samples, 1)) + uncertainty) * self.y_scale +
#    1642     np.tile(df["floor"].values, (n_samples, 1))
#    1643 )
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1676, in Prophet._sample_uncertainty(self, df, n_samples, iteration)
#    1674 mean_delta = np.mean(np.abs(deltas)) + 1e-8
#    1675 if self.growth == "linear":
# -> 1676     mat = self._make_trend_shift_matrix(mean_delta, change_likelihood, n_length, n_samples=n_samples)
#    1677     uncertainties = mat.cumsum(axis=1).cumsum(axis=1)  # from slope changes to actual values
#    1678     uncertainties *= single_diff  # scaled by the actual meaning of the slope
#
# File e:\Projects\liquid_domains\liquid_domains_env\Lib\site-packages\prophet\forecaster.py:1716, in Prophet._make_trend_shift_matrix(mean_delta, likelihood, future_length, n_samples)
#    1714 mat = shift_values * bool_slope_change
#    1715 n_mat = np.hstack([np.zeros((len(mat), 1)), mat])[:, :-1]
# -> 1716 mat = (n_mat + mat) / 2
#    1717 return mat
#
# MemoryError: Unable to allocate 863. MiB for an array with shape (1000, 113093) and data type float64

# %%
# os.chdir('..')
print(os.getcwd())

# %% [markdown]
# os.chdir('data')
# print(os.getcwd())

# %% [markdown]
# # Valuation Model

# %%
from sklearn.ensemble import RandomForestRegressor
import joblib

# %%
prophet_model = joblib.load('../pkl/prophet_model.pkl')
ridge_model = joblib.load('../pkl/ridge_model.pkl')
randomforest_model = joblib.load('../pkl/randomforest_model.pkl')

# %%
from models.forecasters import Prophet_Domain_Valuator, Domain_Valuator

# %%
prophet_features

# %%
combined_dataset['dt']

# %%
def main(domain, prophet_model, ridge_model, randomforest_model, combined_dataset, prophet_features, gen_features, features, X, y,seed=seed,ensamble_method = 'median'):
    set_random_seed(seed)

    prophet_features_data = combined_dataset.copy()
    prophet_features_data.rename(columns={"dt": "ds", "price_usd": "y"}, inplace=True)

    prophet_valuator = Prophet_Domain_Valuator(domain, prophet_features, prophet_features_data)
    prophet_valuator.model_prep()
    prophet_domain_value = prophet_valuator.value_domain(prophet_model)

    features_data = combined_dataset.copy()
    features_data['dt'] = features_data['dt'].dt.tz_localize(None)
    features_data = features_data[features] 

    ridge_valuator = Domain_Valuator(domain, X, y, gen_features, features_data, seed)
    ridge_valuator.model_prep()
    ridge_domain_value = ridge_valuator.value_domain(ridge_model)

    randomforest_valuator = Domain_Valuator(domain, X, y, gen_features, features_data, seed)
    randomforest_valuator.model_prep()
    randomforest_domain_value = randomforest_valuator.value_domain(randomforest_model)

    individual_predictions = [
        prophet_domain_value,
        ridge_domain_value,
        randomforest_domain_value
    ]

    if ensamble_method == 'mean':
        ensemble_domain_value = np.mean(individual_predictions)
    elif ensamble_method == 'median':
        ensemble_domain_value = np.median(individual_predictions)

    print(f'individual valuations: {individual_predictions}')
    print(f'ensamble value: {ensemble_domain_value}')

    if ensemble_domain_value < 0:
        print(f'Defaulting from Negative to $0')
        ensemble_domain_value = 0


    return ensemble_domain_value

# %%
domain = 'google.com'

# %%
combined_dataset[combined_dataset['is_brandable']==1]

# %%
value = main(domain=domain, prophet_model=prophet_model, ridge_model=ridge_model, randomforest_model=randomforest_model, combined_dataset=combined_dataset, prophet_features=prophet_features, gen_features=gen_features, features=features, X=X, y=y,ensamble_method='mean')

# %% [markdown]
# from sklearn.model_selection import GridSearchCV
#
# # Define TLD weight grid
# param_grid = {
#     'tld_weight': [{'com': w_com, 'net': w_net, 'org': w_org, 'eth': w_eth}
#                    for w_com in [1.0, 1.5, 2.0]
#                    for w_net in [0.8, 1.2, 1.5]
#                    for w_org in [1.0, 1.5, 2.0]
#                    for w_eth in [1.0, 2.0, 3.0]]
# }
#
# grid_search = GridSearchCV(estimator=model_pipeline, param_grid=param_grid, cv=5)
# grid_search.fit(X, y)
# best_weights = grid_search.best_params_

# %%
params = {
    "New API Data":api,
    "Used web2 Data":web2_data,
    "Used threshold for correlation value":threshold,
    "Used temporals":temporals,
    "Fine tuned on web3 data":fine_tuning_web3,
    "Domain":domain,
    "Ensamble Value":value
}

params_df = pd.DataFrame([params])

# %%
today = dt.datetime.today().strftime("%d-%m-%y-%H-%M-%S")

today = str(today)

# results_df = pd.DataFrame([results])

# combined_df = pd.concat([results_df, params_df], axis=1)

combined_df = params_df.copy()

combined_df.to_csv(f'../data/results_{today}.csv')

print(combined_df)

# %%
liquidity_discount = 0.3 #If we want to discount 90%, we only take 10% of value 

discounted_value = value * liquidity_discount

liquidity_discount_filtered = 1 - liquidity_discount

print(f'Domain: {domain} \nValue: ${value:,.2f} \nLiquidity Discount: {liquidity_discount_filtered*100:.2f}% \nDiscounted Price w/ Liquidity Discount: ${discounted_value:,.2f}')

# %%
subdomain_values = combined_dataset[combined_dataset['is_subdomain']==1]['domain'].unique()

# %%
subdomain_struct = enumerate(subdomain_values)

# %% [markdown]
# for idx, val in enumerate(subdomain_values):
#     print(f'val: {val}')

# %%
combined_dataset['tld'].unique()

# %%
def search(domain, tld, liquidity_discount=0.3,ensamble_method='median'):
    web3_tlds = ['.op', '.crypto', '.box', '.eth', '.base', '.nft', '.wallet', '.coin', '.finance', '.xyz', '.dao', '.bitcoin', '.blockchain']

    print(f'domain: {domain}')
    print(f'tld: {tld}')

    # Allow subdomains, so no error for dot in domain
    # Check if the TLD ends with any of the Web3 TLDs
    if not any(tld.endswith(web3_tld) for web3_tld in web3_tlds):
        raise ValueError('Error: Cannot Value Non-Web3 Domain')

    full_domain = domain + tld
    value = main(domain=full_domain, prophet_model=prophet_model, ridge_model=ridge_model, randomforest_model=randomforest_model, combined_dataset=combined_dataset, prophet_features=prophet_features, gen_features=gen_features, features=features, X=X, y=y,ensamble_method=ensamble_method)

    discounted_value = value * liquidity_discount
    liquidity_discount_filtered = 1 - liquidity_discount

    print(f'Domain: {full_domain} \nValue: ${value:,.2f} \nLiquidity Discount: {liquidity_discount_filtered*100:.2f}% \nDiscounted Price w/ Liquidity Discount: ${discounted_value:,.2f}')
    
    return value, discounted_value

# %%
domain='uniswap'
tld='.crypto'

# %%
search(domain,tld,liquidity_discount=0.5,ensamble_method='mean')

# %%
op_domains = combined_dataset[combined_dataset['tld']=='op']
op_domains.to_csv('../data/op_domains_dataset.csv')

# %% [markdown]
# # combined_dataset[combined_dataset['tld']=='op']
#
#
# for tld in combined_dataset['tld'].unique():
#     print(f'TLD: {tld} \nShape: {combined_dataset[combined_dataset["tld"]==tld].shape}')

# %%
combined_dataset

# %%
num_of_tld = combined_dataset.groupby('tld')['domain'].count().sort_values(ascending = False)

num_of_tld.head(25)

num_of_tld[num_of_tld.index=='net']

# %%
combined_dataset[combined_dataset['tld']=='op'].shape

# %%
web3_data[web3_data.index == web3_data['price_usd'].idxmax()]

# %%
combined_dataset[combined_dataset.index == combined_dataset['price_usd'].idxmax()]

# %%
combined_dataset[combined_dataset['price_usd']==True].describe()

# %%
combined_dataset[combined_dataset['web3']==True].describe()

# %%
combined_dataset[combined_dataset['web3']==False].describe()

# %% [markdown]
# dcc.Input(
#             id='valuator-input',
#             value='example',
#             type='text',
#             style={
#                 'padding': '10px',
#                 'borderRadius': 'var(--wcm-input-border-radius)',
#                 'border': '1px solid var(--color-border)',
#                 'marginRight': '10px'
#             },
#             pattern='[^.]*'  # Regex pattern to disallow '.' character

# %% [markdown]
# # Things to show on front end
# the metrics we already show
# top 10 most sold domains
# top 10 most recent domains
# highest sold domains (top 5 or 10)
# Time series for each top 10 most sold domain
#
# Metrics by web3 == False or True

# %% [markdown]
# # Debugging

# %%
Optimistic_Domains_Sales_query = """
  SELECT
  DATE_TRUNC('HOUR', BLOCK_TIMESTAMP) AS day,
  tokenid,
  price,
  price_usd
FROM
  optimism.nft.ez_nft_sales
WHERE
  NFT_ADDRESS = LOWER('0xC16aCAdf99E4540E6f4E6Da816fd6D2A2C6E1d4F')
  AND event_type = 'sale'
order by
  DATE_TRUNC('HOUR', BLOCK_TIMESTAMP) asc

"""

# %%
optimistic_domains_sales_path = '../data/optimistic_domains_sales.csv'

# %%
optimistic_domains_sales = flipside_api_results(Optimistic_Domains_Sales_query,flipside_api_key)
optimistic_domains_sales.to_csv(optimistic_domains_sales_path, index=False)

# %%
from scripts.apis import alchemy_metadata_api

# %%
eth_price = """

  select
    hour as dt,
    symbol,
    price
  from
    ethereum.price.ez_prices_hourly
  where
    symbol in('WETH')
    AND date_trunc('day', dt) >= '2019-12-01'
  order by
    dt DESC

"""

prices_path = '../data/prices.csv'
prices = flipside_api_results(eth_price, flipside_api_key)
prices.to_csv(prices_path,index=False)

# %% [markdown]
# Optimistic_domains_path = '../data/optimistic_domains_metadata.json'
#
#
#
# optimistic_domains = alchemy_metadata_api(alchemy_api_key, 'optimism', '0xC16aCAdf99E4540E6f4E6Da816fd6D2A2C6E1d4F')
# optimistic_domains.to_json(Optimistic_domains_path, orient='records')

# %%
domain_rankings = pd.read_csv('../data/tranco_5863N.csv')
google_rank = pd.DataFrame({'rank': [1], 'domain': ['google.com']})
domain_rankings.columns = ['rank','domain']

# Concatenate the new row with the original domain rankings
domain_rankings = pd.concat([google_rank, domain_rankings], ignore_index=True)

# Reset the index and display the updated rankings
domain_rankings.reset_index(drop=True, inplace=True)

domain_rankings

# %%
debug_data = pull_data(api=False)

# %%
ens_debug = debug_data['ens']
ens_debug[ens_debug['nft_name']=='mhd.eth'].columns

# %%
ens_debug[ens_debug.index == ens_debug['token_amt_clean'].idxmax()][['dt','token_symbol']]

# %%
ens_debug['token_symbol'] = ens_debug['token_symbol'].str.lower()
ens_debug['token_symbol']

# %%
debug_data['prices_data']

# %%
debug_pd = debug_data['prices_data']

unique_dt = debug_pd['dt'].unique()

# Step 2: Create a new DataFrame with 'USDC' symbol and price 1 for each 'dt'
usdc_rows = pd.DataFrame({
    'dt': unique_dt,
    'symbol': 'USDC',     # Add 'USDC' as the symbol
    'price': 1.0          # Add 1 as the price
})

# Step 3: Concatenate the new rows with the existing DataFrame
debug_pd_combined = pd.concat([debug_pd, usdc_rows], ignore_index=True)

# Step 4: Optional - Sort by 'dt' and reset the row index
debug_pd_combined = debug_pd_combined.sort_values(by='dt').reset_index(drop=True)
debug_pd_combined.rename(columns={'symbol':'token_symbol'},inplace=True)

# %%
debug_pd_combined['token_symbol'] = debug_pd_combined['token_symbol'].str.lower()
debug_pd_combined[['dt','token_symbol']]

# %%
debug_pd_combined['dt'] = pd.to_datetime(debug_pd_combined['dt']).dt.strftime('%Y-%m-%d %H-00-00')
ens_debug['dt'] = pd.to_datetime(ens_debug['dt']).dt.strftime('%Y-%m-%d %H-00-00')

# %%
ens_debug[['dt','token_symbol']]

# %%
ens_debug['dt']

# %%
test = pd.merge(debug_pd_combined,ens_debug,on=['dt','token_symbol'],how='right')
test['price_usd'] = test['token_amt_clean'] * test['price']
test[['nft_name','price_usd']]

# %%
ens_debug[ens_debug['token_symbol']=='eth']
