# %%
import pandas as pd
import numpy as np
import random
import os
import sys
import requests
import time
import datetime as dt


from dotenv import load_dotenv
from flipside import Flipside
from prophet import Prophet

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# from sql_queries.sql_scripts import eth_price

# %%
Optimistic_Domains_Sales_query = """
  SELECT
      DATE_TRUNC('HOUR', BLOCK_TIMESTAMP) AS day, tokenid, price
    FROM
      optimism.nft.ez_nft_sales
    WHERE
      NFT_ADDRESS = LOWER('0xC16aCAdf99E4540E6f4E6Da816fd6D2A2C6E1d4F')
      AND event_type = 'sale'

"""

eth_price = """

  select
    hour as dt,
    symbol,
    price
  from
    ethereum.price.ez_prices_hourly
  where
    symbol in('WETH', 'MATIC')
    AND date_trunc('day', dt) >= '	2022-06-01'
  order by
    dt DESC

"""

# %%
os.chdir('..')
print(os.getcwd())
# Out:
# e:\Projects\liquid_domains

# %%
from scripts.utils import flipside_api_results, set_random_seed
from scripts.pull_data import pull_data
from scripts.data_processing import process_data

# %%
os.chdir('Notebooks')

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
current_directory = os.getcwd()
current_directory
# Out:
# 'e:\\Projects\\liquid_domains\\Notebooks'

# %%
load_dotenv()
# Out:
# True

# %%
seed = 20
set_random_seed(seed)

# %%
flipside_api_key = os.getenv('FLIPSIDE_API_KEY')
alchemy_api_key = os.getenv('ALCHEMY_API_KEY')
opensea_api_key = os.getenv('OPENSEA_API_KEY')

# print(alchemy_api_key)

# %%
api = False
web2_data = True #Includes web2 data in training
threshold = None #Correlation value for correlation analysis
temporals = True #Tends to inflate estimation
fine_tuning_web3 = True #Train again on web3 data only
correlation_analysis = False
last_dataset = True

# %% [markdown]
# # To preview web2 domain data; Kaggle dataset and namebio dataset
#
# domain_path = '../data/domain-name-sales.tsv'
# domain_data = pd.read_csv(domain_path, delimiter='\t')
#
# domain_data.set_index('date', inplace=True)
# domain_data = domain_data.drop(columns=['venue'])
# domain_data.sort_index(inplace=True)
# domain_data
#
# domain_data = domain_data.reset_index()
# domain_data = domain_data.rename(columns={"date":"dt","price":"price_usd"})
# domain_data['dt'] = pd.to_datetime(domain_data['dt'])
# domain_data['dt'] = domain_data['dt'].dt.tz_localize('UTC')
# domain_data['dt'] = pd.to_datetime(domain_data['dt'])
#
# domain_data['web3'] = False
#
# namebio_path = '../data/namebio_sales.csv'
# namebio_data = pd.read_csv(namebio_path)
# namebio_data.set_index('Date', inplace=True)
# namebio_data = namebio_data.drop(columns=['Venue'])
# namebio_data.sort_index(inplace=True)
#
# namebio_data = namebio_data.reset_index()
# namebio_data = namebio_data.rename(columns={"Date":"dt","Price":"price_usd","Domain":"domain"})
# namebio_data['dt'] = pd.to_datetime(namebio_data['dt'])
# namebio_data['dt'] = namebio_data['dt'].dt.tz_localize('UTC')
# namebio_data['dt'] = pd.to_datetime(namebio_data['dt'])
#
# namebio_data['web3'] = False
#
# domain_data = pd.concat([domain_data,namebio_data],ignore_index=True)

# %%
X, y, prophet_features, gen_features, target, combined_dataset, features, web3_data, X_web3, y_web3 = process_data(api=api,web2_data=web2_data,threshold=threshold,temporals=temporals,correlation_analysis=correlation_analysis)
# Out:
# starting process_data
# 6AUlaGmWe505S7gRPZXVh4YEFgJdYHy5
# Loading Existing Data...
# --- ens ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0x61648021e425cf8f4894b69f61a404939ce4b4f4baeb...  ethereum
# 1       sale                                                     ethereum
# 2       sale  0xfba3e32b0bbf57a27d1fe4a07fbd60a82e2e046b01d1...  ethereum
# 3       sale                                                     ethereum
# 4       sale                                                     ethereum
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1728693023
# 1                                                1728691007
# 2  0x0000000000000068f116a894984e2db1123eb395    1728681671
# 3                                                1728677843
# 4                                                1728666623
#
#                                                  nft  quantity  \
# 0  {'identifier': '112759552000644761024343409845...         1
# 1  {'identifier': '311794404914177446451940551923...         1
# 2  {'identifier': '777143408933322316001567537583...         1
# 3  {'identifier': '100157018557711288775784665048...         1
# 4  {'identifier': '555218375765265287494607783285...         1
#
#                                        seller  \
# 0  0xe5857bac6426a1ca0f77901b1cac98494a8e6b2d
# 1  0x72c1bd2c05847f0e2e1c728a70ba76451f0bfe63
# 2  0x4c4672153069e131ae924e08c525ac65ea7e46c4
# 3  0xc0a183eea8112072dc1deaa81b7ad59a3f4a620f
# 4  0x7e2951afc33e3296fcb3704265c22e3d6eeab8db
#
#                                         buyer  \
# 0  0x6053904b1643182f235dd8f1a91e851662d93d35
# 1  0x83b364d8863bbdaba86d085fd09d6f4a03b36c7c
# 2  0xce8181c12bfba4d1c243eead9767780a35908f09
# 3  0x923f8d40629d1858de2262ff41bba52be677fef7
# 4  0x750f5657b0007e97c2f3ea27c28c41cca7f9285e
#
#                                              payment  \
# 0  {'quantity': '1990000000000000000', 'token_add...
# 1  {'quantity': '9000000000000000', 'token_addres...
# 2  {'quantity': '1860000000000000000', 'token_add...
# 3  {'quantity': '20000000000000000', 'token_addre...
# 4  {'quantity': '1500000000000000000', 'token_add...
#
#                                          transaction  event_timestamp  \
# 0  0x35d72e10e0b948b6e705094c2a9a17834473ab311e56...       1728693023
# 1  0x42083af8bca2ac2fbbfc344eacb2b1db7bbeb37e0b4e...       1728691007
# 2  0xf5507f70f67f6bec05ed47166161c6353c7517f17ea6...       1728681671
# 3  0x037fbb2c84a56b2cf6b4bf588286ecd36725ce7a07e0...       1728677843
# 4  0x64eeb6e29d44bcbfc749dfaa66895a74bbb7ac6775b9...       1728666623
#
#                                       nft_identifier     nft_name  \
# 0 112,759,552,000,644,765,072,037,425,393,839,043...  👨‍⚕️.eth ⚠️
# 1 31,179,440,491,417,743,210,438,814,606,478,310,...  ✊🏼✊🏼.eth ⚠️
# 2 77,714,340,893,332,230,817,459,414,514,272,141,...      451.eth
# 3 100,157,018,557,711,294,857,994,736,596,377,966...   sprung.eth
# 4 55,521,837,576,526,526,339,359,089,923,498,481,...  v-bucks.eth
#
#                  token_amt_raw token_symbol  token_decimals  \
# 0 1,990,000,000,000,000,000.00          ETH              18
# 1     9,000,000,000,000,000.00          ETH              18
# 2 1,860,000,000,000,000,000.00         WETH              18
# 3    20,000,000,000,000,000.00          ETH              18
# 4 1,500,000,000,000,000,000.00          ETH              18
#
#                         dt  token_amt_clean
# 0  2024-10-12T00:30:23.000             1.99
# 1  2024-10-11T23:56:47.000             0.01
# 2  2024-10-11T21:21:11.000             1.86
# 3  2024-10-11T20:17:23.000             0.02
# 4  2024-10-11T17:10:23.000             1.50
#
# Tail:
#        event_type                                         order_hash  \
# 222647       sale  0x1a341b8d4a96fa521fce84a724cffad15e88fd2e9d64...
# 222648       sale  0x1a341b8d4a96fa521fce84a724cffad15e88fd2e9d64...
# 222649       sale  0x36b86f5949fb9108f048011f8ff91124f2924a457cbd...
# 222650       sale  0x36b86f5949fb9108f048011f8ff91124f2924a457cbd...
# 222651       sale  0xd4ed9155ced63280ba0d5e16c54e49ab2956911f309c...
#
#            chain                            protocol_address  closing_date  \
# 222647  ethereum  0x00000000006c3852cbef3e08e8df289169ede581    1660907693
# 222648  ethereum  0x00000000006c3852cbef3e08e8df289169ede581    1660907693
# 222649  ethereum  0x00000000006c3852cbef3e08e8df289169ede581    1660907624
# 222650  ethereum  0x00000000006c3852cbef3e08e8df289169ede581    1660907624
# 222651  ethereum  0x00000000006c3852cbef3e08e8df289169ede581    1660907479
#
#                                                       nft  quantity  \
# 222647  {'identifier': '800979678537230422498406109236...         1
# 222648  {'identifier': '800979678537230422498406109236...         1
# 222649  {'identifier': '481108216118856689410282770477...         1
# 222650  {'identifier': '481108216118856689410282770477...         1
# 222651  {'identifier': '840355872414807686514140264904...         1
#
#                                             seller  \
# 222647  0x0703d4d7e2b0fc40da2c8a7ce63211dc95c19249
# 222648  0x0703d4d7e2b0fc40da2c8a7ce63211dc95c19249
# 222649  0xfdbaed3cd99be718581c8462a0ba81a867ce55f7
# 222650  0xfdbaed3cd99be718581c8462a0ba81a867ce55f7
# 222651  0xfdbaed3cd99be718581c8462a0ba81a867ce55f7
#
#                                              buyer  \
# 222647  0xbac7084f8d6e0292a3cdec744259c5a7957dcdeb
# 222648  0xbac7084f8d6e0292a3cdec744259c5a7957dcdeb
# 222649  0x504ee56f8f2e8d5ca0eb36e2cbb3673828818794
# 222650  0x504ee56f8f2e8d5ca0eb36e2cbb3673828818794
# 222651  0x67d8d181bcfd3fa76d6ab5a110437a9116ff16b6
#
#                                                   payment  \
# 222647  {'quantity': '7800000000000000', 'token_addres...
# 222648  {'quantity': '7800000000000000', 'token_addres...
# 222649  {'quantity': '1500000000000000', 'token_addres...
# 222650  {'quantity': '1500000000000000', 'token_addres...
# 222651  {'quantity': '1500000000000000', 'token_addres...
#
#                                               transaction  event_timestamp  \
# 222647                                                          1660907693
# 222648                                                          1660907693
# 222649  0xd8c9b016b1c9c2c6df42cd2bcd1356971ef160538b7e...       1660907624
# 222650                                                          1660907624
# 222651                                                          1660907479
#
#                                            nft_identifier          nft_name  \
# 222647 8,009,796,785,372,304,321,014,678,658,263,914,4...    212-scizor.eth
# 222648 8,009,796,785,372,304,321,014,678,658,263,914,4...    212-scizor.eth
# 222649 48,110,821,611,885,669,318,281,707,834,270,628,...  iamagoodgirl.eth
# 222650 48,110,821,611,885,669,318,281,707,834,270,628,...  iamagoodgirl.eth
# 222651 84,035,587,241,480,771,788,569,292,245,128,613,...      scamsoon.eth
#
#                   token_amt_raw token_symbol  token_decimals  \
# 222647 7,800,000,000,000,000.00          ETH              18
# 222648 7,800,000,000,000,000.00          ETH              18
# 222649 1,500,000,000,000,000.00          ETH              18
# 222650 1,500,000,000,000,000.00          ETH              18
# 222651 1,500,000,000,000,000.00          ETH              18
#
#                              dt  token_amt_clean
# 222647  2022-08-19T11:14:53.000             0.01
# 222648  2022-08-19T11:14:53.000             0.01
# 222649  2022-08-19T11:13:44.000             0.00
# 222650  2022-08-19T11:13:44.000             0.00
# 222651  2022-08-19T11:11:19.000             0.00
#
# ========================================
#
# --- optimistic_domains ---
# Head:
#    tokenId              name
# 0        0        vitalik.op
# 1        1       cardenas.op
# 2        2  davidcardenas.op
# 3        3        bitcoin.op
# 4        4          daffy.op
#
# Tail:
#       tokenId           name
# 1322     1322       trump.op
# 1323     1323        send.op
# 1324     1324        mint.op
# 1325     1325        lock.op
# 1326     1326  avantgarde.op
#
# ========================================
#
# --- Three_DNS_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0xc2f6e5998c936f1e61108cb2b2fbb034bb24fab1fd7f...  optimism
# 1       sale                                                     optimism
# 2       sale  0xbb6757784c322caf280aebad16a2a1e146b2ca6561e2...  optimism
# 3       sale  0x2405ffdc0fe574f4c67e6cb6f73aa559d928331e64a2...  optimism
# 4       sale  0x54f7ab871ce99321d1d76bacc1a96a91d7ce5434555a...  optimism
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1728640937
# 1                                                1728618689
# 2  0x0000000000000068f116a894984e2db1123eb395    1728374131
# 3  0x0000000000000068f116a894984e2db1123eb395    1728373875
# 4  0x0000000000000068f116a894984e2db1123eb395    1728318347
#
#                                                  nft  quantity  \
# 0  {'identifier': '670040026567203581986537479954...         1
# 1  {'identifier': '670040026567203581986537479954...         1
# 2  {'identifier': '959677170388745174648042643274...         1
# 3  {'identifier': '767170620579392153107941902450...         1
# 4  {'identifier': '266179517651107229517413979543...         1
#
#                                        seller  \
# 0  0x84ec0cfbefd2a273136c118942b26de2f9efc6a0
# 1  0x84ec0cfbefd2a273136c118942b26de2f9efc6a0
# 2  0xf6c6dca0fc24ac1c492a5ce307ba24e66261d235
# 3  0xf8d7d866ddfe616157b4fcd871e863c7c1be8c6d
# 4  0x2acda2f4dd7e828874130f66376daad146a190e5
#
#                                         buyer  \
# 0  0x104423799c2f1606dcc68edd2f566ca4ae618c24
# 1  0x104423799c2f1606dcc68edd2f566ca4ae618c24
# 2  0xb98de9e9edebb7f3bde66e21493d20bc0c2004e1
# 3  0xb98de9e9edebb7f3bde66e21493d20bc0c2004e1
# 4  0xea9b191c6fb5cde98d216503539753acdff8aeee
#
#                                              payment  \
# 0  {'quantity': '820000000000000', 'token_address...
# 1  {'quantity': '800000000000000', 'token_address...
# 2  {'quantity': '100000000000000', 'token_address...
# 3  {'quantity': '100000000000000', 'token_address...
# 4  {'quantity': '300000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0x75473f5c35c76777fa1502c8cfdbb71427c42ff84881...       1728640937
# 1  0xf8b5788a0c2ab4f3e2796762946f3a276edda6a682b3...       1728618689
# 2  0x6cbffbc5257d19c6c9ca807c8f0d8aacc1a5e0c1547d...       1728374131
# 3  0xe8aad8baa79ae6c5a89e90bda921dc0e4fc0dcef172f...       1728373875
# 4  0xee4567375d4659346dcc59052a86f5dd88dc8ac27176...       1728318347
#
#                                       nft_identifier          nft_name  \
# 0 67,004,002,656,720,352,249,700,323,626,544,493,...   intra.super.box
# 1 67,004,002,656,720,352,249,700,323,626,544,493,...   intra.super.box
# 2 95,967,717,038,874,516,058,563,922,361,054,680,...        3lfiko.xyz
# 3 76,717,062,057,939,212,449,783,147,581,141,637,...  positiveaura.xyz
# 4 26,617,951,765,110,724,084,811,562,641,290,570,...    0x7n.chain.box
#
#            token_amt_raw token_symbol  token_decimals             dt  \
# 0 820,000,000,000,000.00          ETH              18  1728640937000
# 1 800,000,000,000,000.00          ETH              18  1728618689000
# 2 100,000,000,000,000.00          ETH              18  1728374131000
# 3 100,000,000,000,000.00          ETH              18  1728373875000
# 4 300,000,000,000,000.00          ETH              18  1728318347000
#
#    token_amt_clean
# 0             0.00
# 1             0.00
# 2             0.00
# 3             0.00
# 4             0.00
#
# Tail:
#     event_type                                         order_hash     chain  \
# 290       sale  0x8bde44f2d46537cf8d025cc498eaf7bdeadce3631f15...  optimism
# 291       sale  0xc0547b5b8d575e3ba16b529ee2530a35c437bc75fa93...  optimism
# 292       sale  0xff4b9bdd3f140f8211864ef34e0a07ea0a92eaf98f7d...  optimism
# 293       sale  0x03188e15aaf9596307117e30355f6b2ac79665fbd1c2...  optimism
# 294       sale  0x3cd7cfda4dd935529af2c4f882476b40cc37340ae2a6...  optimism
#
#                                protocol_address  closing_date  \
# 290  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706970257
# 291  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706653465
# 292  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1706203283
# 293  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1704080589
# 294  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1703624873
#
#                                                    nft  quantity  \
# 290  {'identifier': '260923785748676206958654735781...         1
# 291  {'identifier': '566479911085778512201556021651...         1
# 292  {'identifier': '364706086468987072255605061503...         1
# 293  {'identifier': '992340878683635895851755157396...         1
# 294  {'identifier': '686186082504474765846111255346...         1
#
#                                          seller  \
# 290  0xcc0e0b9ebd4ce352f5a50b3ae77ea01202c284ee
# 291  0x240ad467a71210629d71d4de22ebde27951c83fc
# 292  0x7b363822d744143d51c69b0757165c987a6e4ef4
# 293  0x31b32020fb1bdf0228c58b80590f07b235f2b0ce
# 294  0xff3d39f7766ebb57a4175b6d919937409f6d6fee
#
#                                           buyer  \
# 290  0xc48a8ac51df7b71e500a5580b89e47ab26ca1472
# 291  0x82eb45562f991329ed2867f43fc60f0ba52c3dab
# 292  0xe68e8cc7ff772b026c062b9cc28246676d044947
# 293  0x64233eaa064ef0d54ff1a963933d0d2d46ab5829
# 294  0x46f09888867c8cd9042b943099663e856e43de46
#
#                                                payment  \
# 290  {'quantity': '1000000000000000', 'token_addres...
# 291  {'quantity': '110000000000000000', 'token_addr...
# 292  {'quantity': '10000000000000000', 'token_addre...
# 293  {'quantity': '150000000000000000', 'token_addr...
# 294  {'quantity': '22000000000000000', 'token_addre...
#
#                                            transaction  event_timestamp  \
# 290  0x60e952a8e0fa8d052791b2e4a22fd52eb3c759511e62...       1706970257
# 291  0x6672189deb7829838aabba20ddeb66a3cb5fee5b55a2...       1706653465
# 292  0xd8e71f4d52c43fa770b9aa7ad7d5cfb073f04c7495e0...       1706203283
# 293  0x186d1ceacf620bab710d11cf928b79e5dd46790ff1d5...       1704080589
# 294  0x1c7ed62756b60a73470fa39ea6546510ad426e261d14...       1703624873
#
#                                         nft_identifier            nft_name  \
# 290 26,092,378,574,867,619,527,232,167,678,805,405,...             696.box
# 291 56,647,991,108,577,850,953,984,972,492,538,466,...         opensea.box
# 292 36,470,608,646,898,707,880,068,503,761,534,760,...           08000.xyz
# 293 99,234,087,868,363,590,418,701,991,799,513,400,...        2024.finance
# 294 68,618,608,250,447,471,069,153,845,880,935,638,...  topdomains.finance
#
#                  token_amt_raw token_symbol  token_decimals             dt  \
# 290   1,000,000,000,000,000.00         WETH              18  1706970257000
# 291 110,000,000,000,000,000.00         WETH              18  1706653465000
# 292  10,000,000,000,000,000.00          ETH              18  1706203283000
# 293 150,000,000,000,000,000.00          ETH              18  1704080589000
# 294  22,000,000,000,000,000.00          ETH              18  1703624873000
#
#      token_amt_clean
# 290             0.00
# 291             0.11
# 292             0.01
# 293             0.15
# 294             0.02
#
# ========================================
#
# --- base_domains_metadata_pd ---
# Head:
#   event_type                                         order_hash chain  \
# 0       sale                                                     base
# 1       sale                                                     base
# 2       sale  0x33ae71063dd94cc25ce5da7955195741ef2c23404c38...  base
# 3       sale  0x18721e62910111674c377b1ff640f792178caa431edd...  base
# 4       sale                                                     base
#
#                              protocol_address  closing_date  \
# 0                                                1728690881
# 1                                                1728690771
# 2  0x0000000000000068f116a894984e2db1123eb395    1727814517
# 3  0x0000000000000068f116a894984e2db1123eb395    1726543153
# 4                                                1726532239
#
#                                                  nft  quantity  \
# 0  {'identifier': '23382', 'collection': 'basedom...         1
# 1  {'identifier': '23380', 'collection': 'basedom...         1
# 2  {'identifier': '20141', 'collection': 'basedom...         1
# 3  {'identifier': '10545', 'collection': 'basedom...         1
# 4  {'identifier': '23991', 'collection': 'basedom...         1
#
#                                        seller  \
# 0  0xcc0d8f409b149b92c089b5a9177331338671501c
# 1  0xcc0d8f409b149b92c089b5a9177331338671501c
# 2  0x3fe632db0fca7e31b24680ec9f2031a80a221382
# 3  0xdf5226b9dadd9fc2ad91c61bb5f51532a115eb8c
# 4  0xd63dca620e6d0c10dc5268fa86b119f58650e78f
#
#                                         buyer  \
# 0  0xc2e3d9f054a494b228d44b78781eb03ca6e05c35
# 1  0xc2e3d9f054a494b228d44b78781eb03ca6e05c35
# 2  0x40686b23f81a8f7daab759801b1ca71c9bdc18ce
# 3  0xcec0acf3ff46ef6ba322ea567b09b8f82b1b3edc
# 4  0x090c6f36df8a3a803bcbbe5fb26a91d036fe669d
#
#                                              payment  \
# 0  {'quantity': '40000000000000', 'token_address'...
# 1  {'quantity': '40000000000000', 'token_address'...
# 2  {'quantity': '400000000000000', 'token_address...
# 3  {'quantity': '500000000000000', 'token_address...
# 4  {'quantity': '35100000000000', 'token_address'...
#
#                                          transaction  event_timestamp  \
# 0  0x90bcc6b5250358d820e1efea1c462fb9328e076e0d1b...       1728690881
# 1  0x8dcc0fc8bdaab919236a436afd41560c144146865ef1...       1728690771
# 2  0xadfd8edefa865ddbab048f77b09dbd089fb2f6ddb4af...       1727814517
# 3  0x83054ebe875f3bf61a793dba260fa17ca6c1972fed90...       1726543153
# 4  0x87795b325b127e48f75e508f27afad8fe8ff60ad241f...       1726532239
#
#    nft_identifier          nft_name    token_amt_raw token_symbol  \
# 0           23382     baseluke.base   40000000000000          ETH
# 1           23380     luke0909.base   40000000000000          ETH
# 2           20141  Motilalsahu.base  400000000000000          ETH
# 3           10545        dread.base  500000000000000          ETH
# 4           23991        0xbsc.base   35100000000000         WETH
#
#    token_decimals             dt  token_amt_clean
# 0              18  1728690881000             0.00
# 1              18  1728690771000             0.00
# 2              18  1727814517000             0.00
# 3              18  1726543153000             0.00
# 4              18  1726532239000             0.00
#
# Tail:
#     event_type                                         order_hash chain  \
# 104       sale  0x179558a1e2b1588b041e77960b7c415339db8d055f29...  base
# 105       sale  0x3b6a002b6daf8e3218cf5d8d858d482c4076d88d3fcc...  base
# 106       sale  0x6a9be1bc39c943a96d0f7c7afce10082d4f295f0adfa...  base
# 107       sale  0xb4693b06b1c088276aaff2c83e8b736272fad0e1bd19...  base
# 108       sale  0xb7b5e18955103fa4ca87d37d44c18362867a6b3fbca4...  base
#
#                                protocol_address  closing_date  \
# 104  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691618587
# 105  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691616539
# 106  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691613043
# 107  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691607621
# 108  0x00000000000000adc04c56bf30ac9d3c0aaf14dc    1691598979
#
#                                                    nft  quantity  \
# 104  {'identifier': '3505', 'collection': 'basedoma...         1
# 105  {'identifier': '2704', 'collection': 'basedoma...         1
# 106  {'identifier': '4695', 'collection': 'basedoma...         1
# 107  {'identifier': '3204', 'collection': 'basedoma...         1
# 108  {'identifier': '6435', 'collection': 'basedoma...         1
#
#                                          seller  \
# 104  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 105  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 106  0x269f77497956ef4aa79962b54bc715ee62b4c684
# 107  0x037d7dc68b9f46400ee33792aa258612ad5045f1
# 108  0x280ad8a544ca166f4ec2ddc4458aeb194d53e3fb
#
#                                           buyer  \
# 104  0xa2bae9e9fc3af9dc136db6d06be07c7f2e71b5bc
# 105  0x1deacf16b32bd686bea74cff7c382f675c3aa7c1
# 106  0x208e184f3186bc19b1c49a3cae8cbff3142d6e91
# 107  0x570866568da48898755268239c27e34afa575226
# 108  0x96fd61202a698ee3eac21e247a6b209ea5ffeb91
#
#                                                payment  \
# 104  {'quantity': '11000000000000000', 'token_addre...
# 105  {'quantity': '11000000000000000', 'token_addre...
# 106  {'quantity': '2500000000000000', 'token_addres...
# 107  {'quantity': '3500000000000000', 'token_addres...
# 108  {'quantity': '7300000000000000', 'token_addres...
#
#                                            transaction  event_timestamp  \
# 104  0x3064100ce1ab4419c19324f7d83e5b42ab6603e96b15...       1691618587
# 105  0x18e2ed5f6ee64211f19e887197fe104c78becff9dbb6...       1691616539
# 106  0x45819e6cea811e2b858b8dc938cf234e69d24f7b84e6...       1691613043
# 107  0xb5cd43a2d7fb7b4e9acebdc727190c079204c1d23529...       1691607621
# 108  0x2a2ce146c08f0424b8a82448abe1308ff3a9c8ceb9e6...       1691598979
#
#      nft_identifier      nft_name      token_amt_raw token_symbol  \
# 104            3505      rug.base  11000000000000000          ETH
# 105            2704      200.base  11000000000000000          ETH
# 106            4695    manga.base   2500000000000000          ETH
# 107            3204  bullish.base   3500000000000000          ETH
# 108            6435    Clock.base   7300000000000000          ETH
#
#      token_decimals             dt  token_amt_clean
# 104              18  1691618587000             0.01
# 105              18  1691616539000             0.01
# 106              18  1691613043000             0.00
# 107              18  1691607621000             0.00
# 108              18  1691598979000             0.01
#
# ========================================
#
# --- unstoppable_sales_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0xb03f2e78925cde538c10e5fad3bcc6b4e655ae51e003...  ethereum
# 1       sale  0x088e924cb0ef441b0d68821764db063467c572e8f9a1...  ethereum
# 2       sale  0xceb738fa285cf4de22c16c5c676ba026e5ffe84c73b7...  ethereum
# 3       sale  0x1064f829ae8be80b5ad31a1271cdeae52d7e3a44f474...  ethereum
# 4       sale  0xa30969fb217ac7c58101213ac2104bd6598db75d7c5d...  ethereum
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1720198883
# 1  0x0000000000000068f116a894984e2db1123eb395    1718617967
# 2  0x0000000000000068f116a894984e2db1123eb395    1718614055
# 3  0x0000000000000068f116a894984e2db1123eb395    1718613323
# 4  0x0000000000000068f116a894984e2db1123eb395    1718550443
#
#                                                  nft  quantity  \
# 0  {'identifier': '732609744346663118421256248151...         1
# 1  {'identifier': '799288950834081445126736498481...         1
# 2  {'identifier': '720141416088167626284738564926...         1
# 3  {'identifier': '559353050680242471594511596608...         1
# 4  {'identifier': '911899529139068149563600522019...         1
#
#                                        seller  \
# 0  0xd5b43c1d9c145bdf25c163ecf8fa1fe040202adc
# 1  0xcbb58904774cf1bee98741c466aace0206fb090b
# 2  0xcbb58904774cf1bee98741c466aace0206fb090b
# 3  0xcbb58904774cf1bee98741c466aace0206fb090b
# 4  0xcbb58904774cf1bee98741c466aace0206fb090b
#
#                                         buyer  \
# 0  0x84eb2355fc7556e07bbc410be55063bc3b61a006
# 1  0xb54e5bd4a9d9f2a7721136041ba41db77cd90e9a
# 2  0x0a3b0a790ca4f9fbaa2618c548cde45be0249c2f
# 3  0x8be28746913422eef1e255df992b32c702576bdc
# 4  0xeb11c3f006b1fe207f8ec1a153e480db86c3ce4f
#
#                                              payment  \
# 0  {'quantity': '50000000000000', 'token_address'...
# 1  {'quantity': '990000000000000', 'token_address...
# 2  {'quantity': '990000000000000', 'token_address...
# 3  {'quantity': '990000000000000', 'token_address...
# 4  {'quantity': '890000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0xdb0a0ef3662b0975e886b41bf984f03f387ab6edcfa2...       1720198883
# 1  0x6d26ae182bb40d6dd4a7378609061cb046103bd30853...       1718617967
# 2  0x447d7ccb8ccb6eeb7d4dfbb6e838e918639172ac66a9...       1718614055
# 3  0x22369eee55b5313147708ada54f6276be250850f8f7a...       1718613323
# 4  0x25db8dd631e2901f0020dee0f8d826dd1b7f2c22f8b5...       1718550443
#
#                                       nft_identifier  \
# 0 73,260,974,434,666,309,016,726,815,552,216,794,...
# 1 79,928,895,083,408,148,097,614,756,880,763,030,...
# 2 72,014,141,608,816,767,035,628,981,280,910,821,...
# 3 55,935,305,068,024,247,420,483,647,586,810,650,...
# 4 91,189,952,913,906,813,838,813,506,742,274,520,...
#
#                    nft_name          token_amt_raw token_symbol  \
# 0           gaydream.crypto  50,000,000,000,000.00          ETH
# 1    officialdaimler.crypto 990,000,000,000,000.00          ETH
# 2       officialaudi.crypto 990,000,000,000,000.00          ETH
# 3  officialbillgates.crypto 990,000,000,000,000.00          ETH
# 4         scaryterry.crypto 890,000,000,000,000.00          ETH
#
#    token_decimals                       dt  token_amt_clean
# 0              18  2024-07-05T17:01:23.000             0.00
# 1              18  2024-06-17T09:52:47.000             0.00
# 2              18  2024-06-17T08:47:35.000             0.00
# 3              18  2024-06-17T08:35:23.000             0.00
# 4              18  2024-06-16T15:07:23.000             0.00
#
# Tail:
#      event_type order_hash     chain  \
# 3896       sale             ethereum
# 3897       sale             ethereum
# 3898       sale             ethereum
# 3899       sale             ethereum
# 3900       sale             ethereum
#
#                                 protocol_address  closing_date  \
# 3896  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1577178632
# 3897  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1577178582
# 3898  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576900527
# 3899  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576768395
# 3900  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b    1576313422
#
#                                                     nft  quantity  \
# 3896  {'identifier': '860899055054694856908010487707...         1
# 3897  {'identifier': '940569713444058262943635252235...         1
# 3898  {'identifier': '446163175071435156510839745607...         1
# 3899  {'identifier': '176192171829730767798338643850...         1
# 3900  {'identifier': '164502264543840507301076043053...         1
#
#                                           seller  \
# 3896  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3897  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3898  0x8124b02b4967bd7338a450420a572d574915ff9c
# 3899  0xfa4ab967d3ac0b94955b8df63ede213695f38d6f
# 3900  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
#
#                                            buyer  \
# 3896  0x525e89c4d5052d5afb5a7f0884b296b0138adfd4
# 3897  0x525e89c4d5052d5afb5a7f0884b296b0138adfd4
# 3898  0x7c3295b9bb9b689924f2b2882d78eaaed1fd2063
# 3899  0x8124b02b4967bd7338a450420a572d574915ff9c
# 3900  0x519e570344747173c5febde6c2df0c3252175bb3
#
#                                                 payment  \
# 3896  {'quantity': '100000000000000000', 'token_addr...
# 3897  {'quantity': '100000000000000000', 'token_addr...
# 3898  {'quantity': '45000000000000000', 'token_addre...
# 3899  {'quantity': '70000000000000000', 'token_addre...
# 3900  {'quantity': '69900000000000000', 'token_addre...
#
#                                             transaction  event_timestamp  \
# 3896  0xa0349c718c1f794d51d1ba664ee238f2d61dac847e5c...       1577178632
# 3897  0x6f83aa5c2d5377fa88d770d6b6709922fe79d16eb2c5...       1577178582
# 3898  0x068264028eac1e60c0bfc6dac93d65165edaaad19ea6...       1576900527
# 3899  0x0994ef978059265afb7b8c6deb0ac6afe4d6f31b25ba...       1576768395
# 3900  0x60b8773e82dd9f9612f687c925062aa2bc4e2cf8c86f...       1576313422
#
#                                          nft_identifier          nft_name  \
# 3896 86,089,905,505,469,488,148,445,830,396,242,062,...    bittiez.crypto
# 3897 94,056,971,344,405,822,053,661,343,907,032,761,...    bitties.crypto
# 3898 44,616,317,507,143,517,844,109,711,444,778,473,...  impeached.crypto
# 3899 17,619,217,182,973,076,162,112,808,839,711,553,...  ethstaker.crypto
# 3900 16,450,226,454,384,049,539,296,233,940,056,623,...    cryptoq.crypto
#
#                   token_amt_raw token_symbol  token_decimals  \
# 3896 100,000,000,000,000,000.00         WETH              18
# 3897 100,000,000,000,000,000.00         WETH              18
# 3898  45,000,000,000,000,000.00         WETH              18
# 3899  70,000,000,000,000,000.00          ETH              18
# 3900  69,900,000,000,000,000.00          ETH              18
#
#                            dt  token_amt_clean
# 3896  2019-12-24T09:10:32.000             0.10
# 3897  2019-12-24T09:09:42.000             0.10
# 3898  2019-12-21T03:55:27.000             0.04
# 3899  2019-12-19T15:13:15.000             0.07
# 3900  2019-12-14T08:50:22.000             0.07
#
# ========================================
#
# --- optimistic_domains_sales ---
# Head:
#                         day  tokenid  price  price_usd  __row_index
# 0  2022-06-03T04:00:00.000Z      482   0.01      27.47            0
# 1  2022-06-04T02:00:00.000Z      549   0.05      88.79            1
# 2  2022-06-04T02:00:00.000Z      550   0.01      26.64            2
# 3  2022-06-06T14:00:00.000Z      576   0.05      95.46            3
# 4  2022-06-19T00:00:00.000Z      787   0.02      19.68            4
#
# Tail:
#                          day  tokenid  price  price_usd  __row_index
# 12  2022-12-29T07:00:00.000Z      759   0.01      13.15           12
# 13  2023-02-11T03:00:00.000Z      347   0.00       3.79           13
# 14  2023-02-18T19:00:00.000Z      731   0.03      42.32           14
# 15  2023-02-20T21:00:00.000Z      413   0.03      46.02           15
# 16  2023-02-20T21:00:00.000Z     1076   0.05      85.22           16
#
# ========================================
#
# --- optimism_name_service_data ---
# Head:
#   event_type                                         order_hash     chain  \
# 0       sale  0xa5b84471cd09ffe871ccf72178819b04a9e9f2899b45...  optimism
# 1       sale  0xa5b84471cd09ffe871ccf72178819b04a9e9f2899b45...  optimism
# 2       sale  0xa5b84471cd09ffe871ccf72178819b04a9e9f2899b45...  optimism
# 3       sale  0xa5b84471cd09ffe871ccf72178819b04a9e9f2899b45...  optimism
# 4       sale  0xa5b84471cd09ffe871ccf72178819b04a9e9f2899b45...  optimism
#
#                              protocol_address  closing_date  \
# 0  0x0000000000000068f116a894984e2db1123eb395    1727393211
# 1  0x0000000000000068f116a894984e2db1123eb395    1727393211
# 2  0x0000000000000068f116a894984e2db1123eb395    1727393211
# 3  0x0000000000000068f116a894984e2db1123eb395    1727393211
# 4  0x0000000000000068f116a894984e2db1123eb395    1727393211
#
#                                                  nft  quantity  \
# 0  {'identifier': '829861512140454604944751413042...         1
# 1  {'identifier': '573106699312866679939841196346...         1
# 2  {'identifier': '252847519059889457847611790853...         1
# 3  {'identifier': '983360983556807487444203612537...         1
# 4  {'identifier': '773742526247128867942102398045...         1
#
#                                        seller  \
# 0  0x27bcc725962ac4d7c413d009cf5d887b700c20ee
# 1  0x27bcc725962ac4d7c413d009cf5d887b700c20ee
# 2  0x27bcc725962ac4d7c413d009cf5d887b700c20ee
# 3  0x27bcc725962ac4d7c413d009cf5d887b700c20ee
# 4  0x27bcc725962ac4d7c413d009cf5d887b700c20ee
#
#                                         buyer  \
# 0  0x2897be1b8411c248dfaab1186bdd89a3f4b2ffbe
# 1  0x2897be1b8411c248dfaab1186bdd89a3f4b2ffbe
# 2  0x2897be1b8411c248dfaab1186bdd89a3f4b2ffbe
# 3  0x2897be1b8411c248dfaab1186bdd89a3f4b2ffbe
# 4  0x2897be1b8411c248dfaab1186bdd89a3f4b2ffbe
#
#                                              payment  \
# 0  {'quantity': '100000000000000', 'token_address...
# 1  {'quantity': '100000000000000', 'token_address...
# 2  {'quantity': '100000000000000', 'token_address...
# 3  {'quantity': '100000000000000', 'token_address...
# 4  {'quantity': '100000000000000', 'token_address...
#
#                                          transaction  event_timestamp  \
# 0  0x3464b54555336247eb01a3e53d277d6c17aa09cbfecb...       1727393211
# 1  0x3464b54555336247eb01a3e53d277d6c17aa09cbfecb...       1727393211
# 2  0x3464b54555336247eb01a3e53d277d6c17aa09cbfecb...       1727393211
# 3  0x3464b54555336247eb01a3e53d277d6c17aa09cbfecb...       1727393211
# 4  0x3464b54555336247eb01a3e53d277d6c17aa09cbfecb...       1727393211
#
#                                       nft_identifier     nft_name  \
# 0 82,986,151,214,045,461,530,082,862,358,185,376,...   timothy.op
# 1 5,731,066,993,128,667,067,191,611,142,755,089,3...   charles.op
# 2 25,284,751,905,988,947,097,190,703,347,712,673,...  jonathan.op
# 3 98,336,098,355,680,749,582,723,945,672,751,911,...  pocoloco.op
# 4 77,374,252,624,712,887,074,880,736,396,449,538,...   absolut.op
#
#      token_amt_raw token_symbol  token_decimals             dt  \
# 0  100000000000000         WETH              18  1727393211000
# 1  100000000000000         WETH              18  1727393211000
# 2  100000000000000         WETH              18  1727393211000
# 3  100000000000000         WETH              18  1727393211000
# 4  100000000000000         WETH              18  1727393211000
#
#    token_amt_clean
# 0             0.00
# 1             0.00
# 2             0.00
# 3             0.00
# 4             0.00
#
# Tail:
#     event_type                                         order_hash     chain  \
# 753       sale  0x0da4f090909f31862f79a4e76a396766a7fe3e3d8637...  optimism
# 754       sale  0x07f366c8693d6492b394ce78aa1e580a230b6e282d36...  optimism
# 755       sale  0x029b6a83792ed956bff1318490196524c8de7b5d5d74...  optimism
# 756       sale  0x621db398cdef6e0b0737ba21715d07b42927ad838ea4...  optimism
# 757       sale  0xbb5d4c44682316fee95d1dd37d302982ec32f626b5c7...  optimism
#
#                                protocol_address  closing_date  \
# 753  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932343
# 754  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 755  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 756  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677932205
# 757  0x00000000000001ad428e4906ae43d8f9852d0dd6    1677921991
#
#                                                    nft  quantity  \
# 753  {'identifier': '120219272988803680872974995977...         1
# 754  {'identifier': '212128970836456136940270979598...         1
# 755  {'identifier': '248444384559923954980940474589...         1
# 756  {'identifier': '549015022443570801134689433390...         1
# 757  {'identifier': '488099369330375128690249371270...         1
#
#                                          seller  \
# 753  0xaf6d4f2f0f4d08b34182234d6c39865b56ab5b4c
# 754  0x50921467fd9defc962af2636b36867d423244ff8
# 755  0x50921467fd9defc962af2636b36867d423244ff8
# 756  0x50921467fd9defc962af2636b36867d423244ff8
# 757  0xa2bc5e3be3d883879caf9a9f2a610584506fc6dd
#
#                                           buyer  \
# 753  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 754  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 755  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 756  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
# 757  0x2d14e3849b020bfe4d274c71d3bf091df4a44dd1
#
#                                                payment  \
# 753  {'quantity': '2500000000000000', 'token_addres...
# 754  {'quantity': '50000000000000000', 'token_addre...
# 755  {'quantity': '50000000000000000', 'token_addre...
# 756  {'quantity': '50000000000000000', 'token_addre...
# 757  {'quantity': '100000000000000000', 'token_addr...
#
#                                            transaction  event_timestamp  \
# 753  0xdaff73e094af54678a23e9a419d4d7fb53ce76d443e3...       1677932343
# 754  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 755  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 756  0x8c0d484b61b5cbe2d80226f58a689aea6a7b801b18bb...       1677932205
# 757  0xf1c8349d99024e6792525239b4cd655d219957433ec9...       1677921991
#
#                                         nft_identifier       nft_name  \
# 753 12,021,927,298,880,368,312,276,012,569,694,239,...      888666.op
# 754 21,212,897,083,645,615,095,268,562,890,835,548,...  highstreet.op
# 755 24,844,438,455,992,396,859,894,623,792,547,027,...      bitget.op
# 756 54,901,502,244,357,081,727,363,511,107,096,227,...       bybit.op
# 757 48,809,936,933,037,512,706,059,515,308,167,888,...       abcde.op
#
#           token_amt_raw token_symbol  token_decimals             dt  \
# 753    2500000000000000          ETH              18  1677932343000
# 754   50000000000000000          ETH              18  1677932205000
# 755   50000000000000000          ETH              18  1677932205000
# 756   50000000000000000          ETH              18  1677932205000
# 757  100000000000000000          ETH              18  1677921991000
#
#      token_amt_clean
# 753             0.00
# 754             0.05
# 755             0.05
# 756             0.05
# 757             0.10
#
# ========================================
#
# --- prices_data ---
# Head:
#                          dt symbol    price  __row_index
# 0  2024-10-12T13:00:00.000Z  MATIC     0.38            0
# 1  2024-10-12T13:00:00.000Z   WETH 2,455.94            1
# 2  2024-10-12T12:00:00.000Z  MATIC     0.38            2
# 3  2024-10-12T12:00:00.000Z   WETH 2,454.14            3
# 4  2024-10-12T11:00:00.000Z  MATIC     0.38            4
#
# Tail:
#                              dt symbol    price  __row_index
# 41495  2022-06-01T02:00:00.000Z  MATIC     0.67        41495
# 41496  2022-06-01T01:00:00.000Z   WETH 1,945.78        41496
# 41497  2022-06-01T01:00:00.000Z  MATIC     0.66        41497
# 41498  2022-06-01T00:00:00.000Z   WETH 1,954.12        41498
# 41499  2022-06-01T00:00:00.000Z  MATIC     0.67        41499
#
# ========================================
#
# pulled data
# web2 data
# optimistic_domains_sales:                          day  tokenid  price  price_usd  __row_index
# 0   2022-06-03T04:00:00.000Z      482   0.01      27.47            0
# 1   2022-06-04T02:00:00.000Z      549   0.05      88.79            1
# 2   2022-06-04T02:00:00.000Z      550   0.01      26.64            2
# 3   2022-06-06T14:00:00.000Z      576   0.05      95.46            3
# 4   2022-06-19T00:00:00.000Z      787   0.02      19.68            4
# 5   2022-07-13T06:00:00.000Z      902   0.02      21.05            5
# 6   2022-07-13T06:00:00.000Z      915   0.03      26.31            6
# 7   2022-07-28T16:00:00.000Z      850   0.01       8.27            7
# 8   2022-08-04T20:00:00.000Z      932   0.01      21.43            8
# 9   2022-08-04T20:00:00.000Z      933   0.01      22.76            9
# 10  2022-10-13T10:00:00.000Z      413  11.00       7.53           10
# 11  2022-10-28T09:00:00.000Z     1069   0.02      29.98           11
# 12  2022-12-29T07:00:00.000Z      759   0.01      13.15           12
# 13  2023-02-11T03:00:00.000Z      347   0.00       3.79           13
# 14  2023-02-18T19:00:00.000Z      731   0.03      42.32           14
# 15  2023-02-20T21:00:00.000Z      413   0.03      46.02           15
# 16  2023-02-20T21:00:00.000Z     1076   0.05      85.22           16
# e:\Projects\liquid_domains\scripts\data_processing.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   optimism_name_service_data['dt'] = pd.to_datetime(optimism_name_service_data['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Three_DNS_data['dt'] = pd.to_datetime(Three_DNS_data['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ens_data['dt'] = pd.to_datetime(ens_data['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unstoppable_sales_data['dt'] = pd.to_datetime(unstoppable_sales_data['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   base_domains_metadata_pd['dt'] = pd.to_datetime(base_domains_metadata_pd['dt'], unit='ms')
# e:\Projects\liquid_domains\scripts\data_processing.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:212: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:212: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:212: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:212: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = df['dt'].dt.strftime('%Y-%m-%d %H-00-00')
# e:\Projects\liquid_domains\scripts\data_processing.py:212: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dt'] = pd.to_datetime(df['dt'])
# e:\Projects\liquid_domains\scripts\data_processing.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dt'] = pd.to_datetime(df['dt'])
# standardized time
# prices data dt: 0       2022-06-01 00:00:00+00:00
# 1       2022-06-01 01:00:00+00:00
# 2       2022-06-01 02:00:00+00:00
# 3       2022-06-01 03:00:00+00:00
# 4       2022-06-01 04:00:00+00:00
#                    ...
# 20745   2024-10-12 09:00:00+00:00
# 20746   2024-10-12 10:00:00+00:00
# 20747   2024-10-12 11:00:00+00:00
# 20748   2024-10-12 12:00:00+00:00
# 20749   2024-10-12 13:00:00+00:00
# Name: dt, Length: 20750, dtype: datetime64[ns, UTC]
# optimistic_data:                          dt  nft_identifier  price  price_usd  __row_index  \
# 0   2022-06-03T04:00:00.000Z             482   0.01      27.47            0
# 1   2022-06-04T02:00:00.000Z             549   0.05      88.79            1
# 2   2022-06-04T02:00:00.000Z             550   0.01      26.64            2
# 3   2022-06-06T14:00:00.000Z             576   0.05      95.46            3
# 4   2022-06-19T00:00:00.000Z             787   0.02      19.68            4
# 5   2022-07-13T06:00:00.000Z             902   0.02      21.05            5
# 6   2022-07-13T06:00:00.000Z             915   0.03      26.31            6
# 7   2022-07-28T16:00:00.000Z             850   0.01       8.27            7
# 8   2022-08-04T20:00:00.000Z             932   0.01      21.43            8
# 9   2022-08-04T20:00:00.000Z             933   0.01      22.76            9
# 10  2022-10-13T10:00:00.000Z             413  11.00       7.53           10
# 11  2022-10-28T09:00:00.000Z            1069   0.02      29.98           11
# 12  2022-12-29T07:00:00.000Z             759   0.01      13.15           12
# 13  2023-02-11T03:00:00.000Z             347   0.00       3.79           13
# 14  2023-02-18T19:00:00.000Z             731   0.03      42.32           14
# 15  2023-02-20T21:00:00.000Z             413   0.03      46.02           15
# 16  2023-02-20T21:00:00.000Z            1076   0.05      85.22           16
#
#         nft_name
# 0      luxury.op
# 1      prince.op
# 2    princess.op
# 3          17.op
# 4         188.op
# 5         sir.op
# 6        dude.op
# 7        heng.op
# 8         swo.op
# 9         tro.op
# 10        dip.op
# 11       aave.op
# 12  chainlink.op
# 13         lo.op
# 14         74.op
# 15        dip.op
# 16         qx.op
# optimistic_data:                          dt  nft_identifier  token_amt_clean  price_usd  \
# 0  2022-06-03 04:00:00+00:00             482             0.01      27.47
# 1  2022-06-04 02:00:00+00:00             549             0.05      88.79
# 2  2022-06-04 02:00:00+00:00             550             0.01      26.64
# 3  2022-06-06 14:00:00+00:00             576             0.05      95.46
# 4  2022-06-19 00:00:00+00:00             787             0.02      19.68
# 5  2022-07-13 06:00:00+00:00             902             0.02      21.05
# 6  2022-07-13 06:00:00+00:00             915             0.03      26.31
# 7  2022-07-28 16:00:00+00:00             850             0.01       8.27
# 8  2022-08-04 20:00:00+00:00             932             0.01      21.43
# 9  2022-08-04 20:00:00+00:00             933             0.01      22.76
# 10 2022-10-13 10:00:00+00:00             413            11.00       7.53
# 11 2022-10-28 09:00:00+00:00            1069             0.02      29.98
# 12 2022-12-29 07:00:00+00:00             759             0.01      13.15
# 13 2023-02-11 03:00:00+00:00             347             0.00       3.79
# 14 2023-02-18 19:00:00+00:00             731             0.03      42.32
# 15 2023-02-20 21:00:00+00:00             413             0.03      46.02
# 16 2023-02-20 21:00:00+00:00            1076             0.05      85.22
#
#     __row_index      nft_name
# 0             0     luxury.op
# 1             1     prince.op
# 2             2   princess.op
# 3             3         17.op
# 4             4        188.op
# 5             5        sir.op
# 6             6       dude.op
# 7             7       heng.op
# 8             8        swo.op
# 9             9        tro.op
# 10           10        dip.op
# 11           11       aave.op
# 12           12  chainlink.op
# 13           13         lo.op
# 14           14         74.op
# 15           15        dip.op
# 16           16         qx.op
# combined dataset
# adding web2 data
# domain feature engineering
# @ num_vols
# extracting tld
# is_brandable

# %%
combined_dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 combined_dataset
#
# NameError: name 'combined_dataset' is not defined

# %%
combined_dataset[combined_dataset['word_count']>1]
# Out:
#                              dt                       domain  price_usd  web3  \
# 15    2020-01-11 18:00:00+00:00  reseller-test-paul00.crypto       0.15  True
# 167   2020-03-21 21:00:00+00:00           dark-market.crypto      13.19  True
# 168   2020-03-21 22:00:00+00:00              alt-coin.crypto      20.52  True
# 217   2020-03-31 20:00:00+00:00       satoshi-lottery.crypto      79.89  True
# 298   2020-04-08 06:00:00+00:00            awcdik-dik.crypto       0.86  True
# ...                         ...                          ...        ...   ...
# 45373 2024-07-24 19:00:00+00:00           girls-on.chain.box       2.69  True
# 45399 2024-07-25 14:00:00+00:00       memecoins-on.chain.box       1.20  True
# 45474 2024-07-26 17:00:00+00:00            e-transaction.eth       2.61  True
# 45729 2024-07-31 05:00:00+00:00        nintendo-pictures.eth       3.29  True
# 45739 2024-07-31 18:00:00+00:00              meta-humans.eth       1.48  True
#
#        domain_length  num_vowels  num_consonants     tld  word_count  \
# 15                27           7              15  crypto           3
# 167               18           4              12  crypto           2
# 168               15           4               9  crypto           2
# 217               22           6              14  crypto           2
# 298               17           4              11  crypto           2
# ...              ...         ...             ...     ...         ...
# 45373             18           5              10     box           2
# 45399             22           8              11     box           2
# 45474             17           6               9     eth           2
# 45729             21           7              12     eth           2
# 45739             15           5               8     eth           2
#
#        has_numbers  tld_length  is_brandable  levenshtein_distance  \
# 15            True           6             0                    12
# 167          False           6             0                     3
# 168          False           6             1                     3
# 217          False           6             0                     5
# 298          False           6             0                     6
# ...            ...         ...           ...                   ...
# 45373        False           3             0                     4
# 45399        False           3             1                     6
# 45474        False           3             0                     5
# 45729        False           3             0                     9
# 45739        False           3             1                     5
#
#        is_subdomain  domain_entropy      rank  tld_weight
# 15                0            3.63  unranked           1
# 167               0            3.57  unranked           1
# 168               0            3.51  unranked           1
# 217               0            3.61  unranked           1
# 298               0            3.62  unranked           1
# ...             ...             ...       ...         ...
# 45373             1            3.73  unranked           1
# 45399             1            3.57  unranked           1
# 45474             0            3.45  unranked           1
# 45729             0            3.62  unranked           1
# 45739             0            3.24  unranked           1
#
# [1335 rows x 17 columns]

# %%
combined_dataset[combined_dataset['rank']!='unranked']
# Out:
# Empty DataFrame
# Columns: [dt, domain, price_usd, web3, domain_length, num_vowels, num_consonants, tld, word_count, has_numbers, tld_length, is_brandable, levenshtein_distance, is_subdomain, domain_entropy, rank, tld_weight]
# Index: []

# %%
domain_rankings = pd.read_csv('../data/tranco_5863N.csv')
google_rank = pd.DataFrame({'rank': [1], 'domain': ['google.com']})
domain_rankings.columns = ['rank','domain']

# Concatenate the new row with the original domain rankings
domain_rankings = pd.concat([google_rank, domain_rankings], ignore_index=True)

# Reset the index and display the updated rankings
domain_rankings.reset_index(drop=True, inplace=True)

domain_rankings['domain'].head(500).values
# Out:
# array(['google.com', 'amazonaws.com', 'microsoft.com', 'facebook.com',
#        'akamai.net', 'apple.com', 'root-servers.net', 'a-msedge.net',
#        'youtube.com', 'googleapis.com', 'azure.com', 'akamaiedge.net',
#        'twitter.com', 'cloudflare.com', 'instagram.com', 'gstatic.com',
#        'office.com', 'linkedin.com', 'live.com', 'gtld-servers.net',
#        'tiktokcdn.com', 'googletagmanager.com', 'googlevideo.com',
#        'akadns.net', 'windowsupdate.com', 'googleusercontent.com',
#        'doubleclick.net', 'fbcdn.net', 'microsoftonline.com',
#        'amazon.com', 'trafficmanager.net', 'wikipedia.org', 'bing.com',
#        'l-msedge.net', 'apple-dns.net', 'fastly.net', 'office.net',
#        'googlesyndication.com', 'mail.ru', 'icloud.com', 'wordpress.org',
#        'sharepoint.com', 't-msedge.net', 'youtu.be', 'github.com',
#        'netflix.com', 'aaplimg.com', 'whatsapp.net', 'domaincontrol.com',
#        'pinterest.com', 'yahoo.com', 'digicert.com', 's-msedge.net',
#        'appsflyersdk.com', 'adobe.com', 'cloudfront.net', 'goo.gl',
#        'windows.net', 'gvt2.com', 'spotify.com', 'vimeo.com',
#        'google-analytics.com', 'tiktokv.com', 'cdn77.org', 'gvt1.com',
#        'whatsapp.com', 'skype.com', 'wac-msedge.net', 'bit.ly', 'zoom.us',
#        'yandex.net', 'msn.com', 'gandi.net', 'wordpress.com', 'ntp.org',
#        'nic.ru', 'cloudflare.net', 'office365.com',
#        'bytefcdn-oversea.com', 'roblox.com', 'qq.com', 'ytimg.com',
#        'edgekey.net', 'tiktok.com', 'blogspot.com', 'mozilla.org',
#        'cloudflare-dns.com', 'opera.com', 'reddit.com', 'unity3d.com',
#        'cdninstagram.com', 'googleadservices.com', 'e2ro.com',
#        'intuit.com', 'baidu.com', 'lencr.org', 'snapchat.com',
#        'comcast.net', 'ax-msedge.net', 'googledomains.com', 'x.com',
#        'europa.eu', 'amazon-adsystem.com', 'mts.ru', 'a2z.com',
#        'samsung.com', 't.me', 'app-analytics-services.com', 'wa.me',
#        'rocket-cdn.com', 'outlook.com', 'macromedia.com',
#        'bytefcdn-ttpeu.com', 'nih.gov', 'dropbox.com', 'tumblr.com',
#        'gravatar.com', 'msedge.net', 'app-measurement.com', 'sentry.io',
#        'trbcdn.net', 'vk.com', 'ui.com', 'dns.google', 'aiv-cdn.net',
#        'github.io', 'userapi.com', 'windows.com', 'edgesuite.net',
#        'rbxcdn.com', 'nytimes.com', 'spo-msedge.net', 'one.one',
#        'msftncsi.com', 'epicgames.com', 'telecid.ru', 'xiaomi.com',
#        'ggpht.com', 'forms.gle', 'webex.com', 'ttlivecdn.com',
#        'apache.org', 'dual-s-msedge.net', 'nist.gov', 'adnxs.com',
#        'archive.org', 'applovin.com', 'b-msedge.net', 'paypal.com',
#        'flickr.com', 'criteo.com', 'meraki.com', 'pki.goog',
#        'mangosip.ru', 'medium.com', 'casalemedia.com', 'forbes.com',
#        'dnsowl.com', 'soundcloud.com', 'vtwenty.com', 'qlivecdn.com',
#        'cnn.com', 'miit.gov.cn', 'omtrdc.net', 'aliyuncs.com',
#        'registrar-servers.com', 'miui.com', 't.co', 'cdn-apple.com',
#        'azurewebsites.net', 'myfritz.net', 'shifen.com', 'amazon.dev',
#        'tiktokcdn-us.com', 'taboola.com', 'nflxso.net', 'theguardian.com',
#        'wildberries.ru', 'android.com', 'kaspersky.com', 'wsdvs.com',
#        '2mdn.net', 'gmail.com', 'adobe.io', 'nginx.org', 'w3.org',
#        'ebay.com', 'demdex.net', 'akamaized.net', 'doubleverify.com',
#        'yandex.ru', 'bbc.co.uk', 'akamaihd.net', 'adriver.ru',
#        'nginx.com', 'ozon.ru', 'jomodns.com', 'twitch.tv',
#        'creativecommons.org', 'bbc.com', 'roku.com', 'amazonvideo.com',
#        '3gppnetwork.org', 'edgecdn.ru', 'cisco.com', 'imdb.com', 'ivi.ru',
#        'msftconnecttest.com', 'sourceforge.net', 'salesforce.com',
#        'mit.edu', 'elisa.fi', 'b-cdn.net', 'sciencedirect.com',
#        'ubuntu.com', 'scorecardresearch.com', 'shopify.com',
#        'researchgate.net', 'tiktokcdn-eu.com', 'rubiconproject.com',
#        'nr-data.net', 'ring.com', 'my.com', 'dzeninfra.ru', 'cedexis.net',
#        'who.int', 'azureedge.net', 'hubspot.com', 'youtube-nocookie.com',
#        'facebook.net', 'booking.com', 'smartadserver.com',
#        'launchdarkly.com', 't-online.de', 'slack.com', 'hp.com',
#        'salesforceliveagent.com', 'go.com', 'canva.com', 'googleblog.com',
#        'linktr.ee', 'byteoversea.net', 'doi.org', 'ampproject.org',
#        'wixsite.com', 'mzstatic.com', 'taobao.com', 'wikimedia.org',
#        'sharethrough.com', 'cdngslb.com', 'openx.net', 'tinyurl.com',
#        'example.com', 'issuu.com', 'businessinsider.com', 'alicdn.com',
#        'espn.com', 'appsflyer.com', 'cdc.gov', 'mtgglobals.com',
#        'harvard.edu', 'oracle.com', 'discord.com', '3lift.com', 'drom.ru',
#        'crashlytics.com', 'o365filtering.com', 'adsrvr.org', 'weebly.com',
#        'google.com.br', 'mozilla.com', 'opendns.com', 'avast.com',
#        'reuters.com', 'rlcdn.com', 'media-amazon.com', 'reg.ru',
#        'stripe.com', 'godaddy.com', 'netangels.ru', 'washingtonpost.com',
#        'pubmatic.com', 'alibabadns.com', 'dailymail.co.uk', 'media.net',
#        'grammarly.com', 'tiktokv.us', 'cmediahub.ru', 'amazon.co.uk',
#        'www.gov.uk', 'steamserver.net', 'ttdns2.com', 'vungle.com',
#        'slideshare.net', 'wiley.com', 'nease.net', 'samsungqbe.com',
#        'googletagservices.com', 'atomile.com', 'weibo.com', 'ripn.net',
#        'steampowered.com', 'bidswitch.net', 'appcenter.ms', '1c.ru',
#        'azurefd.net', 'samsungcloud.com', 'usatoday.com', 'jsdelivr.net',
#        'wbx2.com', 'f5.com', 'openai.com', 'bloomberg.com',
#        'telegraph.co.uk', 'adsafeprotected.com', 'playstation.net',
#        'worldfcdn2.com', 'nature.com', 'health.mil', 'criteo.net',
#        'pages.dev', 'ibm.com', 'online.net', 'pangle.io', 'dzen.ru',
#        't-mobile.com', 'wsj.com', 'etsy.com', 'quantserve.com',
#        'dell.com', 'weather.com', 'lijit.com', 'samsungcloudsolution.com',
#        'shalltry.com', 'un.org', 'mi.com', 'dotomi.com',
#        'dailymotion.com', 'springer.com', 'allawnos.com', 'douyincdn.com',
#        'zendesk.com', 'dnsmadeeasy.com', 'wp.com', 'notamedia.ru',
#        'google.de', 'eset.com', 'static.microsoft', 'inmobi.com',
#        'liadm.com', 'mcafee.com', 'php.net', 'ibyteimg.com',
#        'telekom.net', 'ea.com', 'sc-cdn.net', 'adform.net', 'clarity.ms',
#        'quora.com', 'creativecdn.com', 'list-manage.com', 'id5-sync.com',
#        'yximgs.com', 'force.com', 'ksyuncdn.com', 'nasa.gov',
#        'pixabay.com', 'outbrain.com', 'stackoverflow.com',
#        'arubanetworks.com', 'autodesk.com', 'indeed.com', 'pv-cdn.net',
#        'independent.co.uk', 'forter.com', 'stanford.edu',
#        'elasticbeanstalk.com', 'gosuslugi.ru', 'gnu.org', 'cnbc.com',
#        'inner-active.mobi', 'sohu.com', 'unsplash.com', 'globo.com',
#        'cpanel.net', 'comfortel.pro', 'tripadvisor.com', 'eventbrite.com',
#        'checkpoint.com', 'chatgpt.com', 'tp-link.com', 'google.co.uk',
#        'ok.ru', 'mynetname.net', 'consultant.ru', 'aliexpress.com',
#        'xcal.tv', 'discord.gg', 'nstld.com', 'giphy.com', 'xboxlive.com',
#        'heytapdl.com', 'amazonalexa.com', 'npr.org', 'moe.video',
#        'kaspersky-labs.com', 'cdn20.com', 'yahoo.co.jp', 'statista.com',
#        'indexww.com', 'rambler.ru', 'myshopify.com', 'goodreads.com',
#        'isnssdk.com', 'sc-gw.com', 'adobe.net', 'duckduckgo.com',
#        'bilibili.com', 'amazon.de', 'foxnews.com', 'cloud.microsoft',
#        'avcdn.net', 'ttvnw.net', 'sfx.ms', 'walmart.com', 'hichina.com',
#        'nvidia.com', 'g.page', 'capcutapi.com', 'aliyun.com',
#        'telegram.org', 'sophos.com', 'dns-parking.com', 'addtoany.com',
#        'teamviewer.com', 'byteoversea.com', 'firetvcaptiveportal.com',
#        'uber.com', 'tradingview.com', 'naver.com', 'gamepass.com',
#        'time.com', 'branch.io', 'vkuser.net', 'verisign.com',
#        'alibaba.com', 'blogger.com', 'mikrotik.com', 'wired.com',
#        'online-metrix.net', 'hicloud.com', 'temu.com', 'entrust.net',
#        'speedtest.net', 'chinamobile.com', 'kwai.net', 'wix.com',
#        'ngenix.net', 'aol.com', 'telegram.me', 'debian.org', 'amzn.to',
#        'name-services.com', 'trustpilot.com', 'mayoclinic.org',
#        'cnet.com', 'scribd.com', 'behance.net', 'imgsmail.ru',
#        'vedcdnlb.com', 'ctdns.cn', 'surveymonkey.com', 'beian.gov.cn',
#        'launchpad.net', 'duolingo.com', 'phicdn.net', 'imcmdb.net',
#        'ups.com', 'duckdns.org', 'mediatek.com', 'ys7.com',
#        'grammarly.io', 'huawei.com', 'twimg.com', 'ovscdns.com',
#        'trendmicro.com', 'blueapron.com', 'safebrowsing.apple',
#        'kahoot.it', 'google.com.hk', 'att.net', 'indiatimes.com',
#        'ft.com', 'ted.com', '360yield.com', 'squarespace.com',
#        'netease.com', 'digitalocean.com', 'disqus.com',
#        'icloud-content.com'], dtype=object)

# %% [markdown]
# # Sales

# %%
from models.model import train_model

# %% [markdown]
# domain_rankings = pd.read_csv('../data/tranco_5863N.csv')

# %% [markdown]
# domain_rankings.columns

# %% [markdown]
# google_rank = pd.DataFrame({'rank': [1], 'domain': ['google.com']})
#
# domain_rankings.columns = ['rank', 'domain']
#
#
# # Concatenate the new row with the original domain rankings
# domain_rankings = pd.concat([google_rank, domain_rankings], ignore_index=True)
# # Reset the index and display the updated rankings
# domain_rankings.reset_index(drop=True, inplace=True)
# domain_rankings

# %% [markdown]
# results = train_model(X, y, prophet_features, gen_features, target, combined_dataset, features, web3_data, X_web3, y_web3, seed=seed, web3=fine_tuning_web3 )

# %%
# os.chdir('..')
print(os.getcwd())
# Out:
# e:\Projects\liquid_domains\Notebooks

# %% [markdown]
# os.chdir('data')
# print(os.getcwd())

# %% [markdown]
# # Valuation Model

# %%
from sklearn.ensemble import RandomForestRegressor
import joblib

# %%
prophet_model = joblib.load('../pkl/prophet_model.pkl')
ridge_model = joblib.load('../pkl/ridge_model.pkl')
randomforest_model = joblib.load('../pkl/randomforest_model.pkl')

# %%
from models.forecasters import Prophet_Domain_Valuator, Domain_Valuator

# %%
prophet_features
# Out:
# Index(['domain', 'domain_entropy', 'domain_length', 'has_numbers',
#        'is_brandable', 'is_subdomain', 'levenshtein_distance',
#        'num_consonants', 'num_vowels', 'rank', 'tld', 'tld_length',
#        'tld_weight', 'web3', 'word_count'],
#       dtype='object')

# %%
def main(domain, prophet_model, ridge_model, randomforest_model, combined_dataset, prophet_features, gen_features, features, X, y,seed=seed ):
    set_random_seed(seed)

    prophet_features_data = combined_dataset.copy()
    prophet_features_data.rename(columns={"dt": "ds", "price_usd": "y"}, inplace=True)

    prophet_valuator = Prophet_Domain_Valuator(domain, prophet_features, prophet_features_data)
    prophet_valuator.model_prep()
    prophet_domain_value = prophet_valuator.value_domain(prophet_model)

    features_data = combined_dataset.copy()
    features_data['dt'] = features_data['dt'].dt.tz_localize(None)
    features_data = features_data[features] 

    ridge_valuator = Domain_Valuator(domain, X, y, gen_features, features_data, seed)
    ridge_valuator.model_prep()
    ridge_domain_value = ridge_valuator.value_domain(ridge_model)

    randomforest_valuator = Domain_Valuator(domain, X, y, gen_features, features_data, seed)
    randomforest_valuator.model_prep()
    randomforest_domain_value = randomforest_valuator.value_domain(randomforest_model)

    individual_predictions = [
        prophet_domain_value,
        ridge_domain_value,
        randomforest_domain_value
    ]

    ensemble_domain_value = np.median(individual_predictions)
    print(f'individual valuations: {individual_predictions}')
    print(f'ensamble value: {ensemble_domain_value}')

    if ensemble_domain_value < 0:
        print(f'Defaulting from Negative to $0')
        ensemble_domain_value = 0


    return ensemble_domain_value

# %%
domain = 'google.com'

# %%
combined_dataset[combined_dataset['rank']!='unranked']
# Out:
# Empty DataFrame
# Columns: [dt, domain, price_usd, web3, domain_length, num_vowels, num_consonants, tld, word_count, has_numbers, tld_length, is_brandable, levenshtein_distance, is_subdomain, domain_entropy, rank, tld_weight]
# Index: []

# %%
value = main(domain=domain, prophet_model=prophet_model, ridge_model=ridge_model, randomforest_model=randomforest_model, combined_dataset=combined_dataset, prophet_features=prophet_features, gen_features=gen_features, features=features, X=X, y=y)
# Out:
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): ds                      2024-08-03 17:00:00+00:00
# domain                     drivenspyder.chain.box
# y                                            1.33
# web3                                         True
# domain_length                                  22
# num_vowels                                      6
# num_consonants                                 14
# tld                                           box
# word_count                                      1
# has_numbers                                 False
# tld_length                                      3
# is_brandable                                    0
# levenshtein_distance                            6
# is_subdomain                                    1
# domain_entropy                               3.91
# rank                                     unranked
# tld_weight                                      1
# Name: 45915, dtype: object
# Prepared data for prediction:           ds      domain  domain_entropy  domain_length  has_numbers  \
# 0 2024-10-11  google.com            3.91             10        False
#
#    is_brandable  is_subdomain  levenshtein_distance  num_consonants  \
# 0             0             1                     6               5
#
#    num_vowels      rank  tld  tld_length  tld_weight  web3  word_count
# 0           4  unranked  com           3           1  True           1
# Domain: google.com
# Predicted value: -3729.812144295236
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): dt                         2024-08-03 17:00:00
# domain                  drivenspyder.chain.box
# web3                                      True
# domain_length                               22
# num_vowels                                   6
# num_consonants                              14
# tld                                        box
# word_count                                   1
# has_numbers                              False
# tld_length                                   3
# is_brandable                                 0
# levenshtein_distance                         6
# is_subdomain                                 1
# domain_entropy                            3.91
# rank                                  unranked
# tld_weight                                   1
# Name: 45915, dtype: object
# domain df before adding features        domain  domain_length  num_vowels  num_consonants  tld
# 0  google.com             10           4               5  com
# domain df cols Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# missing features ['domain_entropy', 'dt', 'has_numbers', 'is_brandable', 'is_subdomain', 'levenshtein_distance', 'rank', 'tld_length', 'tld_weight', 'web3', 'word_count']
# domain features domain                           google.com
# domain_entropy                         3.91
# domain_length                            10
# dt                      2024-08-03 17:00:00
# has_numbers                           False
# is_brandable                              0
# is_subdomain                              1
# levenshtein_distance                      6
# num_consonants                            5
# num_vowels                                4
# rank                               unranked
# tld                                     com
# tld_length                                3
# tld_weight                                1
# web3                                   True
# word_count                                1
# Name: 0, dtype: object
# Prepared data for prediction:           ds      domain  domain_entropy  domain_length                  dt  \
# 0 2024-10-11  google.com            3.91             10 2024-08-03 17:00:00
#
#    has_numbers  is_brandable  is_subdomain  levenshtein_distance  \
# 0        False             0             1                     6
#
#    num_consonants  num_vowels      rank  tld  tld_length  tld_weight  web3  \
# 0               5           4  unranked  com           3           1  True
#
#    word_count
# 0           1
# Prepared col for prediction: Index(['ds', 'domain', 'domain_entropy', 'domain_length', 'dt', 'has_numbers',
#        'is_brandable', 'is_subdomain', 'levenshtein_distance',
#        'num_consonants', 'num_vowels', 'rank', 'tld', 'tld_length',
#        'tld_weight', 'web3', 'word_count'],
#       dtype='object')
# data:           ds      domain  domain_entropy  domain_length                  dt  \
# 0 2024-10-11  google.com            3.91             10 2024-08-03 17:00:00
#
#    has_numbers  is_brandable  is_subdomain  levenshtein_distance  \
# 0        False             0             1                     6
#
#    num_consonants  num_vowels      rank  tld  tld_length  tld_weight  web3  \
# 0               5           4  unranked  com           3           1  True
#
#    word_count
# 0           1
# domain: google.com
# predicted value: 16745.12212099762
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): dt                         2024-08-03 17:00:00
# domain                  drivenspyder.chain.box
# web3                                      True
# domain_length                               22
# num_vowels                                   6
# num_consonants                              14
# tld                                        box
# word_count                                   1
# has_numbers                              False
# tld_length                                   3
# is_brandable                                 0
# levenshtein_distance                         6
# is_subdomain                                 1
# domain_entropy                            3.91
# rank                                  unranked
# tld_weight                                   1
# Name: 45915, dtype: object
# domain df before adding features        domain  domain_length  num_vowels  num_consonants  tld
# 0  google.com             10           4               5  com
# domain df cols Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# missing features ['domain_entropy', 'dt', 'has_numbers', 'is_brandable', 'is_subdomain', 'levenshtein_distance', 'rank', 'tld_length', 'tld_weight', 'web3', 'word_count']
# domain features domain                           google.com
# domain_entropy                         3.91
# domain_length                            10
# dt                      2024-08-03 17:00:00
# has_numbers                           False
# is_brandable                              0
# is_subdomain                              1
# levenshtein_distance                      6
# num_consonants                            5
# num_vowels                                4
# rank                               unranked
# tld                                     com
# tld_length                                3
# tld_weight                                1
# web3                                   True
# word_count                                1
# Name: 0, dtype: object
# Prepared data for prediction:           ds      domain  domain_entropy  domain_length                  dt  \
# 0 2024-10-11  google.com            3.91             10 2024-08-03 17:00:00
#
#    has_numbers  is_brandable  is_subdomain  levenshtein_distance  \
# 0        False             0             1                     6
#
#    num_consonants  num_vowels      rank  tld  tld_length  tld_weight  web3  \
# 0               5           4  unranked  com           3           1  True
#
#    word_count
# 0           1
# Prepared col for prediction: Index(['ds', 'domain', 'domain_entropy', 'domain_length', 'dt', 'has_numbers',
#        'is_brandable', 'is_subdomain', 'levenshtein_distance',
#        'num_consonants', 'num_vowels', 'rank', 'tld', 'tld_length',
#        'tld_weight', 'web3', 'word_count'],
#       dtype='object')
# data:           ds      domain  domain_entropy  domain_length                  dt  \
# 0 2024-10-11  google.com            3.91             10 2024-08-03 17:00:00
#
#    has_numbers  is_brandable  is_subdomain  levenshtein_distance  \
# 0        False             0             1                     6
#
#    num_consonants  num_vowels      rank  tld  tld_length  tld_weight  web3  \
# 0               5           4  unranked  com           3           1  True
#
#    word_count
# 0           1
# domain: google.com
# predicted value: 63.60168722659159
# individual valuations: [np.float64(-3729.812144295236), np.float64(16745.12212099762), np.float64(63.60168722659159)]
# ensamble value: 63.60168722659159

# %% [markdown]
# from sklearn.model_selection import GridSearchCV
#
# # Define TLD weight grid
# param_grid = {
#     'tld_weight': [{'com': w_com, 'net': w_net, 'org': w_org, 'eth': w_eth}
#                    for w_com in [1.0, 1.5, 2.0]
#                    for w_net in [0.8, 1.2, 1.5]
#                    for w_org in [1.0, 1.5, 2.0]
#                    for w_eth in [1.0, 2.0, 3.0]]
# }
#
# grid_search = GridSearchCV(estimator=model_pipeline, param_grid=param_grid, cv=5)
# grid_search.fit(X, y)
# best_weights = grid_search.best_params_

# %%
params = {
    "New API Data":api,
    "Used web2 Data":web2_data,
    "Used threshold for correlation value":threshold,
    "Used temporals":temporals,
    "Fine tuned on web3 data":fine_tuning_web3,
    "Domain":domain,
    "Ensamble Value":value
}

params_df = pd.DataFrame([params])

# %%
today = dt.datetime.today().strftime("%d-%m-%y-%H-%M-%S")

today = str(today)

# results_df = pd.DataFrame([results])

# combined_df = pd.concat([results_df, params_df], axis=1)

combined_df = params_df.copy()

combined_df.to_csv(f'../data/results_{today}.csv')

print(combined_df)
# Out:
#    New API Data  Used web2 Data Used threshold for correlation value  \
# 0         False           False                                 None
#
#    Used temporals  Fine tuned on web3 data      Domain  Ensamble Value
# 0           False                    False  google.com           63.60

# %%
liquidity_discount = 0.3 #If we want to discount 90%, we only take 10% of value 

discounted_value = value * liquidity_discount

liquidity_discount_filtered = 1 - liquidity_discount

print(f'Domain: {domain} \nValue: ${value:,.2f} \nLiquidity Discount: {liquidity_discount_filtered*100:.2f}% \nDiscounted Price w/ Liquidity Discount: ${discounted_value:,.2f}')
# Out:
# Domain: google.com
# Value: $63.60
# Liquidity Discount: 70.00%
# Discounted Price w/ Liquidity Discount: $19.08

# %%
subdomain_values = combined_dataset[combined_dataset['is_subdomain']==1]['domain'].unique()

# %%
subdomain_struct = enumerate(subdomain_values)

# %% [markdown]
# for idx, val in enumerate(subdomain_values):
#     print(f'val: {val}')

# %%
combined_dataset['tld'].unique()
# Out:
# array(['crypto', 'scottishcryptoloans', '888', 'x', 'coin', 'nft',
#        'wallet', 'bitcoin', 'dao', 'op', 'blockchain', 'eth', 'eth ⚠️',
#        'Unknown ENS name', '',
#        '...',
#        'base', 'finance', 'xyz',
#        '...',
#        'box', 'buzz', 'one', 'bio', 'wtf', 'quest', 'org', 'com', 'pro',
#        'blog', 'autos'], dtype=object)

# %%
def search(domain, tld, liquidity_discount=0.3):
    web3_tlds = ['.op', '.crypto', '.box', '.eth', '.base', '.nft', '.wallet', '.coin', '.finance', '.xyz', '.dao', '.bitcoin', '.blockchain']

    print(f'domain: {domain}')
    print(f'tld: {tld}')

    # Allow subdomains, so no error for dot in domain
    # Check if the TLD ends with any of the Web3 TLDs
    if not any(tld.endswith(web3_tld) for web3_tld in web3_tlds):
        raise ValueError('Error: Cannot Value Non-Web3 Domain')

    full_domain = domain + tld
    value = main(domain=full_domain, prophet_model=prophet_model, ridge_model=ridge_model, randomforest_model=randomforest_model, combined_dataset=combined_dataset, prophet_features=prophet_features, gen_features=gen_features, features=features, X=X, y=y)

    discounted_value = value * liquidity_discount
    liquidity_discount_filtered = 1 - liquidity_discount

    print(f'Domain: {full_domain} \nValue: ${value:,.2f} \nLiquidity Discount: {liquidity_discount_filtered*100:.2f}% \nDiscounted Price w/ Liquidity Discount: ${discounted_value:,.2f}')
    
    return value, discounted_value

# %%
domain='five'
tld='.super.eth'

# %%
search(domain,tld,liquidity_discount=0.05)
# Out:
# domain: five
# tld: .super.eth
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): ds                      2024-08-03 17:00:00+00:00
# domain                     drivenspyder.chain.box
# y                                            1.33
# web3                                         True
# domain_length                                  22
# num_vowels                                      6
# num_consonants                                 14
# tld                                           box
# word_count                                      1
# has_numbers                                 False
# tld_length                                      3
# is_brandable                                    0
# levenshtein_distance                            6
# is_subdomain                                    1
# domain_entropy                               3.91
# rank                                     unranked
# tld_weight                                      1
# Name: 45915, dtype: object
# Prepared data for prediction:           ds          domain  domain_entropy  domain_length  has_numbers  \
# 0 2024-10-11  five.super.eth            3.91             14        False
#
#    is_brandable  is_subdomain  levenshtein_distance  num_consonants  \
# 0             0             1                     6               7
#
#    num_vowels      rank  tld  tld_length  tld_weight  web3  word_count
# 0           5  unranked  eth           3           1  True           1
# Domain: five.super.eth
# Predicted value: -3729.671149717488
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): dt                         2024-08-03 17:00:00
# domain                  drivenspyder.chain.box
# web3                                      True
# domain_length                               22
# num_vowels                                   6
# num_consonants                              14
# tld                                        box
# word_count                                   1
# has_numbers                              False
# tld_length                                   3
# is_brandable                                 0
# levenshtein_distance                         6
# is_subdomain                                 1
# domain_entropy                            3.91
# rank                                  unranked
# tld_weight                                   1
# Name: 45915, dtype: object
# domain df before adding features            domain  domain_length  num_vowels  num_consonants  tld
# 0  five.super.eth             14           5               7  eth
# domain df cols Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# missing features ['domain_entropy', 'dt', 'has_numbers', 'is_brandable', 'is_subdomain', 'levenshtein_distance', 'rank', 'tld_length', 'tld_weight', 'web3', 'word_count']
# domain features domain                       five.super.eth
# domain_entropy                         3.91
# domain_length                            14
# dt                      2024-08-03 17:00:00
# has_numbers                           False
# is_brandable                              0
# is_subdomain                              1
# levenshtein_distance                      6
# num_consonants                            7
# num_vowels                                5
# rank                               unranked
# tld                                     eth
# tld_length                                3
# tld_weight                                1
# web3                                   True
# word_count                                1
# Name: 0, dtype: object
# Prepared data for prediction:           ds          domain  domain_entropy  domain_length  \
# 0 2024-10-11  five.super.eth            3.91             14
#
#                    dt  has_numbers  is_brandable  is_subdomain  \
# 0 2024-08-03 17:00:00        False             0             1
#
#    levenshtein_distance  num_consonants  num_vowels      rank  tld  \
# 0                     6               7           5  unranked  eth
#
#    tld_length  tld_weight  web3  word_count
# 0           3           1  True           1
# Prepared col for prediction: Index(['ds', 'domain', 'domain_entropy', 'domain_length', 'dt', 'has_numbers',
#        'is_brandable', 'is_subdomain', 'levenshtein_distance',
#        'num_consonants', 'num_vowels', 'rank', 'tld', 'tld_length',
#        'tld_weight', 'web3', 'word_count'],
#       dtype='object')
# data:           ds          domain  domain_entropy  domain_length  \
# 0 2024-10-11  five.super.eth            3.91             14
#
#                    dt  has_numbers  is_brandable  is_subdomain  \
# 0 2024-08-03 17:00:00        False             0             1
#
#    levenshtein_distance  num_consonants  num_vowels      rank  tld  \
# 0                     6               7           5  unranked  eth
#
#    tld_length  tld_weight  web3  word_count
# 0           3           1  True           1
# domain: five.super.eth
# predicted value: 6289.051781073193
# Domain DataFrame Columns: Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# Feature Data (latest entry): dt                         2024-08-03 17:00:00
# domain                  drivenspyder.chain.box
# web3                                      True
# domain_length                               22
# num_vowels                                   6
# num_consonants                              14
# tld                                        box
# word_count                                   1
# has_numbers                              False
# tld_length                                   3
# is_brandable                                 0
# levenshtein_distance                         6
# is_subdomain                                 1
# domain_entropy                            3.91
# rank                                  unranked
# tld_weight                                   1
# Name: 45915, dtype: object
# domain df before adding features            domain  domain_length  num_vowels  num_consonants  tld
# 0  five.super.eth             14           5               7  eth
# domain df cols Index(['domain', 'domain_length', 'num_vowels', 'num_consonants', 'tld'], dtype='object')
# missing features ['domain_entropy', 'dt', 'has_numbers', 'is_brandable', 'is_subdomain', 'levenshtein_distance', 'rank', 'tld_length', 'tld_weight', 'web3', 'word_count']
# domain features domain                       five.super.eth
# domain_entropy                         3.91
# domain_length                            14
# dt                      2024-08-03 17:00:00
# has_numbers                           False
# is_brandable                              0
# is_subdomain                              1
# levenshtein_distance                      6
# num_consonants                            7
# num_vowels                                5
# rank                               unranked
# tld                                     eth
# tld_length                                3
# tld_weight                                1
# web3                                   True
# word_count                                1
# Name: 0, dtype: object
# Prepared data for prediction:           ds          domain  domain_entropy  domain_length  \
# 0 2024-10-11  five.super.eth            3.91             14
#
#                    dt  has_numbers  is_brandable  is_subdomain  \
# 0 2024-08-03 17:00:00        False             0             1
#
#    levenshtein_distance  num_consonants  num_vowels      rank  tld  \
# 0                     6               7           5  unranked  eth
#
#    tld_length  tld_weight  web3  word_count
# 0           3           1  True           1
# Prepared col for prediction: Index(['ds', 'domain', 'domain_entropy', 'domain_length', 'dt', 'has_numbers',
#        'is_brandable', 'is_subdomain', 'levenshtein_distance',
#        'num_consonants', 'num_vowels', 'rank', 'tld', 'tld_length',
#        'tld_weight', 'web3', 'word_count'],
#       dtype='object')
# data:           ds          domain  domain_entropy  domain_length  \
# 0 2024-10-11  five.super.eth            3.91             14
#
#                    dt  has_numbers  is_brandable  is_subdomain  \
# 0 2024-08-03 17:00:00        False             0             1
#
#    levenshtein_distance  num_consonants  num_vowels      rank  tld  \
# 0                     6               7           5  unranked  eth
#
#    tld_length  tld_weight  web3  word_count
# 0           3           1  True           1
# domain: five.super.eth
# predicted value: 20.31117575691378
# individual valuations: [np.float64(-3729.671149717488), np.float64(6289.051781073193), np.float64(20.31117575691378)]
# ensamble value: 20.31117575691378
# Domain: five.super.eth
# Value: $20.31
# Liquidity Discount: 95.00%
# Discounted Price w/ Liquidity Discount: $1.02
# (np.float64(20.31117575691378), np.float64(1.015558787845689))

# %% [markdown]
# dcc.Input(
#             id='valuator-input',
#             value='example',
#             type='text',
#             style={
#                 'padding': '10px',
#                 'borderRadius': 'var(--wcm-input-border-radius)',
#                 'border': '1px solid var(--color-border)',
#                 'marginRight': '10px'
#             },
#             pattern='[^.]*'  # Regex pattern to disallow '.' character

# %% [markdown]
# Optimistic_Domains_Sales_query = """
#   SELECT
#   DATE_TRUNC('HOUR', BLOCK_TIMESTAMP) AS day,
#   tokenid,
#   price,
#   price_usd
# FROM
#   optimism.nft.ez_nft_sales
# WHERE
#   NFT_ADDRESS = LOWER('0xC16aCAdf99E4540E6f4E6Da816fd6D2A2C6E1d4F')
#   AND event_type = 'sale'
# order by
#   DATE_TRUNC('HOUR', BLOCK_TIMESTAMP) asc
#
# """

# %% [markdown]
# optimistic_domains_sales_path = '../data/optimistic_domains_sales.csv'

# %% [markdown]
# optimistic_domains_sales = flipside_api_results(Optimistic_Domains_Sales_query,flipside_api_key)
# optimistic_domains_sales.to_csv(optimistic_domains_sales_path, index=False)

# %% [markdown]
# from scripts.apis import alchemy_metadata_api

# %% [markdown]
# prices_path = '../data/prices.csv'
# Optimistic_domains_path = '../data/optimistic_domains_metadata.json'
#
# prices = flipside_api_results(eth_price, flipside_api_key)
# prices.to_csv(prices_path,index=False)
#
# optimistic_domains = alchemy_metadata_api(alchemy_api_key, 'optimism', '0xC16aCAdf99E4540E6f4E6Da816fd6D2A2C6E1d4F')
# optimistic_domains.to_json(Optimistic_domains_path, orient='records')
